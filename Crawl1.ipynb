# %%
import requests
import time
import csv

# Đường dẫn đến file CSV
file_path = r"E:\\DA\\Crawl\\BacCan_11.csv"

# Mở file CSV để ghi dữ liệu
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Ghi tiêu đề cột
    writer.writerow([
        'SBD', 'Toan', 'Van', 'NgoaiNgu', 'VatLy', 'HoaHoc', 'SinhHoc',
        'TBKHTN', 'LichSu', 'DiaLy', 'GDCD', 'TBKHXH'
    ])
    
    # Vòng lặp lấy dữ liệu
    for x in range(11000001, 12000001):
        scraping_url = f"https://dantri.com.vn/thpt/1/0/99/{x}/2024/0.2/search-gradle.htm"
        
        try:
            # Gửi yêu cầu
            response = requests.get(scraping_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            
            # Phân tích phản hồi JSON
            data = response.json()
            
            # Kiểm tra nếu có khóa 'student' trong phản hồi
            if 'student' in data:
                info = data['student']
                
                # Ghi dữ liệu vào file CSV
                writer.writerow([
                    info.get('sbd', 'None'),
                    info.get('toan', 'None'),
                    info.get('van', 'None'),
                    info.get('ngoaiNgu', 'None'),
                    info.get('vatLy', 'None'),
                    info.get('hoaHoc', 'None'),
                    info.get('sinhHoc', 'None'),
                    info.get('diemTBTuNhien', 'None'),
                    info.get('lichSu', 'None'),
                    info.get('diaLy', 'None'),
                    info.get('gdcd', 'None'),
                    info.get('diemTBXaHoi', 'None')
                ])
                
                # Hiển thị thông báo đã ghi dữ liệu thành công
                print(f"Đã ghi dữ liệu thành công cho SBD: {info.get('sbd', 'Unknown')}")

                # Đảm bảo dữ liệu được ghi vào tệp ngay lập tức
                file.flush()
            else:
                print(f"Không có khóa 'student' trong phản hồi cho URL: {scraping_url}")
            
        except requests.RequestException as e:
            print(f"Yêu cầu không thành công cho URL {scraping_url}: {e}")
        except ValueError as e:
            print(f"Lỗi khi phân tích cú pháp JSON cho URL {scraping_url}: {e}")
        except csv.Error as e:
            print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
        
        # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
        time.sleep(0.4)
# Out:
# Đã ghi dữ liệu thành công cho SBD: 11000001
# Đã ghi dữ liệu thành công cho SBD: 11000002
# Đã ghi dữ liệu thành công cho SBD: 11000003
# Đã ghi dữ liệu thành công cho SBD: 11000004
# Đã ghi dữ liệu thành công cho SBD: 11000005
# Đã ghi dữ liệu thành công cho SBD: 11000006
# Đã ghi dữ liệu thành công cho SBD: 11000007
# Đã ghi dữ liệu thành công cho SBD: 11000008
# Đã ghi dữ liệu thành công cho SBD: 11000009
# Đã ghi dữ liệu thành công cho SBD: 11000010
# Đã ghi dữ liệu thành công cho SBD: 11000011
# Đã ghi dữ liệu thành công cho SBD: 11000012
# Đã ghi dữ liệu thành công cho SBD: 11000013
# Đã ghi dữ liệu thành công cho SBD: 11000014
# Đã ghi dữ liệu thành công cho SBD: 11000015
# Đã ghi dữ liệu thành công cho SBD: 11000016
# Đã ghi dữ liệu thành công cho SBD: 11000017
# Đã ghi dữ liệu thành công cho SBD: 11000018
# Đã ghi dữ liệu thành công cho SBD: 11000019
# Đã ghi dữ liệu thành công cho SBD: 11000020
# Đã ghi dữ liệu thành công cho SBD: 11000021
# Đã ghi dữ liệu thành công cho SBD: 11000022
# Đã ghi dữ liệu thành công cho SBD: 11000023
# Đã ghi dữ liệu thành công cho SBD: 11000024
# Đã ghi dữ liệu thành công cho SBD: 11000025
# Đã ghi dữ liệu thành công cho SBD: 11000026
# Đã ghi dữ liệu thành công cho SBD: 11000027
# Đã ghi dữ liệu thành công cho SBD: 11000028
# Đã ghi dữ liệu thành công cho SBD: 11000029
# Đã ghi dữ liệu thành công cho SBD: 11000030
# Đã ghi dữ liệu thành công cho SBD: 11000031
# Đã ghi dữ liệu thành công cho SBD: 11000032
# Đã ghi dữ liệu thành công cho SBD: 11000033
# Đã ghi dữ liệu thành công cho SBD: 11000034
# Đã ghi dữ liệu thành công cho SBD: 11000035
# Đã ghi dữ liệu thành công cho SBD: 11000036
# Đã ghi dữ liệu thành công cho SBD: 11000037
# Đã ghi dữ liệu thành công cho SBD: 11000038
# Đã ghi dữ liệu thành công cho SBD: 11000039
# Đã ghi dữ liệu thành công cho SBD: 11000040
# Đã ghi dữ liệu thành công cho SBD: 11000041
# Đã ghi dữ liệu thành công cho SBD: 11000042
# Đã ghi dữ liệu thành công cho SBD: 11000043
# Đã ghi dữ liệu thành công cho SBD: 11000044
# Đã ghi dữ liệu thành công cho SBD: 11000045
# Đã ghi dữ liệu thành công cho SBD: 11000046
# Đã ghi dữ liệu thành công cho SBD: 11000047
# Đã ghi dữ liệu thành công cho SBD: 11000048
# Đã ghi dữ liệu thành công cho SBD: 11000049
# Đã ghi dữ liệu thành công cho SBD: 11000050
# Đã ghi dữ liệu thành công cho SBD: 11000051
# Đã ghi dữ liệu thành công cho SBD: 11000052
# Đã ghi dữ liệu thành công cho SBD: 11000053
# Đã ghi dữ liệu thành công cho SBD: 11000054
# Đã ghi dữ liệu thành công cho SBD: 11000055
# Đã ghi dữ liệu thành công cho SBD: 11000056
# Đã ghi dữ liệu thành công cho SBD: 11000057
# Đã ghi dữ liệu thành công cho SBD: 11000058
# Đã ghi dữ liệu thành công cho SBD: 11000059
# Đã ghi dữ liệu thành công cho SBD: 11000060
# Đã ghi dữ liệu thành công cho SBD: 11000061
# Đã ghi dữ liệu thành công cho SBD: 11000062
# Đã ghi dữ liệu thành công cho SBD: 11000063
# Đã ghi dữ liệu thành công cho SBD: 11000064
# Đã ghi dữ liệu thành công cho SBD: 11000065
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000067
# Đã ghi dữ liệu thành công cho SBD: 11000068
# Đã ghi dữ liệu thành công cho SBD: 11000069
# Đã ghi dữ liệu thành công cho SBD: 11000070
# Đã ghi dữ liệu thành công cho SBD: 11000071
# Đã ghi dữ liệu thành công cho SBD: 11000072
# Đã ghi dữ liệu thành công cho SBD: 11000073
# Đã ghi dữ liệu thành công cho SBD: 11000074
# Đã ghi dữ liệu thành công cho SBD: 11000075
# Đã ghi dữ liệu thành công cho SBD: 11000076
# Đã ghi dữ liệu thành công cho SBD: 11000077
# Đã ghi dữ liệu thành công cho SBD: 11000078
# Đã ghi dữ liệu thành công cho SBD: 11000079
# Đã ghi dữ liệu thành công cho SBD: 11000080
# Đã ghi dữ liệu thành công cho SBD: 11000081
# Đã ghi dữ liệu thành công cho SBD: 11000082
# Đã ghi dữ liệu thành công cho SBD: 11000083
# Đã ghi dữ liệu thành công cho SBD: 11000084
# Đã ghi dữ liệu thành công cho SBD: 11000085
# Đã ghi dữ liệu thành công cho SBD: 11000086
# Đã ghi dữ liệu thành công cho SBD: 11000087
# Đã ghi dữ liệu thành công cho SBD: 11000088
# Đã ghi dữ liệu thành công cho SBD: 11000089
# Đã ghi dữ liệu thành công cho SBD: 11000090
# Đã ghi dữ liệu thành công cho SBD: 11000091
# Đã ghi dữ liệu thành công cho SBD: 11000092
# Đã ghi dữ liệu thành công cho SBD: 11000093
# Đã ghi dữ liệu thành công cho SBD: 11000094
# Đã ghi dữ liệu thành công cho SBD: 11000095
# Đã ghi dữ liệu thành công cho SBD: 11000096
# Đã ghi dữ liệu thành công cho SBD: 11000097
# Đã ghi dữ liệu thành công cho SBD: 11000098
# Đã ghi dữ liệu thành công cho SBD: 11000099
# Đã ghi dữ liệu thành công cho SBD: 11000100
# Đã ghi dữ liệu thành công cho SBD: 11000101
# Đã ghi dữ liệu thành công cho SBD: 11000102
# Đã ghi dữ liệu thành công cho SBD: 11000103
# Đã ghi dữ liệu thành công cho SBD: 11000104
# Đã ghi dữ liệu thành công cho SBD: 11000105
# Đã ghi dữ liệu thành công cho SBD: 11000106
# Đã ghi dữ liệu thành công cho SBD: 11000107
# Đã ghi dữ liệu thành công cho SBD: 11000108
# Đã ghi dữ liệu thành công cho SBD: 11000109
# Đã ghi dữ liệu thành công cho SBD: 11000110
# Đã ghi dữ liệu thành công cho SBD: 11000111
# Đã ghi dữ liệu thành công cho SBD: 11000112
# Đã ghi dữ liệu thành công cho SBD: 11000113
# Đã ghi dữ liệu thành công cho SBD: 11000114
# Đã ghi dữ liệu thành công cho SBD: 11000115
# Đã ghi dữ liệu thành công cho SBD: 11000116
# Đã ghi dữ liệu thành công cho SBD: 11000117
# Đã ghi dữ liệu thành công cho SBD: 11000118
# Đã ghi dữ liệu thành công cho SBD: 11000119
# Đã ghi dữ liệu thành công cho SBD: 11000120
# Đã ghi dữ liệu thành công cho SBD: 11000121
# Đã ghi dữ liệu thành công cho SBD: 11000122
# Đã ghi dữ liệu thành công cho SBD: 11000123
# Đã ghi dữ liệu thành công cho SBD: 11000124
# Đã ghi dữ liệu thành công cho SBD: 11000125
# Đã ghi dữ liệu thành công cho SBD: 11000126
# Đã ghi dữ liệu thành công cho SBD: 11000127
# Đã ghi dữ liệu thành công cho SBD: 11000128
# Đã ghi dữ liệu thành công cho SBD: 11000129
# Đã ghi dữ liệu thành công cho SBD: 11000130
# Đã ghi dữ liệu thành công cho SBD: 11000131
# Đã ghi dữ liệu thành công cho SBD: 11000132
# Đã ghi dữ liệu thành công cho SBD: 11000133
# Đã ghi dữ liệu thành công cho SBD: 11000134
# Đã ghi dữ liệu thành công cho SBD: 11000135
# Đã ghi dữ liệu thành công cho SBD: 11000136
# Đã ghi dữ liệu thành công cho SBD: 11000137
# Đã ghi dữ liệu thành công cho SBD: 11000138
# Đã ghi dữ liệu thành công cho SBD: 11000139
# Đã ghi dữ liệu thành công cho SBD: 11000140
# Đã ghi dữ liệu thành công cho SBD: 11000141
# Đã ghi dữ liệu thành công cho SBD: 11000142
# Đã ghi dữ liệu thành công cho SBD: 11000143
# Đã ghi dữ liệu thành công cho SBD: 11000144
# Đã ghi dữ liệu thành công cho SBD: 11000145
# Đã ghi dữ liệu thành công cho SBD: 11000146
# Đã ghi dữ liệu thành công cho SBD: 11000147
# Đã ghi dữ liệu thành công cho SBD: 11000148
# Đã ghi dữ liệu thành công cho SBD: 11000149
# Đã ghi dữ liệu thành công cho SBD: 11000150
# Đã ghi dữ liệu thành công cho SBD: 11000151
# Đã ghi dữ liệu thành công cho SBD: 11000152
# Đã ghi dữ liệu thành công cho SBD: 11000153
# Đã ghi dữ liệu thành công cho SBD: 11000154
# Đã ghi dữ liệu thành công cho SBD: 11000155
# Đã ghi dữ liệu thành công cho SBD: 11000156
# Đã ghi dữ liệu thành công cho SBD: 11000157
# Đã ghi dữ liệu thành công cho SBD: 11000158
# Đã ghi dữ liệu thành công cho SBD: 11000159
# Đã ghi dữ liệu thành công cho SBD: 11000160
# Đã ghi dữ liệu thành công cho SBD: 11000161
# Đã ghi dữ liệu thành công cho SBD: 11000162
# Đã ghi dữ liệu thành công cho SBD: 11000163
# Đã ghi dữ liệu thành công cho SBD: 11000164
# Đã ghi dữ liệu thành công cho SBD: 11000165
# Đã ghi dữ liệu thành công cho SBD: 11000166
# Đã ghi dữ liệu thành công cho SBD: 11000167
# Đã ghi dữ liệu thành công cho SBD: 11000168
# Đã ghi dữ liệu thành công cho SBD: 11000169
# Đã ghi dữ liệu thành công cho SBD: 11000170
# Đã ghi dữ liệu thành công cho SBD: 11000171
# Đã ghi dữ liệu thành công cho SBD: 11000172
# Đã ghi dữ liệu thành công cho SBD: 11000173
# Đã ghi dữ liệu thành công cho SBD: 11000174
# Đã ghi dữ liệu thành công cho SBD: 11000175
# Đã ghi dữ liệu thành công cho SBD: 11000176
# Đã ghi dữ liệu thành công cho SBD: 11000177
# Đã ghi dữ liệu thành công cho SBD: 11000178
# Đã ghi dữ liệu thành công cho SBD: 11000179
# Đã ghi dữ liệu thành công cho SBD: 11000180
# Đã ghi dữ liệu thành công cho SBD: 11000181
# Đã ghi dữ liệu thành công cho SBD: 11000182
# Đã ghi dữ liệu thành công cho SBD: 11000183
# Đã ghi dữ liệu thành công cho SBD: 11000184
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000186
# Đã ghi dữ liệu thành công cho SBD: 11000187
# Đã ghi dữ liệu thành công cho SBD: 11000188
# Đã ghi dữ liệu thành công cho SBD: 11000189
# Đã ghi dữ liệu thành công cho SBD: 11000190
# Đã ghi dữ liệu thành công cho SBD: 11000191
# Đã ghi dữ liệu thành công cho SBD: 11000192
# Đã ghi dữ liệu thành công cho SBD: 11000193
# Đã ghi dữ liệu thành công cho SBD: 11000194
# Đã ghi dữ liệu thành công cho SBD: 11000195
# Đã ghi dữ liệu thành công cho SBD: 11000196
# Đã ghi dữ liệu thành công cho SBD: 11000197
# Đã ghi dữ liệu thành công cho SBD: 11000198
# Đã ghi dữ liệu thành công cho SBD: 11000199
# Đã ghi dữ liệu thành công cho SBD: 11000200
# Đã ghi dữ liệu thành công cho SBD: 11000201
# Đã ghi dữ liệu thành công cho SBD: 11000202
# Đã ghi dữ liệu thành công cho SBD: 11000203
# Đã ghi dữ liệu thành công cho SBD: 11000204
# Đã ghi dữ liệu thành công cho SBD: 11000205
# Đã ghi dữ liệu thành công cho SBD: 11000206
# Đã ghi dữ liệu thành công cho SBD: 11000207
# Đã ghi dữ liệu thành công cho SBD: 11000208
# Đã ghi dữ liệu thành công cho SBD: 11000209
# Đã ghi dữ liệu thành công cho SBD: 11000210
# Đã ghi dữ liệu thành công cho SBD: 11000211
# Đã ghi dữ liệu thành công cho SBD: 11000212
# Đã ghi dữ liệu thành công cho SBD: 11000213
# Đã ghi dữ liệu thành công cho SBD: 11000214
# Đã ghi dữ liệu thành công cho SBD: 11000215
# Đã ghi dữ liệu thành công cho SBD: 11000216
# Đã ghi dữ liệu thành công cho SBD: 11000217
# Đã ghi dữ liệu thành công cho SBD: 11000218
# Đã ghi dữ liệu thành công cho SBD: 11000219
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000221
# Đã ghi dữ liệu thành công cho SBD: 11000222
# Đã ghi dữ liệu thành công cho SBD: 11000223
# Đã ghi dữ liệu thành công cho SBD: 11000224
# Đã ghi dữ liệu thành công cho SBD: 11000225
# Đã ghi dữ liệu thành công cho SBD: 11000226
# Đã ghi dữ liệu thành công cho SBD: 11000227
# Đã ghi dữ liệu thành công cho SBD: 11000228
# Đã ghi dữ liệu thành công cho SBD: 11000229
# Đã ghi dữ liệu thành công cho SBD: 11000230
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000232
# Đã ghi dữ liệu thành công cho SBD: 11000233
# Đã ghi dữ liệu thành công cho SBD: 11000234
# Đã ghi dữ liệu thành công cho SBD: 11000235
# Đã ghi dữ liệu thành công cho SBD: 11000236
# Đã ghi dữ liệu thành công cho SBD: 11000237
# Đã ghi dữ liệu thành công cho SBD: 11000238
# Đã ghi dữ liệu thành công cho SBD: 11000239
# Đã ghi dữ liệu thành công cho SBD: 11000240
# Đã ghi dữ liệu thành công cho SBD: 11000241
# Đã ghi dữ liệu thành công cho SBD: 11000242
# Đã ghi dữ liệu thành công cho SBD: 11000243
# Đã ghi dữ liệu thành công cho SBD: 11000244
# Đã ghi dữ liệu thành công cho SBD: 11000245
# Đã ghi dữ liệu thành công cho SBD: 11000246
# Đã ghi dữ liệu thành công cho SBD: 11000247
# Đã ghi dữ liệu thành công cho SBD: 11000248
# Đã ghi dữ liệu thành công cho SBD: 11000249
# Đã ghi dữ liệu thành công cho SBD: 11000250
# Đã ghi dữ liệu thành công cho SBD: 11000251
# Đã ghi dữ liệu thành công cho SBD: 11000252
# Đã ghi dữ liệu thành công cho SBD: 11000253
# Đã ghi dữ liệu thành công cho SBD: 11000254
# Đã ghi dữ liệu thành công cho SBD: 11000255
# Đã ghi dữ liệu thành công cho SBD: 11000256
# Đã ghi dữ liệu thành công cho SBD: 11000257
# Đã ghi dữ liệu thành công cho SBD: 11000258
# Đã ghi dữ liệu thành công cho SBD: 11000259
# Đã ghi dữ liệu thành công cho SBD: 11000260
# Đã ghi dữ liệu thành công cho SBD: 11000261
# Đã ghi dữ liệu thành công cho SBD: 11000262
# Đã ghi dữ liệu thành công cho SBD: 11000263
# Đã ghi dữ liệu thành công cho SBD: 11000264
# Đã ghi dữ liệu thành công cho SBD: 11000265
# Đã ghi dữ liệu thành công cho SBD: 11000266
# Đã ghi dữ liệu thành công cho SBD: 11000267
# Đã ghi dữ liệu thành công cho SBD: 11000268
# Đã ghi dữ liệu thành công cho SBD: 11000269
# Đã ghi dữ liệu thành công cho SBD: 11000270
# Đã ghi dữ liệu thành công cho SBD: 11000271
# Đã ghi dữ liệu thành công cho SBD: 11000272
# Đã ghi dữ liệu thành công cho SBD: 11000273
# Đã ghi dữ liệu thành công cho SBD: 11000274
# Đã ghi dữ liệu thành công cho SBD: 11000275
# Đã ghi dữ liệu thành công cho SBD: 11000276
# Đã ghi dữ liệu thành công cho SBD: 11000277
# Đã ghi dữ liệu thành công cho SBD: 11000278
# Đã ghi dữ liệu thành công cho SBD: 11000279
# Đã ghi dữ liệu thành công cho SBD: 11000280
# Đã ghi dữ liệu thành công cho SBD: 11000281
# Đã ghi dữ liệu thành công cho SBD: 11000282
# Đã ghi dữ liệu thành công cho SBD: 11000283
# Đã ghi dữ liệu thành công cho SBD: 11000284
# Đã ghi dữ liệu thành công cho SBD: 11000285
# Đã ghi dữ liệu thành công cho SBD: 11000286
# Đã ghi dữ liệu thành công cho SBD: 11000287
# Đã ghi dữ liệu thành công cho SBD: 11000288
# Đã ghi dữ liệu thành công cho SBD: 11000289
# Đã ghi dữ liệu thành công cho SBD: 11000290
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000292
# Đã ghi dữ liệu thành công cho SBD: 11000293
# Đã ghi dữ liệu thành công cho SBD: 11000294
# Đã ghi dữ liệu thành công cho SBD: 11000295
# Đã ghi dữ liệu thành công cho SBD: 11000296
# Đã ghi dữ liệu thành công cho SBD: 11000297
# Đã ghi dữ liệu thành công cho SBD: 11000298
# Đã ghi dữ liệu thành công cho SBD: 11000299
# Đã ghi dữ liệu thành công cho SBD: 11000300
# Đã ghi dữ liệu thành công cho SBD: 11000301
# Đã ghi dữ liệu thành công cho SBD: 11000302
# Đã ghi dữ liệu thành công cho SBD: 11000303
# Đã ghi dữ liệu thành công cho SBD: 11000304
# Đã ghi dữ liệu thành công cho SBD: 11000305
# Đã ghi dữ liệu thành công cho SBD: 11000306
# Đã ghi dữ liệu thành công cho SBD: 11000307
# Đã ghi dữ liệu thành công cho SBD: 11000308
# Đã ghi dữ liệu thành công cho SBD: 11000309
# Đã ghi dữ liệu thành công cho SBD: 11000310
# Đã ghi dữ liệu thành công cho SBD: 11000311
# Đã ghi dữ liệu thành công cho SBD: 11000312
# Đã ghi dữ liệu thành công cho SBD: 11000313
# Đã ghi dữ liệu thành công cho SBD: 11000314
# Đã ghi dữ liệu thành công cho SBD: 11000315
# Đã ghi dữ liệu thành công cho SBD: 11000316
# Đã ghi dữ liệu thành công cho SBD: 11000317
# Đã ghi dữ liệu thành công cho SBD: 11000318
# Đã ghi dữ liệu thành công cho SBD: 11000319
# Đã ghi dữ liệu thành công cho SBD: 11000320
# Đã ghi dữ liệu thành công cho SBD: 11000321
# Đã ghi dữ liệu thành công cho SBD: 11000322
# Đã ghi dữ liệu thành công cho SBD: 11000323
# Đã ghi dữ liệu thành công cho SBD: 11000324
# Đã ghi dữ liệu thành công cho SBD: 11000325
# Đã ghi dữ liệu thành công cho SBD: 11000326
# Đã ghi dữ liệu thành công cho SBD: 11000327
# Đã ghi dữ liệu thành công cho SBD: 11000328
# Đã ghi dữ liệu thành công cho SBD: 11000329
# Đã ghi dữ liệu thành công cho SBD: 11000330
# Đã ghi dữ liệu thành công cho SBD: 11000331
# Đã ghi dữ liệu thành công cho SBD: 11000332
# Đã ghi dữ liệu thành công cho SBD: 11000333
# Đã ghi dữ liệu thành công cho SBD: 11000334
# Đã ghi dữ liệu thành công cho SBD: 11000335
# Đã ghi dữ liệu thành công cho SBD: 11000336
# Đã ghi dữ liệu thành công cho SBD: 11000337
# Đã ghi dữ liệu thành công cho SBD: 11000338
# Đã ghi dữ liệu thành công cho SBD: 11000339
# Đã ghi dữ liệu thành công cho SBD: 11000340
# Đã ghi dữ liệu thành công cho SBD: 11000341
# Đã ghi dữ liệu thành công cho SBD: 11000342
# Đã ghi dữ liệu thành công cho SBD: 11000343
# Đã ghi dữ liệu thành công cho SBD: 11000344
# Đã ghi dữ liệu thành công cho SBD: 11000345
# Đã ghi dữ liệu thành công cho SBD: 11000346
# Đã ghi dữ liệu thành công cho SBD: 11000347
# Đã ghi dữ liệu thành công cho SBD: 11000348
# Đã ghi dữ liệu thành công cho SBD: 11000349
# Đã ghi dữ liệu thành công cho SBD: 11000350
# Đã ghi dữ liệu thành công cho SBD: 11000351
# Đã ghi dữ liệu thành công cho SBD: 11000352
# Đã ghi dữ liệu thành công cho SBD: 11000353
# Đã ghi dữ liệu thành công cho SBD: 11000354
# Đã ghi dữ liệu thành công cho SBD: 11000355
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000357
# Đã ghi dữ liệu thành công cho SBD: 11000358
# Đã ghi dữ liệu thành công cho SBD: 11000359
# Đã ghi dữ liệu thành công cho SBD: 11000360
# Đã ghi dữ liệu thành công cho SBD: 11000361
# Đã ghi dữ liệu thành công cho SBD: 11000362
# Đã ghi dữ liệu thành công cho SBD: 11000363
# Đã ghi dữ liệu thành công cho SBD: 11000364
# Đã ghi dữ liệu thành công cho SBD: 11000365
# Đã ghi dữ liệu thành công cho SBD: 11000366
# Đã ghi dữ liệu thành công cho SBD: 11000367
# Đã ghi dữ liệu thành công cho SBD: 11000368
# Đã ghi dữ liệu thành công cho SBD: 11000369
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000371
# Đã ghi dữ liệu thành công cho SBD: 11000372
# Đã ghi dữ liệu thành công cho SBD: 11000373
# Đã ghi dữ liệu thành công cho SBD: 11000374
# Đã ghi dữ liệu thành công cho SBD: 11000375
# Đã ghi dữ liệu thành công cho SBD: 11000376
# Đã ghi dữ liệu thành công cho SBD: 11000377
# Đã ghi dữ liệu thành công cho SBD: 11000378
# Đã ghi dữ liệu thành công cho SBD: 11000379
# Đã ghi dữ liệu thành công cho SBD: 11000380
# Đã ghi dữ liệu thành công cho SBD: 11000381
# Đã ghi dữ liệu thành công cho SBD: 11000382
# Đã ghi dữ liệu thành công cho SBD: 11000383
# Đã ghi dữ liệu thành công cho SBD: 11000384
# Đã ghi dữ liệu thành công cho SBD: 11000385
# Đã ghi dữ liệu thành công cho SBD: 11000386
# Đã ghi dữ liệu thành công cho SBD: 11000387
# Đã ghi dữ liệu thành công cho SBD: 11000388
# Đã ghi dữ liệu thành công cho SBD: 11000389
# Đã ghi dữ liệu thành công cho SBD: 11000390
# Đã ghi dữ liệu thành công cho SBD: 11000391
# Đã ghi dữ liệu thành công cho SBD: 11000392
# Đã ghi dữ liệu thành công cho SBD: 11000393
# Đã ghi dữ liệu thành công cho SBD: 11000394
# Đã ghi dữ liệu thành công cho SBD: 11000395
# Đã ghi dữ liệu thành công cho SBD: 11000396
# Đã ghi dữ liệu thành công cho SBD: 11000397
# Đã ghi dữ liệu thành công cho SBD: 11000398
# Đã ghi dữ liệu thành công cho SBD: 11000399
# Đã ghi dữ liệu thành công cho SBD: 11000400
# Đã ghi dữ liệu thành công cho SBD: 11000401
# Đã ghi dữ liệu thành công cho SBD: 11000402
# Đã ghi dữ liệu thành công cho SBD: 11000403
# Đã ghi dữ liệu thành công cho SBD: 11000404
# Đã ghi dữ liệu thành công cho SBD: 11000405
# Đã ghi dữ liệu thành công cho SBD: 11000406
# Đã ghi dữ liệu thành công cho SBD: 11000407
# Đã ghi dữ liệu thành công cho SBD: 11000408
# Đã ghi dữ liệu thành công cho SBD: 11000409
# Đã ghi dữ liệu thành công cho SBD: 11000410
# Đã ghi dữ liệu thành công cho SBD: 11000411
# Đã ghi dữ liệu thành công cho SBD: 11000412
# Đã ghi dữ liệu thành công cho SBD: 11000413
# Đã ghi dữ liệu thành công cho SBD: 11000414
# Đã ghi dữ liệu thành công cho SBD: 11000415
# Đã ghi dữ liệu thành công cho SBD: 11000416
# Đã ghi dữ liệu thành công cho SBD: 11000417
# Đã ghi dữ liệu thành công cho SBD: 11000418
# Đã ghi dữ liệu thành công cho SBD: 11000419
# Đã ghi dữ liệu thành công cho SBD: 11000420
# Đã ghi dữ liệu thành công cho SBD: 11000421
# Đã ghi dữ liệu thành công cho SBD: 11000422
# Đã ghi dữ liệu thành công cho SBD: 11000423
# Đã ghi dữ liệu thành công cho SBD: 11000424
# Đã ghi dữ liệu thành công cho SBD: 11000425
# Đã ghi dữ liệu thành công cho SBD: 11000426
# Đã ghi dữ liệu thành công cho SBD: 11000427
# Đã ghi dữ liệu thành công cho SBD: 11000428
# Đã ghi dữ liệu thành công cho SBD: 11000429
# Đã ghi dữ liệu thành công cho SBD: 11000430
# Đã ghi dữ liệu thành công cho SBD: 11000431
# Đã ghi dữ liệu thành công cho SBD: 11000432
# Đã ghi dữ liệu thành công cho SBD: 11000433
# Đã ghi dữ liệu thành công cho SBD: 11000434
# Đã ghi dữ liệu thành công cho SBD: 11000435
# Đã ghi dữ liệu thành công cho SBD: 11000436
# Đã ghi dữ liệu thành công cho SBD: 11000437
# Đã ghi dữ liệu thành công cho SBD: 11000438
# Đã ghi dữ liệu thành công cho SBD: 11000439
# Đã ghi dữ liệu thành công cho SBD: 11000440
# Đã ghi dữ liệu thành công cho SBD: 11000441
# Đã ghi dữ liệu thành công cho SBD: 11000442
# Đã ghi dữ liệu thành công cho SBD: 11000443
# Đã ghi dữ liệu thành công cho SBD: 11000444
# Đã ghi dữ liệu thành công cho SBD: 11000445
# Đã ghi dữ liệu thành công cho SBD: 11000446
# Đã ghi dữ liệu thành công cho SBD: 11000447
# Đã ghi dữ liệu thành công cho SBD: 11000448
# Đã ghi dữ liệu thành công cho SBD: 11000449
# Đã ghi dữ liệu thành công cho SBD: 11000450
# Đã ghi dữ liệu thành công cho SBD: 11000451
# Đã ghi dữ liệu thành công cho SBD: 11000452
# Đã ghi dữ liệu thành công cho SBD: 11000453
# Đã ghi dữ liệu thành công cho SBD: 11000454
# Đã ghi dữ liệu thành công cho SBD: 11000455
# Đã ghi dữ liệu thành công cho SBD: 11000456
# Đã ghi dữ liệu thành công cho SBD: 11000457
# Đã ghi dữ liệu thành công cho SBD: 11000458
# Đã ghi dữ liệu thành công cho SBD: 11000459
# Đã ghi dữ liệu thành công cho SBD: 11000460
# Đã ghi dữ liệu thành công cho SBD: 11000461
# Đã ghi dữ liệu thành công cho SBD: 11000462
# Đã ghi dữ liệu thành công cho SBD: 11000463
# Đã ghi dữ liệu thành công cho SBD: 11000464
# Đã ghi dữ liệu thành công cho SBD: 11000465
# Đã ghi dữ liệu thành công cho SBD: 11000466
# Đã ghi dữ liệu thành công cho SBD: 11000467
# Đã ghi dữ liệu thành công cho SBD: 11000468
# Đã ghi dữ liệu thành công cho SBD: 11000469
# Đã ghi dữ liệu thành công cho SBD: 11000470
# Đã ghi dữ liệu thành công cho SBD: 11000471
# Đã ghi dữ liệu thành công cho SBD: 11000472
# Đã ghi dữ liệu thành công cho SBD: 11000473
# Đã ghi dữ liệu thành công cho SBD: 11000474
# Đã ghi dữ liệu thành công cho SBD: 11000475
# Đã ghi dữ liệu thành công cho SBD: 11000476
# Đã ghi dữ liệu thành công cho SBD: 11000477
# Đã ghi dữ liệu thành công cho SBD: 11000478
# Đã ghi dữ liệu thành công cho SBD: 11000479
# Đã ghi dữ liệu thành công cho SBD: 11000480
# Đã ghi dữ liệu thành công cho SBD: 11000481
# Đã ghi dữ liệu thành công cho SBD: 11000482
# Đã ghi dữ liệu thành công cho SBD: 11000483
# Đã ghi dữ liệu thành công cho SBD: 11000484
# Đã ghi dữ liệu thành công cho SBD: 11000485
# Đã ghi dữ liệu thành công cho SBD: 11000486
# Đã ghi dữ liệu thành công cho SBD: 11000487
# Đã ghi dữ liệu thành công cho SBD: 11000488
# Đã ghi dữ liệu thành công cho SBD: 11000489
# Đã ghi dữ liệu thành công cho SBD: 11000490
# Đã ghi dữ liệu thành công cho SBD: 11000491
# Đã ghi dữ liệu thành công cho SBD: 11000492
# Đã ghi dữ liệu thành công cho SBD: 11000493
# Đã ghi dữ liệu thành công cho SBD: 11000494
# Đã ghi dữ liệu thành công cho SBD: 11000495
# Đã ghi dữ liệu thành công cho SBD: 11000496
# Đã ghi dữ liệu thành công cho SBD: 11000497
# Đã ghi dữ liệu thành công cho SBD: 11000498
# Đã ghi dữ liệu thành công cho SBD: 11000499
# Đã ghi dữ liệu thành công cho SBD: 11000500
# Đã ghi dữ liệu thành công cho SBD: 11000501
# Đã ghi dữ liệu thành công cho SBD: 11000502
# Đã ghi dữ liệu thành công cho SBD: 11000503
# Đã ghi dữ liệu thành công cho SBD: 11000504
# Đã ghi dữ liệu thành công cho SBD: 11000505
# Đã ghi dữ liệu thành công cho SBD: 11000506
# Đã ghi dữ liệu thành công cho SBD: 11000507
# Đã ghi dữ liệu thành công cho SBD: 11000508
# Đã ghi dữ liệu thành công cho SBD: 11000509
# Đã ghi dữ liệu thành công cho SBD: 11000510
# Đã ghi dữ liệu thành công cho SBD: 11000511
# Đã ghi dữ liệu thành công cho SBD: 11000512
# Đã ghi dữ liệu thành công cho SBD: 11000513
# Đã ghi dữ liệu thành công cho SBD: 11000514
# Đã ghi dữ liệu thành công cho SBD: 11000515
# Đã ghi dữ liệu thành công cho SBD: 11000516
# Đã ghi dữ liệu thành công cho SBD: 11000517
# Đã ghi dữ liệu thành công cho SBD: 11000518
# Đã ghi dữ liệu thành công cho SBD: 11000519
# Đã ghi dữ liệu thành công cho SBD: 11000520
# Đã ghi dữ liệu thành công cho SBD: 11000521
# Đã ghi dữ liệu thành công cho SBD: 11000522
# Đã ghi dữ liệu thành công cho SBD: 11000523
# Đã ghi dữ liệu thành công cho SBD: 11000524
# Đã ghi dữ liệu thành công cho SBD: 11000525
# Đã ghi dữ liệu thành công cho SBD: 11000526
# Đã ghi dữ liệu thành công cho SBD: 11000527
# Đã ghi dữ liệu thành công cho SBD: 11000528
# Đã ghi dữ liệu thành công cho SBD: 11000529
# Đã ghi dữ liệu thành công cho SBD: 11000530
# Đã ghi dữ liệu thành công cho SBD: 11000531
# Đã ghi dữ liệu thành công cho SBD: 11000532
# Đã ghi dữ liệu thành công cho SBD: 11000533
# Đã ghi dữ liệu thành công cho SBD: 11000534
# Đã ghi dữ liệu thành công cho SBD: 11000535
# Đã ghi dữ liệu thành công cho SBD: 11000536
# Đã ghi dữ liệu thành công cho SBD: 11000537
# Đã ghi dữ liệu thành công cho SBD: 11000538
# Đã ghi dữ liệu thành công cho SBD: 11000539
# Đã ghi dữ liệu thành công cho SBD: 11000540
# Đã ghi dữ liệu thành công cho SBD: 11000541
# Đã ghi dữ liệu thành công cho SBD: 11000542
# Đã ghi dữ liệu thành công cho SBD: 11000543
# Đã ghi dữ liệu thành công cho SBD: 11000544
# Đã ghi dữ liệu thành công cho SBD: 11000545
# Đã ghi dữ liệu thành công cho SBD: 11000546
# Đã ghi dữ liệu thành công cho SBD: 11000547
# Đã ghi dữ liệu thành công cho SBD: 11000548
# Đã ghi dữ liệu thành công cho SBD: 11000549
# Đã ghi dữ liệu thành công cho SBD: 11000550
# Đã ghi dữ liệu thành công cho SBD: 11000551
# Đã ghi dữ liệu thành công cho SBD: 11000552
# Đã ghi dữ liệu thành công cho SBD: 11000553
# Đã ghi dữ liệu thành công cho SBD: 11000554
# Đã ghi dữ liệu thành công cho SBD: 11000555
# Đã ghi dữ liệu thành công cho SBD: 11000556
# Đã ghi dữ liệu thành công cho SBD: 11000557
# Đã ghi dữ liệu thành công cho SBD: 11000558
# Đã ghi dữ liệu thành công cho SBD: 11000559
# Đã ghi dữ liệu thành công cho SBD: 11000560
# Đã ghi dữ liệu thành công cho SBD: 11000561
# Đã ghi dữ liệu thành công cho SBD: 11000562
# Đã ghi dữ liệu thành công cho SBD: 11000563
# Đã ghi dữ liệu thành công cho SBD: 11000564
# Đã ghi dữ liệu thành công cho SBD: 11000565
# Đã ghi dữ liệu thành công cho SBD: 11000566
# Đã ghi dữ liệu thành công cho SBD: 11000567
# Đã ghi dữ liệu thành công cho SBD: 11000568
# Đã ghi dữ liệu thành công cho SBD: 11000569
# Đã ghi dữ liệu thành công cho SBD: 11000570
# Đã ghi dữ liệu thành công cho SBD: 11000571
# Đã ghi dữ liệu thành công cho SBD: 11000572
# Đã ghi dữ liệu thành công cho SBD: 11000573
# Đã ghi dữ liệu thành công cho SBD: 11000574
# Đã ghi dữ liệu thành công cho SBD: 11000575
# Đã ghi dữ liệu thành công cho SBD: 11000576
# Đã ghi dữ liệu thành công cho SBD: 11000577
# Đã ghi dữ liệu thành công cho SBD: 11000578
# Đã ghi dữ liệu thành công cho SBD: 11000579
# Đã ghi dữ liệu thành công cho SBD: 11000580
# Đã ghi dữ liệu thành công cho SBD: 11000581
# Đã ghi dữ liệu thành công cho SBD: 11000582
# Đã ghi dữ liệu thành công cho SBD: 11000583
# Đã ghi dữ liệu thành công cho SBD: 11000584
# Đã ghi dữ liệu thành công cho SBD: 11000585
# Đã ghi dữ liệu thành công cho SBD: 11000586
# Đã ghi dữ liệu thành công cho SBD: 11000587
# Đã ghi dữ liệu thành công cho SBD: 11000588
# Đã ghi dữ liệu thành công cho SBD: 11000589
# Đã ghi dữ liệu thành công cho SBD: 11000590
# Đã ghi dữ liệu thành công cho SBD: 11000591
# Đã ghi dữ liệu thành công cho SBD: 11000592
# Đã ghi dữ liệu thành công cho SBD: 11000593
# Đã ghi dữ liệu thành công cho SBD: 11000594
# Đã ghi dữ liệu thành công cho SBD: 11000595
# Đã ghi dữ liệu thành công cho SBD: 11000596
# Đã ghi dữ liệu thành công cho SBD: 11000597
# Đã ghi dữ liệu thành công cho SBD: 11000598
# Đã ghi dữ liệu thành công cho SBD: 11000599
# Đã ghi dữ liệu thành công cho SBD: 11000600
# Đã ghi dữ liệu thành công cho SBD: 11000601
# Đã ghi dữ liệu thành công cho SBD: 11000602
# Đã ghi dữ liệu thành công cho SBD: 11000603
# Đã ghi dữ liệu thành công cho SBD: 11000604
# Đã ghi dữ liệu thành công cho SBD: 11000605
# Đã ghi dữ liệu thành công cho SBD: 11000606
# Đã ghi dữ liệu thành công cho SBD: 11000607
# Đã ghi dữ liệu thành công cho SBD: 11000608
# Đã ghi dữ liệu thành công cho SBD: 11000609
# Đã ghi dữ liệu thành công cho SBD: 11000610
# Đã ghi dữ liệu thành công cho SBD: 11000611
# Đã ghi dữ liệu thành công cho SBD: 11000612
# Đã ghi dữ liệu thành công cho SBD: 11000613
# Đã ghi dữ liệu thành công cho SBD: 11000614
# Đã ghi dữ liệu thành công cho SBD: 11000615
# Đã ghi dữ liệu thành công cho SBD: 11000616
# Đã ghi dữ liệu thành công cho SBD: 11000617
# Đã ghi dữ liệu thành công cho SBD: 11000618
# Đã ghi dữ liệu thành công cho SBD: 11000619
# Đã ghi dữ liệu thành công cho SBD: 11000620
# Đã ghi dữ liệu thành công cho SBD: 11000621
# Đã ghi dữ liệu thành công cho SBD: 11000622
# Đã ghi dữ liệu thành công cho SBD: 11000623
# Đã ghi dữ liệu thành công cho SBD: 11000624
# Đã ghi dữ liệu thành công cho SBD: 11000625
# Đã ghi dữ liệu thành công cho SBD: 11000626
# Đã ghi dữ liệu thành công cho SBD: 11000627
# Đã ghi dữ liệu thành công cho SBD: 11000628
# Đã ghi dữ liệu thành công cho SBD: 11000629
# Đã ghi dữ liệu thành công cho SBD: 11000630
# Đã ghi dữ liệu thành công cho SBD: 11000631
# Đã ghi dữ liệu thành công cho SBD: 11000632
# Đã ghi dữ liệu thành công cho SBD: 11000633
# Đã ghi dữ liệu thành công cho SBD: 11000634
# Đã ghi dữ liệu thành công cho SBD: 11000635
# Đã ghi dữ liệu thành công cho SBD: 11000636
# Đã ghi dữ liệu thành công cho SBD: 11000637
# Đã ghi dữ liệu thành công cho SBD: 11000638
# Đã ghi dữ liệu thành công cho SBD: 11000639
# Đã ghi dữ liệu thành công cho SBD: 11000640
# Đã ghi dữ liệu thành công cho SBD: 11000641
# Đã ghi dữ liệu thành công cho SBD: 11000642
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000644
# Đã ghi dữ liệu thành công cho SBD: 11000645
# Đã ghi dữ liệu thành công cho SBD: 11000646
# Đã ghi dữ liệu thành công cho SBD: 11000647
# Đã ghi dữ liệu thành công cho SBD: 11000648
# Đã ghi dữ liệu thành công cho SBD: 11000649
# Đã ghi dữ liệu thành công cho SBD: 11000650
# Đã ghi dữ liệu thành công cho SBD: 11000651
# Đã ghi dữ liệu thành công cho SBD: 11000652
# Đã ghi dữ liệu thành công cho SBD: 11000653
# Đã ghi dữ liệu thành công cho SBD: 11000654
# Đã ghi dữ liệu thành công cho SBD: 11000655
# Đã ghi dữ liệu thành công cho SBD: 11000656
# Đã ghi dữ liệu thành công cho SBD: 11000657
# Đã ghi dữ liệu thành công cho SBD: 11000658
# Đã ghi dữ liệu thành công cho SBD: 11000659
# Đã ghi dữ liệu thành công cho SBD: 11000660
# Đã ghi dữ liệu thành công cho SBD: 11000661
# Đã ghi dữ liệu thành công cho SBD: 11000662
# Đã ghi dữ liệu thành công cho SBD: 11000663
# Đã ghi dữ liệu thành công cho SBD: 11000664
# Đã ghi dữ liệu thành công cho SBD: 11000665
# Đã ghi dữ liệu thành công cho SBD: 11000666
# Đã ghi dữ liệu thành công cho SBD: 11000667
# Đã ghi dữ liệu thành công cho SBD: 11000668
# Đã ghi dữ liệu thành công cho SBD: 11000669
# Đã ghi dữ liệu thành công cho SBD: 11000670
# Đã ghi dữ liệu thành công cho SBD: 11000671
# Đã ghi dữ liệu thành công cho SBD: 11000672
# Đã ghi dữ liệu thành công cho SBD: 11000673
# Đã ghi dữ liệu thành công cho SBD: 11000674
# Đã ghi dữ liệu thành công cho SBD: 11000675
# Đã ghi dữ liệu thành công cho SBD: 11000676
# Đã ghi dữ liệu thành công cho SBD: 11000677
# Đã ghi dữ liệu thành công cho SBD: 11000678
# Đã ghi dữ liệu thành công cho SBD: 11000679
# Đã ghi dữ liệu thành công cho SBD: 11000680
# Đã ghi dữ liệu thành công cho SBD: 11000681
# Đã ghi dữ liệu thành công cho SBD: 11000682
# Đã ghi dữ liệu thành công cho SBD: 11000683
# Đã ghi dữ liệu thành công cho SBD: 11000684
# Đã ghi dữ liệu thành công cho SBD: 11000685
# Đã ghi dữ liệu thành công cho SBD: 11000686
# Đã ghi dữ liệu thành công cho SBD: 11000687
# Đã ghi dữ liệu thành công cho SBD: 11000688
# Đã ghi dữ liệu thành công cho SBD: 11000689
# Đã ghi dữ liệu thành công cho SBD: 11000690
# Đã ghi dữ liệu thành công cho SBD: 11000691
# Đã ghi dữ liệu thành công cho SBD: 11000692
# Đã ghi dữ liệu thành công cho SBD: 11000693
# Đã ghi dữ liệu thành công cho SBD: 11000694
# Đã ghi dữ liệu thành công cho SBD: 11000695
# Đã ghi dữ liệu thành công cho SBD: 11000696
# Đã ghi dữ liệu thành công cho SBD: 11000697
# Đã ghi dữ liệu thành công cho SBD: 11000698
# Đã ghi dữ liệu thành công cho SBD: 11000699
# Đã ghi dữ liệu thành công cho SBD: 11000700
# Đã ghi dữ liệu thành công cho SBD: 11000701
# Đã ghi dữ liệu thành công cho SBD: 11000702
# Đã ghi dữ liệu thành công cho SBD: 11000703
# Đã ghi dữ liệu thành công cho SBD: 11000704
# Đã ghi dữ liệu thành công cho SBD: 11000705
# Đã ghi dữ liệu thành công cho SBD: 11000706
# Đã ghi dữ liệu thành công cho SBD: 11000707
# Đã ghi dữ liệu thành công cho SBD: 11000708
# Đã ghi dữ liệu thành công cho SBD: 11000709
# Đã ghi dữ liệu thành công cho SBD: 11000710
# Đã ghi dữ liệu thành công cho SBD: 11000711
# Đã ghi dữ liệu thành công cho SBD: 11000712
# Đã ghi dữ liệu thành công cho SBD: 11000713
# Đã ghi dữ liệu thành công cho SBD: 11000714
# Đã ghi dữ liệu thành công cho SBD: 11000715
# Đã ghi dữ liệu thành công cho SBD: 11000716
# Đã ghi dữ liệu thành công cho SBD: 11000717
# Đã ghi dữ liệu thành công cho SBD: 11000718
# Đã ghi dữ liệu thành công cho SBD: 11000719
# Đã ghi dữ liệu thành công cho SBD: 11000720
# Đã ghi dữ liệu thành công cho SBD: 11000721
# Đã ghi dữ liệu thành công cho SBD: 11000722
# Đã ghi dữ liệu thành công cho SBD: 11000723
# Đã ghi dữ liệu thành công cho SBD: 11000724
# Đã ghi dữ liệu thành công cho SBD: 11000725
# Đã ghi dữ liệu thành công cho SBD: 11000726
# Đã ghi dữ liệu thành công cho SBD: 11000727
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000729
# Đã ghi dữ liệu thành công cho SBD: 11000730
# Đã ghi dữ liệu thành công cho SBD: 11000731
# Đã ghi dữ liệu thành công cho SBD: 11000732
# Đã ghi dữ liệu thành công cho SBD: 11000733
# Đã ghi dữ liệu thành công cho SBD: 11000734
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000736
# Đã ghi dữ liệu thành công cho SBD: 11000737
# Đã ghi dữ liệu thành công cho SBD: 11000738
# Đã ghi dữ liệu thành công cho SBD: 11000739
# Đã ghi dữ liệu thành công cho SBD: 11000740
# Đã ghi dữ liệu thành công cho SBD: 11000741
# Đã ghi dữ liệu thành công cho SBD: 11000742
# Đã ghi dữ liệu thành công cho SBD: 11000743
# Đã ghi dữ liệu thành công cho SBD: 11000744
# Đã ghi dữ liệu thành công cho SBD: 11000745
# Đã ghi dữ liệu thành công cho SBD: 11000746
# Đã ghi dữ liệu thành công cho SBD: 11000747
# Đã ghi dữ liệu thành công cho SBD: 11000748
# Đã ghi dữ liệu thành công cho SBD: 11000749
# Đã ghi dữ liệu thành công cho SBD: 11000750
# Đã ghi dữ liệu thành công cho SBD: 11000751
# Đã ghi dữ liệu thành công cho SBD: 11000752
# Đã ghi dữ liệu thành công cho SBD: 11000753
# Đã ghi dữ liệu thành công cho SBD: 11000754
# Đã ghi dữ liệu thành công cho SBD: 11000755
# Đã ghi dữ liệu thành công cho SBD: 11000756
# Đã ghi dữ liệu thành công cho SBD: 11000757
# Đã ghi dữ liệu thành công cho SBD: 11000758
# Đã ghi dữ liệu thành công cho SBD: 11000759
# Đã ghi dữ liệu thành công cho SBD: 11000760
# Đã ghi dữ liệu thành công cho SBD: 11000761
# Đã ghi dữ liệu thành công cho SBD: 11000762
# Đã ghi dữ liệu thành công cho SBD: 11000763
# Đã ghi dữ liệu thành công cho SBD: 11000764
# Đã ghi dữ liệu thành công cho SBD: 11000765
# Đã ghi dữ liệu thành công cho SBD: 11000766
# Đã ghi dữ liệu thành công cho SBD: 11000767
# Đã ghi dữ liệu thành công cho SBD: 11000768
# Đã ghi dữ liệu thành công cho SBD: 11000769
# Đã ghi dữ liệu thành công cho SBD: 11000770
# Đã ghi dữ liệu thành công cho SBD: 11000771
# Đã ghi dữ liệu thành công cho SBD: 11000772
# Đã ghi dữ liệu thành công cho SBD: 11000773
# Đã ghi dữ liệu thành công cho SBD: 11000774
# Đã ghi dữ liệu thành công cho SBD: 11000775
# Đã ghi dữ liệu thành công cho SBD: 11000776
# Đã ghi dữ liệu thành công cho SBD: 11000777
# Đã ghi dữ liệu thành công cho SBD: 11000778
# Đã ghi dữ liệu thành công cho SBD: 11000779
# Đã ghi dữ liệu thành công cho SBD: 11000780
# Đã ghi dữ liệu thành công cho SBD: 11000781
# Đã ghi dữ liệu thành công cho SBD: 11000782
# Đã ghi dữ liệu thành công cho SBD: 11000783
# Đã ghi dữ liệu thành công cho SBD: 11000784
# Đã ghi dữ liệu thành công cho SBD: 11000785
# Đã ghi dữ liệu thành công cho SBD: 11000786
# Đã ghi dữ liệu thành công cho SBD: 11000787
# Đã ghi dữ liệu thành công cho SBD: 11000788
# Đã ghi dữ liệu thành công cho SBD: 11000789
# Đã ghi dữ liệu thành công cho SBD: 11000790
# Đã ghi dữ liệu thành công cho SBD: 11000791
# Đã ghi dữ liệu thành công cho SBD: 11000792
# Đã ghi dữ liệu thành công cho SBD: 11000793
# Đã ghi dữ liệu thành công cho SBD: 11000794
# Đã ghi dữ liệu thành công cho SBD: 11000795
# Đã ghi dữ liệu thành công cho SBD: 11000796
# Đã ghi dữ liệu thành công cho SBD: 11000797
# Đã ghi dữ liệu thành công cho SBD: 11000798
# Đã ghi dữ liệu thành công cho SBD: 11000799
# Đã ghi dữ liệu thành công cho SBD: 11000800
# Đã ghi dữ liệu thành công cho SBD: 11000801
# Đã ghi dữ liệu thành công cho SBD: 11000802
# Đã ghi dữ liệu thành công cho SBD: 11000803
# Đã ghi dữ liệu thành công cho SBD: 11000804
# Đã ghi dữ liệu thành công cho SBD: 11000805
# Đã ghi dữ liệu thành công cho SBD: 11000806
# Đã ghi dữ liệu thành công cho SBD: 11000807
# Đã ghi dữ liệu thành công cho SBD: 11000808
# Đã ghi dữ liệu thành công cho SBD: 11000809
# Đã ghi dữ liệu thành công cho SBD: 11000810
# Đã ghi dữ liệu thành công cho SBD: 11000811
# Đã ghi dữ liệu thành công cho SBD: 11000812
# Đã ghi dữ liệu thành công cho SBD: 11000813
# Đã ghi dữ liệu thành công cho SBD: 11000814
# Đã ghi dữ liệu thành công cho SBD: 11000815
# Đã ghi dữ liệu thành công cho SBD: 11000816
# Đã ghi dữ liệu thành công cho SBD: 11000817
# Đã ghi dữ liệu thành công cho SBD: 11000818
# Đã ghi dữ liệu thành công cho SBD: 11000819
# Đã ghi dữ liệu thành công cho SBD: 11000820
# Đã ghi dữ liệu thành công cho SBD: 11000821
# Đã ghi dữ liệu thành công cho SBD: 11000822
# Đã ghi dữ liệu thành công cho SBD: 11000823
# Đã ghi dữ liệu thành công cho SBD: 11000824
# Đã ghi dữ liệu thành công cho SBD: 11000825
# Đã ghi dữ liệu thành công cho SBD: 11000826
# Đã ghi dữ liệu thành công cho SBD: 11000827
# Đã ghi dữ liệu thành công cho SBD: 11000828
# Đã ghi dữ liệu thành công cho SBD: 11000829
# Đã ghi dữ liệu thành công cho SBD: 11000830
# Đã ghi dữ liệu thành công cho SBD: 11000831
# Đã ghi dữ liệu thành công cho SBD: 11000832
# Đã ghi dữ liệu thành công cho SBD: 11000833
# Đã ghi dữ liệu thành công cho SBD: 11000834
# Đã ghi dữ liệu thành công cho SBD: 11000835
# Đã ghi dữ liệu thành công cho SBD: 11000836
# Đã ghi dữ liệu thành công cho SBD: 11000837
# Đã ghi dữ liệu thành công cho SBD: 11000838
# Đã ghi dữ liệu thành công cho SBD: 11000839
# Đã ghi dữ liệu thành công cho SBD: 11000840
# Đã ghi dữ liệu thành công cho SBD: 11000841
# Đã ghi dữ liệu thành công cho SBD: 11000842
# Đã ghi dữ liệu thành công cho SBD: 11000843
# Đã ghi dữ liệu thành công cho SBD: 11000844
# Đã ghi dữ liệu thành công cho SBD: 11000845
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000847
# Đã ghi dữ liệu thành công cho SBD: 11000848
# Đã ghi dữ liệu thành công cho SBD: 11000849
# Đã ghi dữ liệu thành công cho SBD: 11000850
# Đã ghi dữ liệu thành công cho SBD: 11000851
# Đã ghi dữ liệu thành công cho SBD: 11000852
# Đã ghi dữ liệu thành công cho SBD: 11000853
# Đã ghi dữ liệu thành công cho SBD: 11000854
# Đã ghi dữ liệu thành công cho SBD: 11000855
# Đã ghi dữ liệu thành công cho SBD: 11000856
# Đã ghi dữ liệu thành công cho SBD: 11000857
# Đã ghi dữ liệu thành công cho SBD: 11000858
# Đã ghi dữ liệu thành công cho SBD: 11000859
# Đã ghi dữ liệu thành công cho SBD: 11000860
# Đã ghi dữ liệu thành công cho SBD: 11000861
# Đã ghi dữ liệu thành công cho SBD: 11000862
# Đã ghi dữ liệu thành công cho SBD: 11000863
# Đã ghi dữ liệu thành công cho SBD: 11000864
# Đã ghi dữ liệu thành công cho SBD: 11000865
# Đã ghi dữ liệu thành công cho SBD: 11000866
# Đã ghi dữ liệu thành công cho SBD: 11000867
# Đã ghi dữ liệu thành công cho SBD: 11000868
# Đã ghi dữ liệu thành công cho SBD: 11000869
# Đã ghi dữ liệu thành công cho SBD: 11000870
# Đã ghi dữ liệu thành công cho SBD: 11000871
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000873
# Đã ghi dữ liệu thành công cho SBD: 11000874
# Đã ghi dữ liệu thành công cho SBD: 11000875
# Đã ghi dữ liệu thành công cho SBD: 11000876
# Đã ghi dữ liệu thành công cho SBD: 11000877
# Đã ghi dữ liệu thành công cho SBD: 11000878
# Đã ghi dữ liệu thành công cho SBD: 11000879
# Đã ghi dữ liệu thành công cho SBD: 11000880
# Đã ghi dữ liệu thành công cho SBD: 11000881
# Đã ghi dữ liệu thành công cho SBD: 11000882
# Đã ghi dữ liệu thành công cho SBD: 11000883
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000885
# Đã ghi dữ liệu thành công cho SBD: 11000886
# Đã ghi dữ liệu thành công cho SBD: 11000887
# Đã ghi dữ liệu thành công cho SBD: 11000888
# Đã ghi dữ liệu thành công cho SBD: 11000889
# Đã ghi dữ liệu thành công cho SBD: 11000890
# Đã ghi dữ liệu thành công cho SBD: 11000891
# Đã ghi dữ liệu thành công cho SBD: 11000892
# Đã ghi dữ liệu thành công cho SBD: 11000893
# Đã ghi dữ liệu thành công cho SBD: 11000894
# Đã ghi dữ liệu thành công cho SBD: 11000895
# Đã ghi dữ liệu thành công cho SBD: 11000896
# Đã ghi dữ liệu thành công cho SBD: 11000897
# Đã ghi dữ liệu thành công cho SBD: 11000898
# Đã ghi dữ liệu thành công cho SBD: 11000899
# Đã ghi dữ liệu thành công cho SBD: 11000900
# Đã ghi dữ liệu thành công cho SBD: 11000901
# Đã ghi dữ liệu thành công cho SBD: 11000902
# Đã ghi dữ liệu thành công cho SBD: 11000903
# Đã ghi dữ liệu thành công cho SBD: 11000904
# Đã ghi dữ liệu thành công cho SBD: 11000905
# Đã ghi dữ liệu thành công cho SBD: 11000906
# Đã ghi dữ liệu thành công cho SBD: 11000907
# Đã ghi dữ liệu thành công cho SBD: 11000908
# Đã ghi dữ liệu thành công cho SBD: 11000909
# Đã ghi dữ liệu thành công cho SBD: 11000910
# Đã ghi dữ liệu thành công cho SBD: 11000911
# Đã ghi dữ liệu thành công cho SBD: 11000912
# Đã ghi dữ liệu thành công cho SBD: 11000913
# Đã ghi dữ liệu thành công cho SBD: 11000914
# Đã ghi dữ liệu thành công cho SBD: 11000915
# Đã ghi dữ liệu thành công cho SBD: 11000916
# Đã ghi dữ liệu thành công cho SBD: 11000917
# Đã ghi dữ liệu thành công cho SBD: 11000918
# Đã ghi dữ liệu thành công cho SBD: 11000919
# Đã ghi dữ liệu thành công cho SBD: 11000920
# Đã ghi dữ liệu thành công cho SBD: 11000921
# Đã ghi dữ liệu thành công cho SBD: 11000922
# Đã ghi dữ liệu thành công cho SBD: 11000923
# Đã ghi dữ liệu thành công cho SBD: 11000924
# Đã ghi dữ liệu thành công cho SBD: 11000925
# Đã ghi dữ liệu thành công cho SBD: 11000926
# Đã ghi dữ liệu thành công cho SBD: 11000927
# Đã ghi dữ liệu thành công cho SBD: 11000928
# Đã ghi dữ liệu thành công cho SBD: 11000929
# Đã ghi dữ liệu thành công cho SBD: 11000930
# Đã ghi dữ liệu thành công cho SBD: 11000931
# Đã ghi dữ liệu thành công cho SBD: 11000932
# Đã ghi dữ liệu thành công cho SBD: 11000933
# Đã ghi dữ liệu thành công cho SBD: 11000934
# Đã ghi dữ liệu thành công cho SBD: 11000935
# Đã ghi dữ liệu thành công cho SBD: 11000936
# Đã ghi dữ liệu thành công cho SBD: 11000937
# Đã ghi dữ liệu thành công cho SBD: 11000938
# Đã ghi dữ liệu thành công cho SBD: 11000939
# Đã ghi dữ liệu thành công cho SBD: 11000940
# Đã ghi dữ liệu thành công cho SBD: 11000941
# Đã ghi dữ liệu thành công cho SBD: 11000942
# Đã ghi dữ liệu thành công cho SBD: 11000943
# Đã ghi dữ liệu thành công cho SBD: 11000944
# Đã ghi dữ liệu thành công cho SBD: 11000945
# Đã ghi dữ liệu thành công cho SBD: 11000946
# Đã ghi dữ liệu thành công cho SBD: 11000947
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000949
# Đã ghi dữ liệu thành công cho SBD: 11000950
# Đã ghi dữ liệu thành công cho SBD: 11000951
# Đã ghi dữ liệu thành công cho SBD: 11000952
# Đã ghi dữ liệu thành công cho SBD: 11000953
# Đã ghi dữ liệu thành công cho SBD: 11000954
# Đã ghi dữ liệu thành công cho SBD: 11000955
# Đã ghi dữ liệu thành công cho SBD: 11000956
# Đã ghi dữ liệu thành công cho SBD: 11000957
# Đã ghi dữ liệu thành công cho SBD: 11000958
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11000960
# Đã ghi dữ liệu thành công cho SBD: 11000961
# Đã ghi dữ liệu thành công cho SBD: 11000962
# Đã ghi dữ liệu thành công cho SBD: 11000963
# Đã ghi dữ liệu thành công cho SBD: 11000964
# Đã ghi dữ liệu thành công cho SBD: 11000965
# Đã ghi dữ liệu thành công cho SBD: 11000966
# Đã ghi dữ liệu thành công cho SBD: 11000967
# Đã ghi dữ liệu thành công cho SBD: 11000968
# Đã ghi dữ liệu thành công cho SBD: 11000969
# Đã ghi dữ liệu thành công cho SBD: 11000970
# Đã ghi dữ liệu thành công cho SBD: 11000971
# Đã ghi dữ liệu thành công cho SBD: 11000972
# Đã ghi dữ liệu thành công cho SBD: 11000973
# Đã ghi dữ liệu thành công cho SBD: 11000974
# Đã ghi dữ liệu thành công cho SBD: 11000975
# Đã ghi dữ liệu thành công cho SBD: 11000976
# Đã ghi dữ liệu thành công cho SBD: 11000977
# Đã ghi dữ liệu thành công cho SBD: 11000978
# Đã ghi dữ liệu thành công cho SBD: 11000979
# Đã ghi dữ liệu thành công cho SBD: 11000980
# Đã ghi dữ liệu thành công cho SBD: 11000981
# Đã ghi dữ liệu thành công cho SBD: 11000982
# Đã ghi dữ liệu thành công cho SBD: 11000983
# Đã ghi dữ liệu thành công cho SBD: 11000984
# Đã ghi dữ liệu thành công cho SBD: 11000985
# Đã ghi dữ liệu thành công cho SBD: 11000986
# Đã ghi dữ liệu thành công cho SBD: 11000987
# Đã ghi dữ liệu thành công cho SBD: 11000988
# Đã ghi dữ liệu thành công cho SBD: 11000989
# Đã ghi dữ liệu thành công cho SBD: 11000990
# Đã ghi dữ liệu thành công cho SBD: 11000991
# Đã ghi dữ liệu thành công cho SBD: 11000992
# Đã ghi dữ liệu thành công cho SBD: 11000993
# Đã ghi dữ liệu thành công cho SBD: 11000994
# Đã ghi dữ liệu thành công cho SBD: 11000995
# Đã ghi dữ liệu thành công cho SBD: 11000996
# Đã ghi dữ liệu thành công cho SBD: 11000997
# Đã ghi dữ liệu thành công cho SBD: 11000998
# Đã ghi dữ liệu thành công cho SBD: 11000999
# Đã ghi dữ liệu thành công cho SBD: 11001000
# Đã ghi dữ liệu thành công cho SBD: 11001001
# Đã ghi dữ liệu thành công cho SBD: 11001002
# Đã ghi dữ liệu thành công cho SBD: 11001003
# Đã ghi dữ liệu thành công cho SBD: 11001004
# Đã ghi dữ liệu thành công cho SBD: 11001005
# Đã ghi dữ liệu thành công cho SBD: 11001006
# Đã ghi dữ liệu thành công cho SBD: 11001007
# Đã ghi dữ liệu thành công cho SBD: 11001008
# Đã ghi dữ liệu thành công cho SBD: 11001009
# Đã ghi dữ liệu thành công cho SBD: 11001010
# Đã ghi dữ liệu thành công cho SBD: 11001011
# Đã ghi dữ liệu thành công cho SBD: 11001012
# Đã ghi dữ liệu thành công cho SBD: 11001013
# Đã ghi dữ liệu thành công cho SBD: 11001014
# Đã ghi dữ liệu thành công cho SBD: 11001015
# Đã ghi dữ liệu thành công cho SBD: 11001016
# Đã ghi dữ liệu thành công cho SBD: 11001017
# Đã ghi dữ liệu thành công cho SBD: 11001018
# Đã ghi dữ liệu thành công cho SBD: 11001019
# Đã ghi dữ liệu thành công cho SBD: 11001020
# Đã ghi dữ liệu thành công cho SBD: 11001021
# Đã ghi dữ liệu thành công cho SBD: 11001022
# Đã ghi dữ liệu thành công cho SBD: 11001023
# Đã ghi dữ liệu thành công cho SBD: 11001024
# Đã ghi dữ liệu thành công cho SBD: 11001025
# Đã ghi dữ liệu thành công cho SBD: 11001026
# Đã ghi dữ liệu thành công cho SBD: 11001027
# Đã ghi dữ liệu thành công cho SBD: 11001028
# Đã ghi dữ liệu thành công cho SBD: 11001029
# Đã ghi dữ liệu thành công cho SBD: 11001030
# Đã ghi dữ liệu thành công cho SBD: 11001031
# Đã ghi dữ liệu thành công cho SBD: 11001032
# Đã ghi dữ liệu thành công cho SBD: 11001033
# Đã ghi dữ liệu thành công cho SBD: 11001034
# Đã ghi dữ liệu thành công cho SBD: 11001035
# Đã ghi dữ liệu thành công cho SBD: 11001036
# Đã ghi dữ liệu thành công cho SBD: 11001037
# Đã ghi dữ liệu thành công cho SBD: 11001038
# Đã ghi dữ liệu thành công cho SBD: 11001039
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 11001041
# Đã ghi dữ liệu thành công cho SBD: 11001042
# Đã ghi dữ liệu thành công cho SBD: 11001043
# Đã ghi dữ liệu thành công cho SBD: 11001044
# Đã ghi dữ liệu thành công cho SBD: 11001045
# Đã ghi dữ liệu thành công cho SBD: 11001046
# Đã ghi dữ liệu thành công cho SBD: 11001047
# Đã ghi dữ liệu thành công cho SBD: 11001048
# Đã ghi dữ liệu thành công cho SBD: 11001049
# Đã ghi dữ liệu thành công cho SBD: 11001050
# Đã ghi dữ liệu thành công cho SBD: 11001051
# Đã ghi dữ liệu thành công cho SBD: 11001052
# Đã ghi dữ liệu thành công cho SBD: 11001053
# Đã ghi dữ liệu thành công cho SBD: 11001054
# Đã ghi dữ liệu thành công cho SBD: 11001055
# Đã ghi dữ liệu thành công cho SBD: 11001056
# Đã ghi dữ liệu thành công cho SBD: 11001057
# Đã ghi dữ liệu thành công cho SBD: 11001058
# Đã ghi dữ liệu thành công cho SBD: 11001059
# Đã ghi dữ liệu thành công cho SBD: 11001060
# Đã ghi dữ liệu thành công cho SBD: 11001061
# Đã ghi dữ liệu thành công cho SBD: 11001062
# Đã ghi dữ liệu thành công cho SBD: 11001063
# Đã ghi dữ liệu thành công cho SBD: 11001064
# Đã ghi dữ liệu thành công cho SBD: 11001065
# Đã ghi dữ liệu thành công cho SBD: 11001066
# Đã ghi dữ liệu thành công cho SBD: 11001067
# Đã ghi dữ liệu thành công cho SBD: 11001068
# Đã ghi dữ liệu thành công cho SBD: 11001069
# Đã ghi dữ liệu thành công cho SBD: 11001070
# Đã ghi dữ liệu thành công cho SBD: 11001071
# Đã ghi dữ liệu thành công cho SBD: 11001072
# Đã ghi dữ liệu thành công cho SBD: 11001073
# Đã ghi dữ liệu thành công cho SBD: 11001074
# Đã ghi dữ liệu thành công cho SBD: 11001075
# Đã ghi dữ liệu thành công cho SBD: 11001076
# Đã ghi dữ liệu thành công cho SBD: 11001077
# Đã ghi dữ liệu thành công cho SBD: 11001078
# Đã ghi dữ liệu thành công cho SBD: 11001079
# Đã ghi dữ liệu thành công cho SBD: 11001080
# Đã ghi dữ liệu thành công cho SBD: 11001081
# Đã ghi dữ liệu thành công cho SBD: 11001082
# Đã ghi dữ liệu thành công cho SBD: 11001083
# Đã ghi dữ liệu thành công cho SBD: 11001084
# Đã ghi dữ liệu thành công cho SBD: 11001085
# Đã ghi dữ liệu thành công cho SBD: 11001086
# Đã ghi dữ liệu thành công cho SBD: 11001087
# Đã ghi dữ liệu thành công cho SBD: 11001088
# Đã ghi dữ liệu thành công cho SBD: 11001089
# Đã ghi dữ liệu thành công cho SBD: 11001090
# Đã ghi dữ liệu thành công cho SBD: 11001091
# Đã ghi dữ liệu thành công cho SBD: 11001092
# ...
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 66
#      63     print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
#      65 # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
# ---> 66 time.sleep(0.4)
#
# KeyboardInterrupt:

# %%
import requests
import time
import csv

# Đường dẫn đến file CSV
file_path = r"E:\\DA\\Crawl\\HaGiang_05.csv"

# Mở file CSV để ghi dữ liệu
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Ghi tiêu đề cột
    writer.writerow([
        'SBD', 'Toan', 'Van', 'NgoaiNgu', 'VatLy', 'HoaHoc', 'SinhHoc',
        'TBKHTN', 'LichSu', 'DiaLy', 'GDCD', 'TBKHXH'
    ])
    
    # Vòng lặp lấy dữ liệu
    for x in range(5000001, 6000001):
        scraping_url = f"https://dantri.com.vn/thpt/1/0/99/{x}/2024/0.2/search-gradle.htm"
        
        try:
            # Gửi yêu cầu
            response = requests.get(scraping_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            
            # Phân tích phản hồi JSON
            data = response.json()
            
            # Kiểm tra nếu có khóa 'student' trong phản hồi
            if 'student' in data:
                info = data['student']
                
                # Ghi dữ liệu vào file CSV
                writer.writerow([
                    info.get('sbd', 'None'),
                    info.get('toan', 'None'),
                    info.get('van', 'None'),
                    info.get('ngoaiNgu', 'None'),
                    info.get('vatLy', 'None'),
                    info.get('hoaHoc', 'None'),
                    info.get('sinhHoc', 'None'),
                    info.get('diemTBTuNhien', 'None'),
                    info.get('lichSu', 'None'),
                    info.get('diaLy', 'None'),
                    info.get('gdcd', 'None'),
                    info.get('diemTBXaHoi', 'None')
                ])
                
                # Hiển thị thông báo đã ghi dữ liệu thành công
                print(f"Đã ghi dữ liệu thành công cho SBD: {info.get('sbd', 'Unknown')}")

                # Đảm bảo dữ liệu được ghi vào tệp ngay lập tức
                file.flush()
            else:
                print(f"Không có khóa 'student' trong phản hồi cho URL: {scraping_url}")
            
        except requests.RequestException as e:
            print(f"Yêu cầu không thành công cho URL {scraping_url}: {e}")
        except ValueError as e:
            print(f"Lỗi khi phân tích cú pháp JSON cho URL {scraping_url}: {e}")
        except csv.Error as e:
            print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
        
        # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
        time.sleep(0.4)
# Out:
# Đã ghi dữ liệu thành công cho SBD: 05000001
# Đã ghi dữ liệu thành công cho SBD: 05000002
# Đã ghi dữ liệu thành công cho SBD: 05000003
# Đã ghi dữ liệu thành công cho SBD: 05000004
# Đã ghi dữ liệu thành công cho SBD: 05000005
# Đã ghi dữ liệu thành công cho SBD: 05000006
# Đã ghi dữ liệu thành công cho SBD: 05000007
# Đã ghi dữ liệu thành công cho SBD: 05000008
# Đã ghi dữ liệu thành công cho SBD: 05000009
# Đã ghi dữ liệu thành công cho SBD: 05000010
# Đã ghi dữ liệu thành công cho SBD: 05000011
# Đã ghi dữ liệu thành công cho SBD: 05000012
# Đã ghi dữ liệu thành công cho SBD: 05000013
# Đã ghi dữ liệu thành công cho SBD: 05000014
# Đã ghi dữ liệu thành công cho SBD: 05000015
# Đã ghi dữ liệu thành công cho SBD: 05000016
# Đã ghi dữ liệu thành công cho SBD: 05000017
# Đã ghi dữ liệu thành công cho SBD: 05000018
# Đã ghi dữ liệu thành công cho SBD: 05000019
# Đã ghi dữ liệu thành công cho SBD: 05000020
# Đã ghi dữ liệu thành công cho SBD: 05000021
# Đã ghi dữ liệu thành công cho SBD: 05000022
# Đã ghi dữ liệu thành công cho SBD: 05000023
# Đã ghi dữ liệu thành công cho SBD: 05000024
# Đã ghi dữ liệu thành công cho SBD: 05000025
# Đã ghi dữ liệu thành công cho SBD: 05000026
# Đã ghi dữ liệu thành công cho SBD: 05000027
# Đã ghi dữ liệu thành công cho SBD: 05000028
# Đã ghi dữ liệu thành công cho SBD: 05000029
# Đã ghi dữ liệu thành công cho SBD: 05000030
# Đã ghi dữ liệu thành công cho SBD: 05000031
# Đã ghi dữ liệu thành công cho SBD: 05000032
# Đã ghi dữ liệu thành công cho SBD: 05000033
# Đã ghi dữ liệu thành công cho SBD: 05000034
# Đã ghi dữ liệu thành công cho SBD: 05000035
# Đã ghi dữ liệu thành công cho SBD: 05000036
# Đã ghi dữ liệu thành công cho SBD: 05000037
# Đã ghi dữ liệu thành công cho SBD: 05000038
# Đã ghi dữ liệu thành công cho SBD: 05000039
# Đã ghi dữ liệu thành công cho SBD: 05000040
# Đã ghi dữ liệu thành công cho SBD: 05000041
# Đã ghi dữ liệu thành công cho SBD: 05000042
# Đã ghi dữ liệu thành công cho SBD: 05000043
# Đã ghi dữ liệu thành công cho SBD: 05000044
# Đã ghi dữ liệu thành công cho SBD: 05000045
# Đã ghi dữ liệu thành công cho SBD: 05000046
# Đã ghi dữ liệu thành công cho SBD: 05000047
# Đã ghi dữ liệu thành công cho SBD: 05000048
# Đã ghi dữ liệu thành công cho SBD: 05000049
# Đã ghi dữ liệu thành công cho SBD: 05000050
# Đã ghi dữ liệu thành công cho SBD: 05000051
# Đã ghi dữ liệu thành công cho SBD: 05000052
# Đã ghi dữ liệu thành công cho SBD: 05000053
# Đã ghi dữ liệu thành công cho SBD: 05000054
# Đã ghi dữ liệu thành công cho SBD: 05000055
# Đã ghi dữ liệu thành công cho SBD: 05000056
# Đã ghi dữ liệu thành công cho SBD: 05000057
# Đã ghi dữ liệu thành công cho SBD: 05000058
# Đã ghi dữ liệu thành công cho SBD: 05000059
# Đã ghi dữ liệu thành công cho SBD: 05000060
# Đã ghi dữ liệu thành công cho SBD: 05000061
# Đã ghi dữ liệu thành công cho SBD: 05000062
# Đã ghi dữ liệu thành công cho SBD: 05000063
# Đã ghi dữ liệu thành công cho SBD: 05000064
# Đã ghi dữ liệu thành công cho SBD: 05000065
# Đã ghi dữ liệu thành công cho SBD: 05000066
# Đã ghi dữ liệu thành công cho SBD: 05000067
# Đã ghi dữ liệu thành công cho SBD: 05000068
# Đã ghi dữ liệu thành công cho SBD: 05000069
# Đã ghi dữ liệu thành công cho SBD: 05000070
# Đã ghi dữ liệu thành công cho SBD: 05000071
# Đã ghi dữ liệu thành công cho SBD: 05000072
# Đã ghi dữ liệu thành công cho SBD: 05000073
# Đã ghi dữ liệu thành công cho SBD: 05000074
# Đã ghi dữ liệu thành công cho SBD: 05000075
# Đã ghi dữ liệu thành công cho SBD: 05000076
# Đã ghi dữ liệu thành công cho SBD: 05000077
# Đã ghi dữ liệu thành công cho SBD: 05000078
# Đã ghi dữ liệu thành công cho SBD: 05000079
# Đã ghi dữ liệu thành công cho SBD: 05000080
# Đã ghi dữ liệu thành công cho SBD: 05000081
# Đã ghi dữ liệu thành công cho SBD: 05000082
# Đã ghi dữ liệu thành công cho SBD: 05000083
# Đã ghi dữ liệu thành công cho SBD: 05000084
# Đã ghi dữ liệu thành công cho SBD: 05000085
# Đã ghi dữ liệu thành công cho SBD: 05000086
# Đã ghi dữ liệu thành công cho SBD: 05000087
# Đã ghi dữ liệu thành công cho SBD: 05000088
# Đã ghi dữ liệu thành công cho SBD: 05000089
# Đã ghi dữ liệu thành công cho SBD: 05000090
# Đã ghi dữ liệu thành công cho SBD: 05000091
# Đã ghi dữ liệu thành công cho SBD: 05000092
# Đã ghi dữ liệu thành công cho SBD: 05000093
# Đã ghi dữ liệu thành công cho SBD: 05000094
# Đã ghi dữ liệu thành công cho SBD: 05000095
# Đã ghi dữ liệu thành công cho SBD: 05000096
# Đã ghi dữ liệu thành công cho SBD: 05000097
# Đã ghi dữ liệu thành công cho SBD: 05000098
# Đã ghi dữ liệu thành công cho SBD: 05000099
# Đã ghi dữ liệu thành công cho SBD: 05000100
# Đã ghi dữ liệu thành công cho SBD: 05000101
# Đã ghi dữ liệu thành công cho SBD: 05000102
# Đã ghi dữ liệu thành công cho SBD: 05000103
# Đã ghi dữ liệu thành công cho SBD: 05000104
# Đã ghi dữ liệu thành công cho SBD: 05000105
# Đã ghi dữ liệu thành công cho SBD: 05000106
# Đã ghi dữ liệu thành công cho SBD: 05000107
# Đã ghi dữ liệu thành công cho SBD: 05000108
# Đã ghi dữ liệu thành công cho SBD: 05000109
# Đã ghi dữ liệu thành công cho SBD: 05000110
# Đã ghi dữ liệu thành công cho SBD: 05000111
# Đã ghi dữ liệu thành công cho SBD: 05000112
# Đã ghi dữ liệu thành công cho SBD: 05000113
# Đã ghi dữ liệu thành công cho SBD: 05000114
# Đã ghi dữ liệu thành công cho SBD: 05000115
# Đã ghi dữ liệu thành công cho SBD: 05000116
# Đã ghi dữ liệu thành công cho SBD: 05000117
# Đã ghi dữ liệu thành công cho SBD: 05000118
# Đã ghi dữ liệu thành công cho SBD: 05000119
# Đã ghi dữ liệu thành công cho SBD: 05000120
# Đã ghi dữ liệu thành công cho SBD: 05000121
# Đã ghi dữ liệu thành công cho SBD: 05000122
# Đã ghi dữ liệu thành công cho SBD: 05000123
# Đã ghi dữ liệu thành công cho SBD: 05000124
# Đã ghi dữ liệu thành công cho SBD: 05000125
# Đã ghi dữ liệu thành công cho SBD: 05000126
# Đã ghi dữ liệu thành công cho SBD: 05000127
# Đã ghi dữ liệu thành công cho SBD: 05000128
# Đã ghi dữ liệu thành công cho SBD: 05000129
# Đã ghi dữ liệu thành công cho SBD: 05000130
# Đã ghi dữ liệu thành công cho SBD: 05000131
# Đã ghi dữ liệu thành công cho SBD: 05000132
# Đã ghi dữ liệu thành công cho SBD: 05000133
# Đã ghi dữ liệu thành công cho SBD: 05000134
# Đã ghi dữ liệu thành công cho SBD: 05000135
# Đã ghi dữ liệu thành công cho SBD: 05000136
# Đã ghi dữ liệu thành công cho SBD: 05000137
# Đã ghi dữ liệu thành công cho SBD: 05000138
# Đã ghi dữ liệu thành công cho SBD: 05000139
# Đã ghi dữ liệu thành công cho SBD: 05000140
# Đã ghi dữ liệu thành công cho SBD: 05000141
# Đã ghi dữ liệu thành công cho SBD: 05000142
# Đã ghi dữ liệu thành công cho SBD: 05000143
# Đã ghi dữ liệu thành công cho SBD: 05000144
# Đã ghi dữ liệu thành công cho SBD: 05000145
# Đã ghi dữ liệu thành công cho SBD: 05000146
# Đã ghi dữ liệu thành công cho SBD: 05000147
# Đã ghi dữ liệu thành công cho SBD: 05000148
# Đã ghi dữ liệu thành công cho SBD: 05000149
# Đã ghi dữ liệu thành công cho SBD: 05000150
# Đã ghi dữ liệu thành công cho SBD: 05000151
# Đã ghi dữ liệu thành công cho SBD: 05000152
# Đã ghi dữ liệu thành công cho SBD: 05000153
# Đã ghi dữ liệu thành công cho SBD: 05000154
# Đã ghi dữ liệu thành công cho SBD: 05000155
# Đã ghi dữ liệu thành công cho SBD: 05000156
# Đã ghi dữ liệu thành công cho SBD: 05000157
# Đã ghi dữ liệu thành công cho SBD: 05000158
# Đã ghi dữ liệu thành công cho SBD: 05000159
# Đã ghi dữ liệu thành công cho SBD: 05000160
# Đã ghi dữ liệu thành công cho SBD: 05000161
# Đã ghi dữ liệu thành công cho SBD: 05000162
# Đã ghi dữ liệu thành công cho SBD: 05000163
# Đã ghi dữ liệu thành công cho SBD: 05000164
# Đã ghi dữ liệu thành công cho SBD: 05000165
# Đã ghi dữ liệu thành công cho SBD: 05000166
# Đã ghi dữ liệu thành công cho SBD: 05000167
# Đã ghi dữ liệu thành công cho SBD: 05000168
# Đã ghi dữ liệu thành công cho SBD: 05000169
# Đã ghi dữ liệu thành công cho SBD: 05000170
# Đã ghi dữ liệu thành công cho SBD: 05000171
# Đã ghi dữ liệu thành công cho SBD: 05000172
# Đã ghi dữ liệu thành công cho SBD: 05000173
# Đã ghi dữ liệu thành công cho SBD: 05000174
# Đã ghi dữ liệu thành công cho SBD: 05000175
# Đã ghi dữ liệu thành công cho SBD: 05000176
# Đã ghi dữ liệu thành công cho SBD: 05000177
# Đã ghi dữ liệu thành công cho SBD: 05000178
# Đã ghi dữ liệu thành công cho SBD: 05000179
# Đã ghi dữ liệu thành công cho SBD: 05000180
# Đã ghi dữ liệu thành công cho SBD: 05000181
# Đã ghi dữ liệu thành công cho SBD: 05000182
# Đã ghi dữ liệu thành công cho SBD: 05000183
# Đã ghi dữ liệu thành công cho SBD: 05000184
# Đã ghi dữ liệu thành công cho SBD: 05000185
# Đã ghi dữ liệu thành công cho SBD: 05000186
# Đã ghi dữ liệu thành công cho SBD: 05000187
# Đã ghi dữ liệu thành công cho SBD: 05000188
# Đã ghi dữ liệu thành công cho SBD: 05000189
# Đã ghi dữ liệu thành công cho SBD: 05000190
# Đã ghi dữ liệu thành công cho SBD: 05000191
# Đã ghi dữ liệu thành công cho SBD: 05000192
# Đã ghi dữ liệu thành công cho SBD: 05000193
# Đã ghi dữ liệu thành công cho SBD: 05000194
# Đã ghi dữ liệu thành công cho SBD: 05000195
# Đã ghi dữ liệu thành công cho SBD: 05000196
# Đã ghi dữ liệu thành công cho SBD: 05000197
# Đã ghi dữ liệu thành công cho SBD: 05000198
# Đã ghi dữ liệu thành công cho SBD: 05000199
# Đã ghi dữ liệu thành công cho SBD: 05000200
# Đã ghi dữ liệu thành công cho SBD: 05000201
# Đã ghi dữ liệu thành công cho SBD: 05000202
# Đã ghi dữ liệu thành công cho SBD: 05000203
# Đã ghi dữ liệu thành công cho SBD: 05000204
# Đã ghi dữ liệu thành công cho SBD: 05000205
# Đã ghi dữ liệu thành công cho SBD: 05000206
# Đã ghi dữ liệu thành công cho SBD: 05000207
# Đã ghi dữ liệu thành công cho SBD: 05000208
# Đã ghi dữ liệu thành công cho SBD: 05000209
# Đã ghi dữ liệu thành công cho SBD: 05000210
# Đã ghi dữ liệu thành công cho SBD: 05000211
# Đã ghi dữ liệu thành công cho SBD: 05000212
# Đã ghi dữ liệu thành công cho SBD: 05000213
# Đã ghi dữ liệu thành công cho SBD: 05000214
# Đã ghi dữ liệu thành công cho SBD: 05000215
# Đã ghi dữ liệu thành công cho SBD: 05000216
# Đã ghi dữ liệu thành công cho SBD: 05000217
# Đã ghi dữ liệu thành công cho SBD: 05000218
# Đã ghi dữ liệu thành công cho SBD: 05000219
# Đã ghi dữ liệu thành công cho SBD: 05000220
# Đã ghi dữ liệu thành công cho SBD: 05000221
# Đã ghi dữ liệu thành công cho SBD: 05000222
# Đã ghi dữ liệu thành công cho SBD: 05000223
# Đã ghi dữ liệu thành công cho SBD: 05000224
# Đã ghi dữ liệu thành công cho SBD: 05000225
# Đã ghi dữ liệu thành công cho SBD: 05000226
# Đã ghi dữ liệu thành công cho SBD: 05000227
# Đã ghi dữ liệu thành công cho SBD: 05000228
# Đã ghi dữ liệu thành công cho SBD: 05000229
# Đã ghi dữ liệu thành công cho SBD: 05000230
# Đã ghi dữ liệu thành công cho SBD: 05000231
# Đã ghi dữ liệu thành công cho SBD: 05000232
# Đã ghi dữ liệu thành công cho SBD: 05000233
# Đã ghi dữ liệu thành công cho SBD: 05000234
# Đã ghi dữ liệu thành công cho SBD: 05000235
# Đã ghi dữ liệu thành công cho SBD: 05000236
# Đã ghi dữ liệu thành công cho SBD: 05000237
# Đã ghi dữ liệu thành công cho SBD: 05000238
# Đã ghi dữ liệu thành công cho SBD: 05000239
# Đã ghi dữ liệu thành công cho SBD: 05000240
# Đã ghi dữ liệu thành công cho SBD: 05000241
# Đã ghi dữ liệu thành công cho SBD: 05000242
# Đã ghi dữ liệu thành công cho SBD: 05000243
# Đã ghi dữ liệu thành công cho SBD: 05000244
# Đã ghi dữ liệu thành công cho SBD: 05000245
# Đã ghi dữ liệu thành công cho SBD: 05000246
# Đã ghi dữ liệu thành công cho SBD: 05000247
# Đã ghi dữ liệu thành công cho SBD: 05000248
# Đã ghi dữ liệu thành công cho SBD: 05000249
# Đã ghi dữ liệu thành công cho SBD: 05000250
# Đã ghi dữ liệu thành công cho SBD: 05000251
# Đã ghi dữ liệu thành công cho SBD: 05000252
# Đã ghi dữ liệu thành công cho SBD: 05000253
# Đã ghi dữ liệu thành công cho SBD: 05000254
# Đã ghi dữ liệu thành công cho SBD: 05000255
# Đã ghi dữ liệu thành công cho SBD: 05000256
# Đã ghi dữ liệu thành công cho SBD: 05000257
# Đã ghi dữ liệu thành công cho SBD: 05000258
# Đã ghi dữ liệu thành công cho SBD: 05000259
# Đã ghi dữ liệu thành công cho SBD: 05000260
# Đã ghi dữ liệu thành công cho SBD: 05000261
# Đã ghi dữ liệu thành công cho SBD: 05000262
# Đã ghi dữ liệu thành công cho SBD: 05000263
# Đã ghi dữ liệu thành công cho SBD: 05000264
# Đã ghi dữ liệu thành công cho SBD: 05000265
# Đã ghi dữ liệu thành công cho SBD: 05000266
# Đã ghi dữ liệu thành công cho SBD: 05000267
# Đã ghi dữ liệu thành công cho SBD: 05000268
# Đã ghi dữ liệu thành công cho SBD: 05000269
# Đã ghi dữ liệu thành công cho SBD: 05000270
# Đã ghi dữ liệu thành công cho SBD: 05000271
# Đã ghi dữ liệu thành công cho SBD: 05000272
# Đã ghi dữ liệu thành công cho SBD: 05000273
# Đã ghi dữ liệu thành công cho SBD: 05000274
# Đã ghi dữ liệu thành công cho SBD: 05000275
# Đã ghi dữ liệu thành công cho SBD: 05000276
# Đã ghi dữ liệu thành công cho SBD: 05000277
# Đã ghi dữ liệu thành công cho SBD: 05000278
# Đã ghi dữ liệu thành công cho SBD: 05000279
# Đã ghi dữ liệu thành công cho SBD: 05000280
# Đã ghi dữ liệu thành công cho SBD: 05000281
# Đã ghi dữ liệu thành công cho SBD: 05000282
# Đã ghi dữ liệu thành công cho SBD: 05000283
# Đã ghi dữ liệu thành công cho SBD: 05000284
# Đã ghi dữ liệu thành công cho SBD: 05000285
# Đã ghi dữ liệu thành công cho SBD: 05000286
# Đã ghi dữ liệu thành công cho SBD: 05000287
# Đã ghi dữ liệu thành công cho SBD: 05000288
# Đã ghi dữ liệu thành công cho SBD: 05000289
# Đã ghi dữ liệu thành công cho SBD: 05000290
# Đã ghi dữ liệu thành công cho SBD: 05000291
# Đã ghi dữ liệu thành công cho SBD: 05000292
# Đã ghi dữ liệu thành công cho SBD: 05000293
# Đã ghi dữ liệu thành công cho SBD: 05000294
# Đã ghi dữ liệu thành công cho SBD: 05000295
# Đã ghi dữ liệu thành công cho SBD: 05000296
# Đã ghi dữ liệu thành công cho SBD: 05000297
# Đã ghi dữ liệu thành công cho SBD: 05000298
# Đã ghi dữ liệu thành công cho SBD: 05000299
# Đã ghi dữ liệu thành công cho SBD: 05000300
# Đã ghi dữ liệu thành công cho SBD: 05000301
# Đã ghi dữ liệu thành công cho SBD: 05000302
# Đã ghi dữ liệu thành công cho SBD: 05000303
# Đã ghi dữ liệu thành công cho SBD: 05000304
# Đã ghi dữ liệu thành công cho SBD: 05000305
# Đã ghi dữ liệu thành công cho SBD: 05000306
# Đã ghi dữ liệu thành công cho SBD: 05000307
# Đã ghi dữ liệu thành công cho SBD: 05000308
# Đã ghi dữ liệu thành công cho SBD: 05000309
# Đã ghi dữ liệu thành công cho SBD: 05000310
# Đã ghi dữ liệu thành công cho SBD: 05000311
# Đã ghi dữ liệu thành công cho SBD: 05000312
# Đã ghi dữ liệu thành công cho SBD: 05000313
# Đã ghi dữ liệu thành công cho SBD: 05000314
# Đã ghi dữ liệu thành công cho SBD: 05000315
# Đã ghi dữ liệu thành công cho SBD: 05000316
# Đã ghi dữ liệu thành công cho SBD: 05000317
# Đã ghi dữ liệu thành công cho SBD: 05000318
# Đã ghi dữ liệu thành công cho SBD: 05000319
# Đã ghi dữ liệu thành công cho SBD: 05000320
# Đã ghi dữ liệu thành công cho SBD: 05000321
# Đã ghi dữ liệu thành công cho SBD: 05000322
# Đã ghi dữ liệu thành công cho SBD: 05000323
# Đã ghi dữ liệu thành công cho SBD: 05000324
# Đã ghi dữ liệu thành công cho SBD: 05000325
# Đã ghi dữ liệu thành công cho SBD: 05000326
# Đã ghi dữ liệu thành công cho SBD: 05000327
# Đã ghi dữ liệu thành công cho SBD: 05000328
# Đã ghi dữ liệu thành công cho SBD: 05000329
# Đã ghi dữ liệu thành công cho SBD: 05000330
# Đã ghi dữ liệu thành công cho SBD: 05000331
# Đã ghi dữ liệu thành công cho SBD: 05000332
# Đã ghi dữ liệu thành công cho SBD: 05000333
# Đã ghi dữ liệu thành công cho SBD: 05000334
# Đã ghi dữ liệu thành công cho SBD: 05000335
# Đã ghi dữ liệu thành công cho SBD: 05000336
# Đã ghi dữ liệu thành công cho SBD: 05000337
# Đã ghi dữ liệu thành công cho SBD: 05000338
# Đã ghi dữ liệu thành công cho SBD: 05000339
# Đã ghi dữ liệu thành công cho SBD: 05000340
# Đã ghi dữ liệu thành công cho SBD: 05000341
# Đã ghi dữ liệu thành công cho SBD: 05000342
# Đã ghi dữ liệu thành công cho SBD: 05000343
# Đã ghi dữ liệu thành công cho SBD: 05000344
# Đã ghi dữ liệu thành công cho SBD: 05000345
# Đã ghi dữ liệu thành công cho SBD: 05000346
# Đã ghi dữ liệu thành công cho SBD: 05000347
# Đã ghi dữ liệu thành công cho SBD: 05000348
# Đã ghi dữ liệu thành công cho SBD: 05000349
# Đã ghi dữ liệu thành công cho SBD: 05000350
# Đã ghi dữ liệu thành công cho SBD: 05000351
# Đã ghi dữ liệu thành công cho SBD: 05000352
# Đã ghi dữ liệu thành công cho SBD: 05000353
# Đã ghi dữ liệu thành công cho SBD: 05000354
# Đã ghi dữ liệu thành công cho SBD: 05000355
# Đã ghi dữ liệu thành công cho SBD: 05000356
# Đã ghi dữ liệu thành công cho SBD: 05000357
# Đã ghi dữ liệu thành công cho SBD: 05000358
# Đã ghi dữ liệu thành công cho SBD: 05000359
# Đã ghi dữ liệu thành công cho SBD: 05000360
# Đã ghi dữ liệu thành công cho SBD: 05000361
# Đã ghi dữ liệu thành công cho SBD: 05000362
# Đã ghi dữ liệu thành công cho SBD: 05000363
# Đã ghi dữ liệu thành công cho SBD: 05000364
# Đã ghi dữ liệu thành công cho SBD: 05000365
# Đã ghi dữ liệu thành công cho SBD: 05000366
# Đã ghi dữ liệu thành công cho SBD: 05000367
# Đã ghi dữ liệu thành công cho SBD: 05000368
# Đã ghi dữ liệu thành công cho SBD: 05000369
# Đã ghi dữ liệu thành công cho SBD: 05000370
# Đã ghi dữ liệu thành công cho SBD: 05000371
# Đã ghi dữ liệu thành công cho SBD: 05000372
# Đã ghi dữ liệu thành công cho SBD: 05000373
# Đã ghi dữ liệu thành công cho SBD: 05000374
# Đã ghi dữ liệu thành công cho SBD: 05000375
# Đã ghi dữ liệu thành công cho SBD: 05000376
# Đã ghi dữ liệu thành công cho SBD: 05000377
# Đã ghi dữ liệu thành công cho SBD: 05000378
# Đã ghi dữ liệu thành công cho SBD: 05000379
# Đã ghi dữ liệu thành công cho SBD: 05000380
# Đã ghi dữ liệu thành công cho SBD: 05000381
# Đã ghi dữ liệu thành công cho SBD: 05000382
# Đã ghi dữ liệu thành công cho SBD: 05000383
# Đã ghi dữ liệu thành công cho SBD: 05000384
# Đã ghi dữ liệu thành công cho SBD: 05000385
# Đã ghi dữ liệu thành công cho SBD: 05000386
# Đã ghi dữ liệu thành công cho SBD: 05000387
# Đã ghi dữ liệu thành công cho SBD: 05000388
# Đã ghi dữ liệu thành công cho SBD: 05000389
# Đã ghi dữ liệu thành công cho SBD: 05000390
# Đã ghi dữ liệu thành công cho SBD: 05000391
# Đã ghi dữ liệu thành công cho SBD: 05000392
# Đã ghi dữ liệu thành công cho SBD: 05000393
# Đã ghi dữ liệu thành công cho SBD: 05000394
# Đã ghi dữ liệu thành công cho SBD: 05000395
# Đã ghi dữ liệu thành công cho SBD: 05000396
# Đã ghi dữ liệu thành công cho SBD: 05000397
# Đã ghi dữ liệu thành công cho SBD: 05000398
# Đã ghi dữ liệu thành công cho SBD: 05000399
# Đã ghi dữ liệu thành công cho SBD: 05000400
# Đã ghi dữ liệu thành công cho SBD: 05000401
# Đã ghi dữ liệu thành công cho SBD: 05000402
# Đã ghi dữ liệu thành công cho SBD: 05000403
# Đã ghi dữ liệu thành công cho SBD: 05000404
# Đã ghi dữ liệu thành công cho SBD: 05000405
# Đã ghi dữ liệu thành công cho SBD: 05000406
# Đã ghi dữ liệu thành công cho SBD: 05000407
# Đã ghi dữ liệu thành công cho SBD: 05000408
# Đã ghi dữ liệu thành công cho SBD: 05000409
# Đã ghi dữ liệu thành công cho SBD: 05000410
# Đã ghi dữ liệu thành công cho SBD: 05000411
# Đã ghi dữ liệu thành công cho SBD: 05000412
# Đã ghi dữ liệu thành công cho SBD: 05000413
# Đã ghi dữ liệu thành công cho SBD: 05000414
# Đã ghi dữ liệu thành công cho SBD: 05000415
# Đã ghi dữ liệu thành công cho SBD: 05000416
# Đã ghi dữ liệu thành công cho SBD: 05000417
# Đã ghi dữ liệu thành công cho SBD: 05000418
# Đã ghi dữ liệu thành công cho SBD: 05000419
# Đã ghi dữ liệu thành công cho SBD: 05000420
# Đã ghi dữ liệu thành công cho SBD: 05000421
# Đã ghi dữ liệu thành công cho SBD: 05000422
# Đã ghi dữ liệu thành công cho SBD: 05000423
# Đã ghi dữ liệu thành công cho SBD: 05000424
# Đã ghi dữ liệu thành công cho SBD: 05000425
# Đã ghi dữ liệu thành công cho SBD: 05000426
# Đã ghi dữ liệu thành công cho SBD: 05000427
# Đã ghi dữ liệu thành công cho SBD: 05000428
# Đã ghi dữ liệu thành công cho SBD: 05000429
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 05000431
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 05000433
# Đã ghi dữ liệu thành công cho SBD: 05000434
# Đã ghi dữ liệu thành công cho SBD: 05000435
# Đã ghi dữ liệu thành công cho SBD: 05000436
# Đã ghi dữ liệu thành công cho SBD: 05000437
# Đã ghi dữ liệu thành công cho SBD: 05000438
# Đã ghi dữ liệu thành công cho SBD: 05000439
# Đã ghi dữ liệu thành công cho SBD: 05000440
# Đã ghi dữ liệu thành công cho SBD: 05000441
# Đã ghi dữ liệu thành công cho SBD: 05000442
# Đã ghi dữ liệu thành công cho SBD: 05000443
# Đã ghi dữ liệu thành công cho SBD: 05000444
# Đã ghi dữ liệu thành công cho SBD: 05000445
# Đã ghi dữ liệu thành công cho SBD: 05000446
# Đã ghi dữ liệu thành công cho SBD: 05000447
# Đã ghi dữ liệu thành công cho SBD: 05000448
# Đã ghi dữ liệu thành công cho SBD: 05000449
# Đã ghi dữ liệu thành công cho SBD: 05000450
# Đã ghi dữ liệu thành công cho SBD: 05000451
# Đã ghi dữ liệu thành công cho SBD: 05000452
# Đã ghi dữ liệu thành công cho SBD: 05000453
# Đã ghi dữ liệu thành công cho SBD: 05000454
# Đã ghi dữ liệu thành công cho SBD: 05000455
# Đã ghi dữ liệu thành công cho SBD: 05000456
# Đã ghi dữ liệu thành công cho SBD: 05000457
# Đã ghi dữ liệu thành công cho SBD: 05000458
# Đã ghi dữ liệu thành công cho SBD: 05000459
# Đã ghi dữ liệu thành công cho SBD: 05000460
# Đã ghi dữ liệu thành công cho SBD: 05000461
# Đã ghi dữ liệu thành công cho SBD: 05000462
# Đã ghi dữ liệu thành công cho SBD: 05000463
# Đã ghi dữ liệu thành công cho SBD: 05000464
# Đã ghi dữ liệu thành công cho SBD: 05000465
# Đã ghi dữ liệu thành công cho SBD: 05000466
# Đã ghi dữ liệu thành công cho SBD: 05000467
# Đã ghi dữ liệu thành công cho SBD: 05000468
# Đã ghi dữ liệu thành công cho SBD: 05000469
# Đã ghi dữ liệu thành công cho SBD: 05000470
# Đã ghi dữ liệu thành công cho SBD: 05000471
# Đã ghi dữ liệu thành công cho SBD: 05000472
# Đã ghi dữ liệu thành công cho SBD: 05000473
# Đã ghi dữ liệu thành công cho SBD: 05000474
# Đã ghi dữ liệu thành công cho SBD: 05000475
# Đã ghi dữ liệu thành công cho SBD: 05000476
# Đã ghi dữ liệu thành công cho SBD: 05000477
# Đã ghi dữ liệu thành công cho SBD: 05000478
# Đã ghi dữ liệu thành công cho SBD: 05000479
# Đã ghi dữ liệu thành công cho SBD: 05000480
# Đã ghi dữ liệu thành công cho SBD: 05000481
# Đã ghi dữ liệu thành công cho SBD: 05000482
# Đã ghi dữ liệu thành công cho SBD: 05000483
# Đã ghi dữ liệu thành công cho SBD: 05000484
# Đã ghi dữ liệu thành công cho SBD: 05000485
# Đã ghi dữ liệu thành công cho SBD: 05000486
# Đã ghi dữ liệu thành công cho SBD: 05000487
# Đã ghi dữ liệu thành công cho SBD: 05000488
# Đã ghi dữ liệu thành công cho SBD: 05000489
# Đã ghi dữ liệu thành công cho SBD: 05000490
# Đã ghi dữ liệu thành công cho SBD: 05000491
# Đã ghi dữ liệu thành công cho SBD: 05000492
# Đã ghi dữ liệu thành công cho SBD: 05000493
# Đã ghi dữ liệu thành công cho SBD: 05000494
# Đã ghi dữ liệu thành công cho SBD: 05000495
# Đã ghi dữ liệu thành công cho SBD: 05000496
# Đã ghi dữ liệu thành công cho SBD: 05000497
# Đã ghi dữ liệu thành công cho SBD: 05000498
# Đã ghi dữ liệu thành công cho SBD: 05000499
# Đã ghi dữ liệu thành công cho SBD: 05000500
# Đã ghi dữ liệu thành công cho SBD: 05000501
# Đã ghi dữ liệu thành công cho SBD: 05000502
# Đã ghi dữ liệu thành công cho SBD: 05000503
# Đã ghi dữ liệu thành công cho SBD: 05000504
# Đã ghi dữ liệu thành công cho SBD: 05000505
# Đã ghi dữ liệu thành công cho SBD: 05000506
# Đã ghi dữ liệu thành công cho SBD: 05000507
# Đã ghi dữ liệu thành công cho SBD: 05000508
# Đã ghi dữ liệu thành công cho SBD: 05000509
# Đã ghi dữ liệu thành công cho SBD: 05000510
# Đã ghi dữ liệu thành công cho SBD: 05000511
# Đã ghi dữ liệu thành công cho SBD: 05000512
# Đã ghi dữ liệu thành công cho SBD: 05000513
# Đã ghi dữ liệu thành công cho SBD: 05000514
# Đã ghi dữ liệu thành công cho SBD: 05000515
# Đã ghi dữ liệu thành công cho SBD: 05000516
# Đã ghi dữ liệu thành công cho SBD: 05000517
# Đã ghi dữ liệu thành công cho SBD: 05000518
# Đã ghi dữ liệu thành công cho SBD: 05000519
# Đã ghi dữ liệu thành công cho SBD: 05000520
# Đã ghi dữ liệu thành công cho SBD: 05000521
# Đã ghi dữ liệu thành công cho SBD: 05000522
# Đã ghi dữ liệu thành công cho SBD: 05000523
# Đã ghi dữ liệu thành công cho SBD: 05000524
# Đã ghi dữ liệu thành công cho SBD: 05000525
# Đã ghi dữ liệu thành công cho SBD: 05000526
# Đã ghi dữ liệu thành công cho SBD: 05000527
# Đã ghi dữ liệu thành công cho SBD: 05000528
# Đã ghi dữ liệu thành công cho SBD: 05000529
# Đã ghi dữ liệu thành công cho SBD: 05000530
# Đã ghi dữ liệu thành công cho SBD: 05000531
# Đã ghi dữ liệu thành công cho SBD: 05000532
# Đã ghi dữ liệu thành công cho SBD: 05000533
# Đã ghi dữ liệu thành công cho SBD: 05000534
# Đã ghi dữ liệu thành công cho SBD: 05000535
# Đã ghi dữ liệu thành công cho SBD: 05000536
# Đã ghi dữ liệu thành công cho SBD: 05000537
# Đã ghi dữ liệu thành công cho SBD: 05000538
# Đã ghi dữ liệu thành công cho SBD: 05000539
# Đã ghi dữ liệu thành công cho SBD: 05000540
# Đã ghi dữ liệu thành công cho SBD: 05000541
# Đã ghi dữ liệu thành công cho SBD: 05000542
# Đã ghi dữ liệu thành công cho SBD: 05000543
# Đã ghi dữ liệu thành công cho SBD: 05000544
# Đã ghi dữ liệu thành công cho SBD: 05000545
# Đã ghi dữ liệu thành công cho SBD: 05000546
# Đã ghi dữ liệu thành công cho SBD: 05000547
# Đã ghi dữ liệu thành công cho SBD: 05000548
# Đã ghi dữ liệu thành công cho SBD: 05000549
# Đã ghi dữ liệu thành công cho SBD: 05000550
# Đã ghi dữ liệu thành công cho SBD: 05000551
# Đã ghi dữ liệu thành công cho SBD: 05000552
# Đã ghi dữ liệu thành công cho SBD: 05000553
# Đã ghi dữ liệu thành công cho SBD: 05000554
# Đã ghi dữ liệu thành công cho SBD: 05000555
# Đã ghi dữ liệu thành công cho SBD: 05000556
# Đã ghi dữ liệu thành công cho SBD: 05000557
# Đã ghi dữ liệu thành công cho SBD: 05000558
# Đã ghi dữ liệu thành công cho SBD: 05000559
# Đã ghi dữ liệu thành công cho SBD: 05000560
# Đã ghi dữ liệu thành công cho SBD: 05000561
# Đã ghi dữ liệu thành công cho SBD: 05000562
# Đã ghi dữ liệu thành công cho SBD: 05000563
# Đã ghi dữ liệu thành công cho SBD: 05000564
# Đã ghi dữ liệu thành công cho SBD: 05000565
# Đã ghi dữ liệu thành công cho SBD: 05000566
# Đã ghi dữ liệu thành công cho SBD: 05000567
# Đã ghi dữ liệu thành công cho SBD: 05000568
# Đã ghi dữ liệu thành công cho SBD: 05000569
# Đã ghi dữ liệu thành công cho SBD: 05000570
# Đã ghi dữ liệu thành công cho SBD: 05000571
# Đã ghi dữ liệu thành công cho SBD: 05000572
# Đã ghi dữ liệu thành công cho SBD: 05000573
# Đã ghi dữ liệu thành công cho SBD: 05000574
# Đã ghi dữ liệu thành công cho SBD: 05000575
# Đã ghi dữ liệu thành công cho SBD: 05000576
# Đã ghi dữ liệu thành công cho SBD: 05000577
# Đã ghi dữ liệu thành công cho SBD: 05000578
# Đã ghi dữ liệu thành công cho SBD: 05000579
# Đã ghi dữ liệu thành công cho SBD: 05000580
# Đã ghi dữ liệu thành công cho SBD: 05000581
# Đã ghi dữ liệu thành công cho SBD: 05000582
# Đã ghi dữ liệu thành công cho SBD: 05000583
# Đã ghi dữ liệu thành công cho SBD: 05000584
# Đã ghi dữ liệu thành công cho SBD: 05000585
# Đã ghi dữ liệu thành công cho SBD: 05000586
# Đã ghi dữ liệu thành công cho SBD: 05000587
# Đã ghi dữ liệu thành công cho SBD: 05000588
# Đã ghi dữ liệu thành công cho SBD: 05000589
# Đã ghi dữ liệu thành công cho SBD: 05000590
# Đã ghi dữ liệu thành công cho SBD: 05000591
# Đã ghi dữ liệu thành công cho SBD: 05000592
# Đã ghi dữ liệu thành công cho SBD: 05000593
# Đã ghi dữ liệu thành công cho SBD: 05000594
# Đã ghi dữ liệu thành công cho SBD: 05000595
# Đã ghi dữ liệu thành công cho SBD: 05000596
# Đã ghi dữ liệu thành công cho SBD: 05000597
# Đã ghi dữ liệu thành công cho SBD: 05000598
# Đã ghi dữ liệu thành công cho SBD: 05000599
# Đã ghi dữ liệu thành công cho SBD: 05000600
# Đã ghi dữ liệu thành công cho SBD: 05000601
# Đã ghi dữ liệu thành công cho SBD: 05000602
# Đã ghi dữ liệu thành công cho SBD: 05000603
# Đã ghi dữ liệu thành công cho SBD: 05000604
# Đã ghi dữ liệu thành công cho SBD: 05000605
# Đã ghi dữ liệu thành công cho SBD: 05000606
# Đã ghi dữ liệu thành công cho SBD: 05000607
# Đã ghi dữ liệu thành công cho SBD: 05000608
# Đã ghi dữ liệu thành công cho SBD: 05000609
# Đã ghi dữ liệu thành công cho SBD: 05000610
# Đã ghi dữ liệu thành công cho SBD: 05000611
# Đã ghi dữ liệu thành công cho SBD: 05000612
# Đã ghi dữ liệu thành công cho SBD: 05000613
# Đã ghi dữ liệu thành công cho SBD: 05000614
# Đã ghi dữ liệu thành công cho SBD: 05000615
# Đã ghi dữ liệu thành công cho SBD: 05000616
# Đã ghi dữ liệu thành công cho SBD: 05000617
# Đã ghi dữ liệu thành công cho SBD: 05000618
# Đã ghi dữ liệu thành công cho SBD: 05000619
# Đã ghi dữ liệu thành công cho SBD: 05000620
# Đã ghi dữ liệu thành công cho SBD: 05000621
# Đã ghi dữ liệu thành công cho SBD: 05000622
# Đã ghi dữ liệu thành công cho SBD: 05000623
# Đã ghi dữ liệu thành công cho SBD: 05000624
# Đã ghi dữ liệu thành công cho SBD: 05000625
# Đã ghi dữ liệu thành công cho SBD: 05000626
# Đã ghi dữ liệu thành công cho SBD: 05000627
# Đã ghi dữ liệu thành công cho SBD: 05000628
# Đã ghi dữ liệu thành công cho SBD: 05000629
# Đã ghi dữ liệu thành công cho SBD: 05000630
# Đã ghi dữ liệu thành công cho SBD: 05000631
# Đã ghi dữ liệu thành công cho SBD: 05000632
# Đã ghi dữ liệu thành công cho SBD: 05000633
# Đã ghi dữ liệu thành công cho SBD: 05000634
# Đã ghi dữ liệu thành công cho SBD: 05000635
# Đã ghi dữ liệu thành công cho SBD: 05000636
# Đã ghi dữ liệu thành công cho SBD: 05000637
# Đã ghi dữ liệu thành công cho SBD: 05000638
# Đã ghi dữ liệu thành công cho SBD: 05000639
# Đã ghi dữ liệu thành công cho SBD: 05000640
# Đã ghi dữ liệu thành công cho SBD: 05000641
# Đã ghi dữ liệu thành công cho SBD: 05000642
# Đã ghi dữ liệu thành công cho SBD: 05000643
# Đã ghi dữ liệu thành công cho SBD: 05000644
# Đã ghi dữ liệu thành công cho SBD: 05000645
# Đã ghi dữ liệu thành công cho SBD: 05000646
# Đã ghi dữ liệu thành công cho SBD: 05000647
# Đã ghi dữ liệu thành công cho SBD: 05000648
# Đã ghi dữ liệu thành công cho SBD: 05000649
# Đã ghi dữ liệu thành công cho SBD: 05000650
# Đã ghi dữ liệu thành công cho SBD: 05000651
# Đã ghi dữ liệu thành công cho SBD: 05000652
# Đã ghi dữ liệu thành công cho SBD: 05000653
# Đã ghi dữ liệu thành công cho SBD: 05000654
# Đã ghi dữ liệu thành công cho SBD: 05000655
# Đã ghi dữ liệu thành công cho SBD: 05000656
# Đã ghi dữ liệu thành công cho SBD: 05000657
# Đã ghi dữ liệu thành công cho SBD: 05000658
# Đã ghi dữ liệu thành công cho SBD: 05000659
# Đã ghi dữ liệu thành công cho SBD: 05000660
# Đã ghi dữ liệu thành công cho SBD: 05000661
# Đã ghi dữ liệu thành công cho SBD: 05000662
# Đã ghi dữ liệu thành công cho SBD: 05000663
# Đã ghi dữ liệu thành công cho SBD: 05000664
# Đã ghi dữ liệu thành công cho SBD: 05000665
# Đã ghi dữ liệu thành công cho SBD: 05000666
# Đã ghi dữ liệu thành công cho SBD: 05000667
# Đã ghi dữ liệu thành công cho SBD: 05000668
# Đã ghi dữ liệu thành công cho SBD: 05000669
# Đã ghi dữ liệu thành công cho SBD: 05000670
# Đã ghi dữ liệu thành công cho SBD: 05000671
# Đã ghi dữ liệu thành công cho SBD: 05000672
# Đã ghi dữ liệu thành công cho SBD: 05000673
# Đã ghi dữ liệu thành công cho SBD: 05000674
# Đã ghi dữ liệu thành công cho SBD: 05000675
# Đã ghi dữ liệu thành công cho SBD: 05000676
# Đã ghi dữ liệu thành công cho SBD: 05000677
# Đã ghi dữ liệu thành công cho SBD: 05000678
# Đã ghi dữ liệu thành công cho SBD: 05000679
# Đã ghi dữ liệu thành công cho SBD: 05000680
# Đã ghi dữ liệu thành công cho SBD: 05000681
# Đã ghi dữ liệu thành công cho SBD: 05000682
# Đã ghi dữ liệu thành công cho SBD: 05000683
# Đã ghi dữ liệu thành công cho SBD: 05000684
# Đã ghi dữ liệu thành công cho SBD: 05000685
# Đã ghi dữ liệu thành công cho SBD: 05000686
# Đã ghi dữ liệu thành công cho SBD: 05000687
# Đã ghi dữ liệu thành công cho SBD: 05000688
# Đã ghi dữ liệu thành công cho SBD: 05000689
# Đã ghi dữ liệu thành công cho SBD: 05000690
# Đã ghi dữ liệu thành công cho SBD: 05000691
# Đã ghi dữ liệu thành công cho SBD: 05000692
# Đã ghi dữ liệu thành công cho SBD: 05000693
# Đã ghi dữ liệu thành công cho SBD: 05000694
# Đã ghi dữ liệu thành công cho SBD: 05000695
# Đã ghi dữ liệu thành công cho SBD: 05000696
# Đã ghi dữ liệu thành công cho SBD: 05000697
# Đã ghi dữ liệu thành công cho SBD: 05000698
# Đã ghi dữ liệu thành công cho SBD: 05000699
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 05000701
# Đã ghi dữ liệu thành công cho SBD: 05000702
# Đã ghi dữ liệu thành công cho SBD: 05000703
# Đã ghi dữ liệu thành công cho SBD: 05000704
# Đã ghi dữ liệu thành công cho SBD: 05000705
# Đã ghi dữ liệu thành công cho SBD: 05000706
# Đã ghi dữ liệu thành công cho SBD: 05000707
# Đã ghi dữ liệu thành công cho SBD: 05000708
# Đã ghi dữ liệu thành công cho SBD: 05000709
# Đã ghi dữ liệu thành công cho SBD: 05000710
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 05000712
# Đã ghi dữ liệu thành công cho SBD: 05000713
# Đã ghi dữ liệu thành công cho SBD: 05000714
# Đã ghi dữ liệu thành công cho SBD: 05000715
# Đã ghi dữ liệu thành công cho SBD: 05000716
# Đã ghi dữ liệu thành công cho SBD: 05000717
# Đã ghi dữ liệu thành công cho SBD: 05000718
# Đã ghi dữ liệu thành công cho SBD: 05000719
# Đã ghi dữ liệu thành công cho SBD: 05000720
# Đã ghi dữ liệu thành công cho SBD: 05000721
# Đã ghi dữ liệu thành công cho SBD: 05000722
# Đã ghi dữ liệu thành công cho SBD: 05000723
# Đã ghi dữ liệu thành công cho SBD: 05000724
# Đã ghi dữ liệu thành công cho SBD: 05000725
# Đã ghi dữ liệu thành công cho SBD: 05000726
# Đã ghi dữ liệu thành công cho SBD: 05000727
# Đã ghi dữ liệu thành công cho SBD: 05000728
# Đã ghi dữ liệu thành công cho SBD: 05000729
# Đã ghi dữ liệu thành công cho SBD: 05000730
# Đã ghi dữ liệu thành công cho SBD: 05000731
# Đã ghi dữ liệu thành công cho SBD: 05000732
# Đã ghi dữ liệu thành công cho SBD: 05000733
# Đã ghi dữ liệu thành công cho SBD: 05000734
# Đã ghi dữ liệu thành công cho SBD: 05000735
# Đã ghi dữ liệu thành công cho SBD: 05000736
# Đã ghi dữ liệu thành công cho SBD: 05000737
# Đã ghi dữ liệu thành công cho SBD: 05000738
# Đã ghi dữ liệu thành công cho SBD: 05000739
# Đã ghi dữ liệu thành công cho SBD: 05000740
# Đã ghi dữ liệu thành công cho SBD: 05000741
# Đã ghi dữ liệu thành công cho SBD: 05000742
# Đã ghi dữ liệu thành công cho SBD: 05000743
# Đã ghi dữ liệu thành công cho SBD: 05000744
# Đã ghi dữ liệu thành công cho SBD: 05000745
# Đã ghi dữ liệu thành công cho SBD: 05000746
# Đã ghi dữ liệu thành công cho SBD: 05000747
# Đã ghi dữ liệu thành công cho SBD: 05000748
# Đã ghi dữ liệu thành công cho SBD: 05000749
# Đã ghi dữ liệu thành công cho SBD: 05000750
# Đã ghi dữ liệu thành công cho SBD: 05000751
# Đã ghi dữ liệu thành công cho SBD: 05000752
# Đã ghi dữ liệu thành công cho SBD: 05000753
# Đã ghi dữ liệu thành công cho SBD: 05000754
# Đã ghi dữ liệu thành công cho SBD: 05000755
# Đã ghi dữ liệu thành công cho SBD: 05000756
# Đã ghi dữ liệu thành công cho SBD: 05000757
# Đã ghi dữ liệu thành công cho SBD: 05000758
# Đã ghi dữ liệu thành công cho SBD: 05000759
# Đã ghi dữ liệu thành công cho SBD: 05000760
# Đã ghi dữ liệu thành công cho SBD: 05000761
# Đã ghi dữ liệu thành công cho SBD: 05000762
# Đã ghi dữ liệu thành công cho SBD: 05000763
# Đã ghi dữ liệu thành công cho SBD: 05000764
# Đã ghi dữ liệu thành công cho SBD: 05000765
# Đã ghi dữ liệu thành công cho SBD: 05000766
# Đã ghi dữ liệu thành công cho SBD: 05000767
# Đã ghi dữ liệu thành công cho SBD: 05000768
# Đã ghi dữ liệu thành công cho SBD: 05000769
# Đã ghi dữ liệu thành công cho SBD: 05000770
# Đã ghi dữ liệu thành công cho SBD: 05000771
# Đã ghi dữ liệu thành công cho SBD: 05000772
# Đã ghi dữ liệu thành công cho SBD: 05000773
# Đã ghi dữ liệu thành công cho SBD: 05000774
# Đã ghi dữ liệu thành công cho SBD: 05000775
# Đã ghi dữ liệu thành công cho SBD: 05000776
# Đã ghi dữ liệu thành công cho SBD: 05000777
# Đã ghi dữ liệu thành công cho SBD: 05000778
# Đã ghi dữ liệu thành công cho SBD: 05000779
# Đã ghi dữ liệu thành công cho SBD: 05000780
# Đã ghi dữ liệu thành công cho SBD: 05000781
# Đã ghi dữ liệu thành công cho SBD: 05000782
# Đã ghi dữ liệu thành công cho SBD: 05000783
# Đã ghi dữ liệu thành công cho SBD: 05000784
# Đã ghi dữ liệu thành công cho SBD: 05000785
# Đã ghi dữ liệu thành công cho SBD: 05000786
# Đã ghi dữ liệu thành công cho SBD: 05000787
# Đã ghi dữ liệu thành công cho SBD: 05000788
# Đã ghi dữ liệu thành công cho SBD: 05000789
# Đã ghi dữ liệu thành công cho SBD: 05000790
# Đã ghi dữ liệu thành công cho SBD: 05000791
# Đã ghi dữ liệu thành công cho SBD: 05000792
# Đã ghi dữ liệu thành công cho SBD: 05000793
# Đã ghi dữ liệu thành công cho SBD: 05000794
# Đã ghi dữ liệu thành công cho SBD: 05000795
# Đã ghi dữ liệu thành công cho SBD: 05000796
# Đã ghi dữ liệu thành công cho SBD: 05000797
# Đã ghi dữ liệu thành công cho SBD: 05000798
# Đã ghi dữ liệu thành công cho SBD: 05000799
# Đã ghi dữ liệu thành công cho SBD: 05000800
# Đã ghi dữ liệu thành công cho SBD: 05000801
# Đã ghi dữ liệu thành công cho SBD: 05000802
# Đã ghi dữ liệu thành công cho SBD: 05000803
# Đã ghi dữ liệu thành công cho SBD: 05000804
# Đã ghi dữ liệu thành công cho SBD: 05000805
# Đã ghi dữ liệu thành công cho SBD: 05000806
# Đã ghi dữ liệu thành công cho SBD: 05000807
# Đã ghi dữ liệu thành công cho SBD: 05000808
# Đã ghi dữ liệu thành công cho SBD: 05000809
# Đã ghi dữ liệu thành công cho SBD: 05000810
# Đã ghi dữ liệu thành công cho SBD: 05000811
# Đã ghi dữ liệu thành công cho SBD: 05000812
# Đã ghi dữ liệu thành công cho SBD: 05000813
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 05000815
# Đã ghi dữ liệu thành công cho SBD: 05000816
# Đã ghi dữ liệu thành công cho SBD: 05000817
# Đã ghi dữ liệu thành công cho SBD: 05000818
# Đã ghi dữ liệu thành công cho SBD: 05000819
# Đã ghi dữ liệu thành công cho SBD: 05000820
# Đã ghi dữ liệu thành công cho SBD: 05000821
# Đã ghi dữ liệu thành công cho SBD: 05000822
# Đã ghi dữ liệu thành công cho SBD: 05000823
# Đã ghi dữ liệu thành công cho SBD: 05000824
# Đã ghi dữ liệu thành công cho SBD: 05000825
# Đã ghi dữ liệu thành công cho SBD: 05000826
# Đã ghi dữ liệu thành công cho SBD: 05000827
# Đã ghi dữ liệu thành công cho SBD: 05000828
# Đã ghi dữ liệu thành công cho SBD: 05000829
# Đã ghi dữ liệu thành công cho SBD: 05000830
# Đã ghi dữ liệu thành công cho SBD: 05000831
# Đã ghi dữ liệu thành công cho SBD: 05000832
# Đã ghi dữ liệu thành công cho SBD: 05000833
# Đã ghi dữ liệu thành công cho SBD: 05000834
# Đã ghi dữ liệu thành công cho SBD: 05000835
# Đã ghi dữ liệu thành công cho SBD: 05000836
# Đã ghi dữ liệu thành công cho SBD: 05000837
# Đã ghi dữ liệu thành công cho SBD: 05000838
# Đã ghi dữ liệu thành công cho SBD: 05000839
# Đã ghi dữ liệu thành công cho SBD: 05000840
# Đã ghi dữ liệu thành công cho SBD: 05000841
# Đã ghi dữ liệu thành công cho SBD: 05000842
# Đã ghi dữ liệu thành công cho SBD: 05000843
# Đã ghi dữ liệu thành công cho SBD: 05000844
# Đã ghi dữ liệu thành công cho SBD: 05000845
# Đã ghi dữ liệu thành công cho SBD: 05000846
# Đã ghi dữ liệu thành công cho SBD: 05000847
# Đã ghi dữ liệu thành công cho SBD: 05000848
# Đã ghi dữ liệu thành công cho SBD: 05000849
# Đã ghi dữ liệu thành công cho SBD: 05000850
# Đã ghi dữ liệu thành công cho SBD: 05000851
# Đã ghi dữ liệu thành công cho SBD: 05000852
# Đã ghi dữ liệu thành công cho SBD: 05000853
# Đã ghi dữ liệu thành công cho SBD: 05000854
# Đã ghi dữ liệu thành công cho SBD: 05000855
# Đã ghi dữ liệu thành công cho SBD: 05000856
# Đã ghi dữ liệu thành công cho SBD: 05000857
# Đã ghi dữ liệu thành công cho SBD: 05000858
# Đã ghi dữ liệu thành công cho SBD: 05000859
# Đã ghi dữ liệu thành công cho SBD: 05000860
# Đã ghi dữ liệu thành công cho SBD: 05000861
# Đã ghi dữ liệu thành công cho SBD: 05000862
# Đã ghi dữ liệu thành công cho SBD: 05000863
# Đã ghi dữ liệu thành công cho SBD: 05000864
# Đã ghi dữ liệu thành công cho SBD: 05000865
# Đã ghi dữ liệu thành công cho SBD: 05000866
# Đã ghi dữ liệu thành công cho SBD: 05000867
# Đã ghi dữ liệu thành công cho SBD: 05000868
# Đã ghi dữ liệu thành công cho SBD: 05000869
# Đã ghi dữ liệu thành công cho SBD: 05000870
# Đã ghi dữ liệu thành công cho SBD: 05000871
# Đã ghi dữ liệu thành công cho SBD: 05000872
# Đã ghi dữ liệu thành công cho SBD: 05000873
# Đã ghi dữ liệu thành công cho SBD: 05000874
# Đã ghi dữ liệu thành công cho SBD: 05000875
# Đã ghi dữ liệu thành công cho SBD: 05000876
# Đã ghi dữ liệu thành công cho SBD: 05000877
# Đã ghi dữ liệu thành công cho SBD: 05000878
# Đã ghi dữ liệu thành công cho SBD: 05000879
# Đã ghi dữ liệu thành công cho SBD: 05000880
# Đã ghi dữ liệu thành công cho SBD: 05000881
# Đã ghi dữ liệu thành công cho SBD: 05000882
# Đã ghi dữ liệu thành công cho SBD: 05000883
# Đã ghi dữ liệu thành công cho SBD: 05000884
# Đã ghi dữ liệu thành công cho SBD: 05000885
# Đã ghi dữ liệu thành công cho SBD: 05000886
# Đã ghi dữ liệu thành công cho SBD: 05000887
# Đã ghi dữ liệu thành công cho SBD: 05000888
# Đã ghi dữ liệu thành công cho SBD: 05000889
# Đã ghi dữ liệu thành công cho SBD: 05000890
# Đã ghi dữ liệu thành công cho SBD: 05000891
# Đã ghi dữ liệu thành công cho SBD: 05000892
# Đã ghi dữ liệu thành công cho SBD: 05000893
# Đã ghi dữ liệu thành công cho SBD: 05000894
# Đã ghi dữ liệu thành công cho SBD: 05000895
# Đã ghi dữ liệu thành công cho SBD: 05000896
# Đã ghi dữ liệu thành công cho SBD: 05000897
# Đã ghi dữ liệu thành công cho SBD: 05000898
# Đã ghi dữ liệu thành công cho SBD: 05000899
# Đã ghi dữ liệu thành công cho SBD: 05000900
# Đã ghi dữ liệu thành công cho SBD: 05000901
# Đã ghi dữ liệu thành công cho SBD: 05000902
# Đã ghi dữ liệu thành công cho SBD: 05000903
# Đã ghi dữ liệu thành công cho SBD: 05000904
# Đã ghi dữ liệu thành công cho SBD: 05000905
# Đã ghi dữ liệu thành công cho SBD: 05000906
# Đã ghi dữ liệu thành công cho SBD: 05000907
# Đã ghi dữ liệu thành công cho SBD: 05000908
# Đã ghi dữ liệu thành công cho SBD: 05000909
# Đã ghi dữ liệu thành công cho SBD: 05000910
# Đã ghi dữ liệu thành công cho SBD: 05000911
# Đã ghi dữ liệu thành công cho SBD: 05000912
# Đã ghi dữ liệu thành công cho SBD: 05000913
# Đã ghi dữ liệu thành công cho SBD: 05000914
# Đã ghi dữ liệu thành công cho SBD: 05000915
# Đã ghi dữ liệu thành công cho SBD: 05000916
# Đã ghi dữ liệu thành công cho SBD: 05000917
# Đã ghi dữ liệu thành công cho SBD: 05000918
# Đã ghi dữ liệu thành công cho SBD: 05000919
# Đã ghi dữ liệu thành công cho SBD: 05000920
# Đã ghi dữ liệu thành công cho SBD: 05000921
# Đã ghi dữ liệu thành công cho SBD: 05000922
# Đã ghi dữ liệu thành công cho SBD: 05000923
# Đã ghi dữ liệu thành công cho SBD: 05000924
# Đã ghi dữ liệu thành công cho SBD: 05000925
# Đã ghi dữ liệu thành công cho SBD: 05000926
# Đã ghi dữ liệu thành công cho SBD: 05000927
# Đã ghi dữ liệu thành công cho SBD: 05000928
# Đã ghi dữ liệu thành công cho SBD: 05000929
# Đã ghi dữ liệu thành công cho SBD: 05000930
# Đã ghi dữ liệu thành công cho SBD: 05000931
# Đã ghi dữ liệu thành công cho SBD: 05000932
# Đã ghi dữ liệu thành công cho SBD: 05000933
# Đã ghi dữ liệu thành công cho SBD: 05000934
# Đã ghi dữ liệu thành công cho SBD: 05000935
# Đã ghi dữ liệu thành công cho SBD: 05000936
# Đã ghi dữ liệu thành công cho SBD: 05000937
# Đã ghi dữ liệu thành công cho SBD: 05000938
# Đã ghi dữ liệu thành công cho SBD: 05000939
# Đã ghi dữ liệu thành công cho SBD: 05000940
# Đã ghi dữ liệu thành công cho SBD: 05000941
# Đã ghi dữ liệu thành công cho SBD: 05000942
# Đã ghi dữ liệu thành công cho SBD: 05000943
# Đã ghi dữ liệu thành công cho SBD: 05000944
# Đã ghi dữ liệu thành công cho SBD: 05000945
# Đã ghi dữ liệu thành công cho SBD: 05000946
# Đã ghi dữ liệu thành công cho SBD: 05000947
# Đã ghi dữ liệu thành công cho SBD: 05000948
# Đã ghi dữ liệu thành công cho SBD: 05000949
# Đã ghi dữ liệu thành công cho SBD: 05000950
# Đã ghi dữ liệu thành công cho SBD: 05000951
# Đã ghi dữ liệu thành công cho SBD: 05000952
# Đã ghi dữ liệu thành công cho SBD: 05000953
# Đã ghi dữ liệu thành công cho SBD: 05000954
# Đã ghi dữ liệu thành công cho SBD: 05000955
# Đã ghi dữ liệu thành công cho SBD: 05000956
# Đã ghi dữ liệu thành công cho SBD: 05000957
# Đã ghi dữ liệu thành công cho SBD: 05000958
# Đã ghi dữ liệu thành công cho SBD: 05000959
# Đã ghi dữ liệu thành công cho SBD: 05000960
# Đã ghi dữ liệu thành công cho SBD: 05000961
# Đã ghi dữ liệu thành công cho SBD: 05000962
# Đã ghi dữ liệu thành công cho SBD: 05000963
# Đã ghi dữ liệu thành công cho SBD: 05000964
# Đã ghi dữ liệu thành công cho SBD: 05000965
# Đã ghi dữ liệu thành công cho SBD: 05000966
# Đã ghi dữ liệu thành công cho SBD: 05000967
# Đã ghi dữ liệu thành công cho SBD: 05000968
# Đã ghi dữ liệu thành công cho SBD: 05000969
# Đã ghi dữ liệu thành công cho SBD: 05000970
# Đã ghi dữ liệu thành công cho SBD: 05000971
# Đã ghi dữ liệu thành công cho SBD: 05000972
# Đã ghi dữ liệu thành công cho SBD: 05000973
# Đã ghi dữ liệu thành công cho SBD: 05000974
# Đã ghi dữ liệu thành công cho SBD: 05000975
# Đã ghi dữ liệu thành công cho SBD: 05000976
# Đã ghi dữ liệu thành công cho SBD: 05000977
# Đã ghi dữ liệu thành công cho SBD: 05000978
# Đã ghi dữ liệu thành công cho SBD: 05000979
# Đã ghi dữ liệu thành công cho SBD: 05000980
# Đã ghi dữ liệu thành công cho SBD: 05000981
# Đã ghi dữ liệu thành công cho SBD: 05000982
# Đã ghi dữ liệu thành công cho SBD: 05000983
# Đã ghi dữ liệu thành công cho SBD: 05000984
# Đã ghi dữ liệu thành công cho SBD: 05000985
# Đã ghi dữ liệu thành công cho SBD: 05000986
# Đã ghi dữ liệu thành công cho SBD: 05000987
# Đã ghi dữ liệu thành công cho SBD: 05000988
# Đã ghi dữ liệu thành công cho SBD: 05000989
# Đã ghi dữ liệu thành công cho SBD: 05000990
# Đã ghi dữ liệu thành công cho SBD: 05000991
# Đã ghi dữ liệu thành công cho SBD: 05000992
# Đã ghi dữ liệu thành công cho SBD: 05000993
# Đã ghi dữ liệu thành công cho SBD: 05000994
# Đã ghi dữ liệu thành công cho SBD: 05000995
# Đã ghi dữ liệu thành công cho SBD: 05000996
# Đã ghi dữ liệu thành công cho SBD: 05000997
# Đã ghi dữ liệu thành công cho SBD: 05000998
# Đã ghi dữ liệu thành công cho SBD: 05000999
# Đã ghi dữ liệu thành công cho SBD: 05001000
# Đã ghi dữ liệu thành công cho SBD: 05001001
# Đã ghi dữ liệu thành công cho SBD: 05001002
# Đã ghi dữ liệu thành công cho SBD: 05001003
# Đã ghi dữ liệu thành công cho SBD: 05001004
# Đã ghi dữ liệu thành công cho SBD: 05001005
# Đã ghi dữ liệu thành công cho SBD: 05001006
# Đã ghi dữ liệu thành công cho SBD: 05001007
# Đã ghi dữ liệu thành công cho SBD: 05001008
# Đã ghi dữ liệu thành công cho SBD: 05001009
# Đã ghi dữ liệu thành công cho SBD: 05001010
# Đã ghi dữ liệu thành công cho SBD: 05001011
# Đã ghi dữ liệu thành công cho SBD: 05001012
# Đã ghi dữ liệu thành công cho SBD: 05001013
# Đã ghi dữ liệu thành công cho SBD: 05001014
# Đã ghi dữ liệu thành công cho SBD: 05001015
# Đã ghi dữ liệu thành công cho SBD: 05001016
# Đã ghi dữ liệu thành công cho SBD: 05001017
# Đã ghi dữ liệu thành công cho SBD: 05001018
# Đã ghi dữ liệu thành công cho SBD: 05001019
# Đã ghi dữ liệu thành công cho SBD: 05001020
# Đã ghi dữ liệu thành công cho SBD: 05001021
# Đã ghi dữ liệu thành công cho SBD: 05001022
# Đã ghi dữ liệu thành công cho SBD: 05001023
# Đã ghi dữ liệu thành công cho SBD: 05001024
# Đã ghi dữ liệu thành công cho SBD: 05001025
# Đã ghi dữ liệu thành công cho SBD: 05001026
# Đã ghi dữ liệu thành công cho SBD: 05001027
# Đã ghi dữ liệu thành công cho SBD: 05001028
# Đã ghi dữ liệu thành công cho SBD: 05001029
# Đã ghi dữ liệu thành công cho SBD: 05001030
# Đã ghi dữ liệu thành công cho SBD: 05001031
# Đã ghi dữ liệu thành công cho SBD: 05001032
# Đã ghi dữ liệu thành công cho SBD: 05001033
# Đã ghi dữ liệu thành công cho SBD: 05001034
# Đã ghi dữ liệu thành công cho SBD: 05001035
# Đã ghi dữ liệu thành công cho SBD: 05001036
# Đã ghi dữ liệu thành công cho SBD: 05001037
# Đã ghi dữ liệu thành công cho SBD: 05001038
# Đã ghi dữ liệu thành công cho SBD: 05001039
# Đã ghi dữ liệu thành công cho SBD: 05001040
# Đã ghi dữ liệu thành công cho SBD: 05001041
# Đã ghi dữ liệu thành công cho SBD: 05001042
# Đã ghi dữ liệu thành công cho SBD: 05001043
# Đã ghi dữ liệu thành công cho SBD: 05001044
# Đã ghi dữ liệu thành công cho SBD: 05001045
# Đã ghi dữ liệu thành công cho SBD: 05001046
# Đã ghi dữ liệu thành công cho SBD: 05001047
# Đã ghi dữ liệu thành công cho SBD: 05001048
# Đã ghi dữ liệu thành công cho SBD: 05001049
# Đã ghi dữ liệu thành công cho SBD: 05001050
# Đã ghi dữ liệu thành công cho SBD: 05001051
# Đã ghi dữ liệu thành công cho SBD: 05001052
# Đã ghi dữ liệu thành công cho SBD: 05001053
# Đã ghi dữ liệu thành công cho SBD: 05001054
# Đã ghi dữ liệu thành công cho SBD: 05001055
# Đã ghi dữ liệu thành công cho SBD: 05001056
# Đã ghi dữ liệu thành công cho SBD: 05001057
# Đã ghi dữ liệu thành công cho SBD: 05001058
# Đã ghi dữ liệu thành công cho SBD: 05001059
# Đã ghi dữ liệu thành công cho SBD: 05001060
# Đã ghi dữ liệu thành công cho SBD: 05001061
# Đã ghi dữ liệu thành công cho SBD: 05001062
# Đã ghi dữ liệu thành công cho SBD: 05001063
# Đã ghi dữ liệu thành công cho SBD: 05001064
# Đã ghi dữ liệu thành công cho SBD: 05001065
# Đã ghi dữ liệu thành công cho SBD: 05001066
# Đã ghi dữ liệu thành công cho SBD: 05001067
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 05001069
# Đã ghi dữ liệu thành công cho SBD: 05001070
# Đã ghi dữ liệu thành công cho SBD: 05001071
# Đã ghi dữ liệu thành công cho SBD: 05001072
# Đã ghi dữ liệu thành công cho SBD: 05001073
# Đã ghi dữ liệu thành công cho SBD: 05001074
# Đã ghi dữ liệu thành công cho SBD: 05001075
# Đã ghi dữ liệu thành công cho SBD: 05001076
# Đã ghi dữ liệu thành công cho SBD: 05001077
# Đã ghi dữ liệu thành công cho SBD: 05001078
# Đã ghi dữ liệu thành công cho SBD: 05001079
# Đã ghi dữ liệu thành công cho SBD: 05001080
# Đã ghi dữ liệu thành công cho SBD: 05001081
# Đã ghi dữ liệu thành công cho SBD: 05001082
# Đã ghi dữ liệu thành công cho SBD: 05001083
# Đã ghi dữ liệu thành công cho SBD: 05001084
# Đã ghi dữ liệu thành công cho SBD: 05001085
# Đã ghi dữ liệu thành công cho SBD: 05001086
# Đã ghi dữ liệu thành công cho SBD: 05001087
# Đã ghi dữ liệu thành công cho SBD: 05001088
# Đã ghi dữ liệu thành công cho SBD: 05001089
# Đã ghi dữ liệu thành công cho SBD: 05001090
# Đã ghi dữ liệu thành công cho SBD: 05001091
# ...
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 66
#      63     print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
#      65 # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
# ---> 66 time.sleep(0.4)
#
# KeyboardInterrupt:

# %%
import requests
import time
import csv

# Đường dẫn đến file CSV
file_path = r"E:\\DA\\Crawl\\06_CaoBang.csv"

# Mở file CSV để ghi dữ liệu
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Ghi tiêu đề cột
    writer.writerow([
        'SBD', 'Toan', 'Van', 'NgoaiNgu', 'VatLy', 'HoaHoc', 'SinhHoc',
        'TBKHTN', 'LichSu', 'DiaLy', 'GDCD', 'TBKHXH'
    ])
    
    # Vòng lặp lấy dữ liệu
    for x in range(6000001, 7000001):
        scraping_url = f"https://dantri.com.vn/thpt/1/0/99/{x}/2024/0.2/search-gradle.htm"
        
        try:
            # Gửi yêu cầu
            response = requests.get(scraping_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            
            # Phân tích phản hồi JSON
            data = response.json()
            
            # Kiểm tra nếu có khóa 'student' trong phản hồi
            if 'student' in data:
                info = data['student']
                
                # Ghi dữ liệu vào file CSV
                writer.writerow([
                    info.get('sbd', 'None'),
                    info.get('toan', 'None'),
                    info.get('van', 'None'),
                    info.get('ngoaiNgu', 'None'),
                    info.get('vatLy', 'None'),
                    info.get('hoaHoc', 'None'),
                    info.get('sinhHoc', 'None'),
                    info.get('diemTBTuNhien', 'None'),
                    info.get('lichSu', 'None'),
                    info.get('diaLy', 'None'),
                    info.get('gdcd', 'None'),
                    info.get('diemTBXaHoi', 'None')
                ])
                
                # Hiển thị thông báo đã ghi dữ liệu thành công
                print(f"Đã ghi dữ liệu thành công cho SBD: {info.get('sbd', 'Unknown')}")

                # Đảm bảo dữ liệu được ghi vào tệp ngay lập tức
                file.flush()
            else:
                print(f"Không có khóa 'student' trong phản hồi cho URL: {scraping_url}")
            
        except requests.RequestException as e:
            print(f"Yêu cầu không thành công cho URL {scraping_url}: {e}")
        except ValueError as e:
            print(f"Lỗi khi phân tích cú pháp JSON cho URL {scraping_url}: {e}")
        except csv.Error as e:
            print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
        
        # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
        time.sleep(0.4)
# Out:
# Đã ghi dữ liệu thành công cho SBD: 06000001
# Đã ghi dữ liệu thành công cho SBD: 06000002
# Đã ghi dữ liệu thành công cho SBD: 06000003
# Đã ghi dữ liệu thành công cho SBD: 06000004
# Đã ghi dữ liệu thành công cho SBD: 06000005
# Đã ghi dữ liệu thành công cho SBD: 06000006
# Đã ghi dữ liệu thành công cho SBD: 06000007
# Đã ghi dữ liệu thành công cho SBD: 06000008
# Đã ghi dữ liệu thành công cho SBD: 06000009
# Đã ghi dữ liệu thành công cho SBD: 06000010
# Đã ghi dữ liệu thành công cho SBD: 06000011
# Đã ghi dữ liệu thành công cho SBD: 06000012
# Đã ghi dữ liệu thành công cho SBD: 06000013
# Đã ghi dữ liệu thành công cho SBD: 06000014
# Đã ghi dữ liệu thành công cho SBD: 06000015
# Đã ghi dữ liệu thành công cho SBD: 06000016
# Đã ghi dữ liệu thành công cho SBD: 06000017
# Đã ghi dữ liệu thành công cho SBD: 06000018
# Đã ghi dữ liệu thành công cho SBD: 06000019
# Đã ghi dữ liệu thành công cho SBD: 06000020
# Đã ghi dữ liệu thành công cho SBD: 06000021
# Đã ghi dữ liệu thành công cho SBD: 06000022
# Đã ghi dữ liệu thành công cho SBD: 06000023
# Đã ghi dữ liệu thành công cho SBD: 06000024
# Đã ghi dữ liệu thành công cho SBD: 06000025
# Đã ghi dữ liệu thành công cho SBD: 06000026
# Đã ghi dữ liệu thành công cho SBD: 06000027
# Đã ghi dữ liệu thành công cho SBD: 06000028
# Đã ghi dữ liệu thành công cho SBD: 06000029
# Đã ghi dữ liệu thành công cho SBD: 06000030
# Đã ghi dữ liệu thành công cho SBD: 06000031
# Đã ghi dữ liệu thành công cho SBD: 06000032
# Đã ghi dữ liệu thành công cho SBD: 06000033
# Đã ghi dữ liệu thành công cho SBD: 06000034
# Đã ghi dữ liệu thành công cho SBD: 06000035
# Đã ghi dữ liệu thành công cho SBD: 06000036
# Đã ghi dữ liệu thành công cho SBD: 06000037
# Đã ghi dữ liệu thành công cho SBD: 06000038
# Đã ghi dữ liệu thành công cho SBD: 06000039
# Đã ghi dữ liệu thành công cho SBD: 06000040
# Đã ghi dữ liệu thành công cho SBD: 06000041
# Đã ghi dữ liệu thành công cho SBD: 06000042
# Đã ghi dữ liệu thành công cho SBD: 06000043
# Đã ghi dữ liệu thành công cho SBD: 06000044
# Đã ghi dữ liệu thành công cho SBD: 06000045
# Đã ghi dữ liệu thành công cho SBD: 06000046
# Đã ghi dữ liệu thành công cho SBD: 06000047
# Đã ghi dữ liệu thành công cho SBD: 06000048
# Đã ghi dữ liệu thành công cho SBD: 06000049
# Đã ghi dữ liệu thành công cho SBD: 06000050
# Đã ghi dữ liệu thành công cho SBD: 06000051
# Đã ghi dữ liệu thành công cho SBD: 06000052
# Đã ghi dữ liệu thành công cho SBD: 06000053
# Đã ghi dữ liệu thành công cho SBD: 06000054
# Đã ghi dữ liệu thành công cho SBD: 06000055
# Đã ghi dữ liệu thành công cho SBD: 06000056
# Đã ghi dữ liệu thành công cho SBD: 06000057
# Đã ghi dữ liệu thành công cho SBD: 06000058
# Đã ghi dữ liệu thành công cho SBD: 06000059
# Đã ghi dữ liệu thành công cho SBD: 06000060
# Đã ghi dữ liệu thành công cho SBD: 06000061
# Đã ghi dữ liệu thành công cho SBD: 06000062
# Đã ghi dữ liệu thành công cho SBD: 06000063
# Đã ghi dữ liệu thành công cho SBD: 06000064
# Đã ghi dữ liệu thành công cho SBD: 06000065
# Đã ghi dữ liệu thành công cho SBD: 06000066
# Đã ghi dữ liệu thành công cho SBD: 06000067
# Đã ghi dữ liệu thành công cho SBD: 06000068
# Đã ghi dữ liệu thành công cho SBD: 06000069
# Đã ghi dữ liệu thành công cho SBD: 06000070
# Đã ghi dữ liệu thành công cho SBD: 06000071
# Đã ghi dữ liệu thành công cho SBD: 06000072
# Đã ghi dữ liệu thành công cho SBD: 06000073
# Đã ghi dữ liệu thành công cho SBD: 06000074
# Đã ghi dữ liệu thành công cho SBD: 06000075
# Đã ghi dữ liệu thành công cho SBD: 06000076
# Đã ghi dữ liệu thành công cho SBD: 06000077
# Đã ghi dữ liệu thành công cho SBD: 06000078
# Đã ghi dữ liệu thành công cho SBD: 06000079
# Đã ghi dữ liệu thành công cho SBD: 06000080
# Đã ghi dữ liệu thành công cho SBD: 06000081
# Đã ghi dữ liệu thành công cho SBD: 06000082
# Đã ghi dữ liệu thành công cho SBD: 06000083
# Đã ghi dữ liệu thành công cho SBD: 06000084
# Đã ghi dữ liệu thành công cho SBD: 06000085
# Đã ghi dữ liệu thành công cho SBD: 06000086
# Đã ghi dữ liệu thành công cho SBD: 06000087
# Đã ghi dữ liệu thành công cho SBD: 06000088
# Đã ghi dữ liệu thành công cho SBD: 06000089
# Đã ghi dữ liệu thành công cho SBD: 06000090
# Đã ghi dữ liệu thành công cho SBD: 06000091
# Đã ghi dữ liệu thành công cho SBD: 06000092
# Đã ghi dữ liệu thành công cho SBD: 06000093
# Đã ghi dữ liệu thành công cho SBD: 06000094
# Đã ghi dữ liệu thành công cho SBD: 06000095
# Đã ghi dữ liệu thành công cho SBD: 06000096
# Đã ghi dữ liệu thành công cho SBD: 06000097
# Đã ghi dữ liệu thành công cho SBD: 06000098
# Đã ghi dữ liệu thành công cho SBD: 06000099
# Đã ghi dữ liệu thành công cho SBD: 06000100
# Đã ghi dữ liệu thành công cho SBD: 06000101
# Đã ghi dữ liệu thành công cho SBD: 06000102
# Đã ghi dữ liệu thành công cho SBD: 06000103
# Đã ghi dữ liệu thành công cho SBD: 06000104
# Đã ghi dữ liệu thành công cho SBD: 06000105
# Đã ghi dữ liệu thành công cho SBD: 06000106
# Đã ghi dữ liệu thành công cho SBD: 06000107
# Đã ghi dữ liệu thành công cho SBD: 06000108
# Đã ghi dữ liệu thành công cho SBD: 06000109
# Đã ghi dữ liệu thành công cho SBD: 06000110
# Đã ghi dữ liệu thành công cho SBD: 06000111
# Đã ghi dữ liệu thành công cho SBD: 06000112
# Đã ghi dữ liệu thành công cho SBD: 06000113
# Đã ghi dữ liệu thành công cho SBD: 06000114
# Đã ghi dữ liệu thành công cho SBD: 06000115
# Đã ghi dữ liệu thành công cho SBD: 06000116
# Đã ghi dữ liệu thành công cho SBD: 06000117
# Đã ghi dữ liệu thành công cho SBD: 06000118
# Đã ghi dữ liệu thành công cho SBD: 06000119
# Đã ghi dữ liệu thành công cho SBD: 06000120
# Đã ghi dữ liệu thành công cho SBD: 06000121
# Đã ghi dữ liệu thành công cho SBD: 06000122
# Đã ghi dữ liệu thành công cho SBD: 06000123
# Đã ghi dữ liệu thành công cho SBD: 06000124
# Đã ghi dữ liệu thành công cho SBD: 06000125
# Đã ghi dữ liệu thành công cho SBD: 06000126
# Đã ghi dữ liệu thành công cho SBD: 06000127
# Đã ghi dữ liệu thành công cho SBD: 06000128
# Đã ghi dữ liệu thành công cho SBD: 06000129
# Đã ghi dữ liệu thành công cho SBD: 06000130
# Đã ghi dữ liệu thành công cho SBD: 06000131
# Đã ghi dữ liệu thành công cho SBD: 06000132
# Đã ghi dữ liệu thành công cho SBD: 06000133
# Đã ghi dữ liệu thành công cho SBD: 06000134
# Đã ghi dữ liệu thành công cho SBD: 06000135
# Đã ghi dữ liệu thành công cho SBD: 06000136
# Đã ghi dữ liệu thành công cho SBD: 06000137
# Đã ghi dữ liệu thành công cho SBD: 06000138
# Đã ghi dữ liệu thành công cho SBD: 06000139
# Đã ghi dữ liệu thành công cho SBD: 06000140
# Đã ghi dữ liệu thành công cho SBD: 06000141
# Đã ghi dữ liệu thành công cho SBD: 06000142
# Đã ghi dữ liệu thành công cho SBD: 06000143
# Đã ghi dữ liệu thành công cho SBD: 06000144
# Đã ghi dữ liệu thành công cho SBD: 06000145
# Đã ghi dữ liệu thành công cho SBD: 06000146
# Đã ghi dữ liệu thành công cho SBD: 06000147
# Đã ghi dữ liệu thành công cho SBD: 06000148
# Đã ghi dữ liệu thành công cho SBD: 06000149
# Đã ghi dữ liệu thành công cho SBD: 06000150
# Đã ghi dữ liệu thành công cho SBD: 06000151
# Đã ghi dữ liệu thành công cho SBD: 06000152
# Đã ghi dữ liệu thành công cho SBD: 06000153
# Đã ghi dữ liệu thành công cho SBD: 06000154
# Đã ghi dữ liệu thành công cho SBD: 06000155
# Đã ghi dữ liệu thành công cho SBD: 06000156
# Đã ghi dữ liệu thành công cho SBD: 06000157
# Đã ghi dữ liệu thành công cho SBD: 06000158
# Đã ghi dữ liệu thành công cho SBD: 06000159
# Đã ghi dữ liệu thành công cho SBD: 06000160
# Đã ghi dữ liệu thành công cho SBD: 06000161
# Đã ghi dữ liệu thành công cho SBD: 06000162
# Đã ghi dữ liệu thành công cho SBD: 06000163
# Đã ghi dữ liệu thành công cho SBD: 06000164
# Đã ghi dữ liệu thành công cho SBD: 06000165
# Đã ghi dữ liệu thành công cho SBD: 06000166
# Đã ghi dữ liệu thành công cho SBD: 06000167
# Đã ghi dữ liệu thành công cho SBD: 06000168
# Đã ghi dữ liệu thành công cho SBD: 06000169
# Đã ghi dữ liệu thành công cho SBD: 06000170
# Đã ghi dữ liệu thành công cho SBD: 06000171
# Đã ghi dữ liệu thành công cho SBD: 06000172
# Đã ghi dữ liệu thành công cho SBD: 06000173
# Đã ghi dữ liệu thành công cho SBD: 06000174
# Đã ghi dữ liệu thành công cho SBD: 06000175
# Đã ghi dữ liệu thành công cho SBD: 06000176
# Đã ghi dữ liệu thành công cho SBD: 06000177
# Đã ghi dữ liệu thành công cho SBD: 06000178
# Đã ghi dữ liệu thành công cho SBD: 06000179
# Đã ghi dữ liệu thành công cho SBD: 06000180
# Đã ghi dữ liệu thành công cho SBD: 06000181
# Đã ghi dữ liệu thành công cho SBD: 06000182
# Đã ghi dữ liệu thành công cho SBD: 06000183
# Đã ghi dữ liệu thành công cho SBD: 06000184
# Đã ghi dữ liệu thành công cho SBD: 06000185
# Đã ghi dữ liệu thành công cho SBD: 06000186
# Đã ghi dữ liệu thành công cho SBD: 06000187
# Đã ghi dữ liệu thành công cho SBD: 06000188
# Đã ghi dữ liệu thành công cho SBD: 06000189
# Đã ghi dữ liệu thành công cho SBD: 06000190
# Đã ghi dữ liệu thành công cho SBD: 06000191
# Đã ghi dữ liệu thành công cho SBD: 06000192
# Đã ghi dữ liệu thành công cho SBD: 06000193
# Đã ghi dữ liệu thành công cho SBD: 06000194
# Đã ghi dữ liệu thành công cho SBD: 06000195
# Đã ghi dữ liệu thành công cho SBD: 06000196
# Đã ghi dữ liệu thành công cho SBD: 06000197
# Đã ghi dữ liệu thành công cho SBD: 06000198
# Đã ghi dữ liệu thành công cho SBD: 06000199
# Đã ghi dữ liệu thành công cho SBD: 06000200
# Đã ghi dữ liệu thành công cho SBD: 06000201
# Đã ghi dữ liệu thành công cho SBD: 06000202
# Đã ghi dữ liệu thành công cho SBD: 06000203
# Đã ghi dữ liệu thành công cho SBD: 06000204
# Đã ghi dữ liệu thành công cho SBD: 06000205
# Đã ghi dữ liệu thành công cho SBD: 06000206
# Đã ghi dữ liệu thành công cho SBD: 06000207
# Đã ghi dữ liệu thành công cho SBD: 06000208
# Đã ghi dữ liệu thành công cho SBD: 06000209
# Đã ghi dữ liệu thành công cho SBD: 06000210
# Đã ghi dữ liệu thành công cho SBD: 06000211
# Đã ghi dữ liệu thành công cho SBD: 06000212
# Đã ghi dữ liệu thành công cho SBD: 06000213
# Đã ghi dữ liệu thành công cho SBD: 06000214
# Đã ghi dữ liệu thành công cho SBD: 06000215
# Đã ghi dữ liệu thành công cho SBD: 06000216
# Đã ghi dữ liệu thành công cho SBD: 06000217
# Đã ghi dữ liệu thành công cho SBD: 06000218
# Đã ghi dữ liệu thành công cho SBD: 06000219
# Đã ghi dữ liệu thành công cho SBD: 06000220
# Đã ghi dữ liệu thành công cho SBD: 06000221
# Đã ghi dữ liệu thành công cho SBD: 06000222
# Đã ghi dữ liệu thành công cho SBD: 06000223
# Đã ghi dữ liệu thành công cho SBD: 06000224
# Đã ghi dữ liệu thành công cho SBD: 06000225
# Đã ghi dữ liệu thành công cho SBD: 06000226
# Đã ghi dữ liệu thành công cho SBD: 06000227
# Đã ghi dữ liệu thành công cho SBD: 06000228
# Đã ghi dữ liệu thành công cho SBD: 06000229
# Đã ghi dữ liệu thành công cho SBD: 06000230
# Đã ghi dữ liệu thành công cho SBD: 06000231
# Đã ghi dữ liệu thành công cho SBD: 06000232
# Đã ghi dữ liệu thành công cho SBD: 06000233
# Đã ghi dữ liệu thành công cho SBD: 06000234
# Đã ghi dữ liệu thành công cho SBD: 06000235
# Đã ghi dữ liệu thành công cho SBD: 06000236
# Đã ghi dữ liệu thành công cho SBD: 06000237
# Đã ghi dữ liệu thành công cho SBD: 06000238
# Đã ghi dữ liệu thành công cho SBD: 06000239
# Đã ghi dữ liệu thành công cho SBD: 06000240
# Đã ghi dữ liệu thành công cho SBD: 06000241
# Đã ghi dữ liệu thành công cho SBD: 06000242
# Đã ghi dữ liệu thành công cho SBD: 06000243
# Đã ghi dữ liệu thành công cho SBD: 06000244
# Đã ghi dữ liệu thành công cho SBD: 06000245
# Đã ghi dữ liệu thành công cho SBD: 06000246
# Đã ghi dữ liệu thành công cho SBD: 06000247
# Đã ghi dữ liệu thành công cho SBD: 06000248
# Đã ghi dữ liệu thành công cho SBD: 06000249
# Đã ghi dữ liệu thành công cho SBD: 06000250
# Đã ghi dữ liệu thành công cho SBD: 06000251
# Đã ghi dữ liệu thành công cho SBD: 06000252
# Đã ghi dữ liệu thành công cho SBD: 06000253
# Đã ghi dữ liệu thành công cho SBD: 06000254
# Đã ghi dữ liệu thành công cho SBD: 06000255
# Đã ghi dữ liệu thành công cho SBD: 06000256
# Đã ghi dữ liệu thành công cho SBD: 06000257
# Đã ghi dữ liệu thành công cho SBD: 06000258
# Đã ghi dữ liệu thành công cho SBD: 06000259
# Đã ghi dữ liệu thành công cho SBD: 06000260
# Đã ghi dữ liệu thành công cho SBD: 06000261
# Đã ghi dữ liệu thành công cho SBD: 06000262
# Đã ghi dữ liệu thành công cho SBD: 06000263
# Đã ghi dữ liệu thành công cho SBD: 06000264
# Đã ghi dữ liệu thành công cho SBD: 06000265
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 06000267
# Đã ghi dữ liệu thành công cho SBD: 06000268
# Đã ghi dữ liệu thành công cho SBD: 06000269
# Đã ghi dữ liệu thành công cho SBD: 06000270
# Đã ghi dữ liệu thành công cho SBD: 06000271
# Đã ghi dữ liệu thành công cho SBD: 06000272
# Đã ghi dữ liệu thành công cho SBD: 06000273
# Đã ghi dữ liệu thành công cho SBD: 06000274
# Đã ghi dữ liệu thành công cho SBD: 06000275
# Đã ghi dữ liệu thành công cho SBD: 06000276
# Đã ghi dữ liệu thành công cho SBD: 06000277
# Đã ghi dữ liệu thành công cho SBD: 06000278
# Đã ghi dữ liệu thành công cho SBD: 06000279
# Đã ghi dữ liệu thành công cho SBD: 06000280
# Đã ghi dữ liệu thành công cho SBD: 06000281
# Đã ghi dữ liệu thành công cho SBD: 06000282
# Đã ghi dữ liệu thành công cho SBD: 06000283
# Đã ghi dữ liệu thành công cho SBD: 06000284
# Đã ghi dữ liệu thành công cho SBD: 06000285
# Đã ghi dữ liệu thành công cho SBD: 06000286
# Đã ghi dữ liệu thành công cho SBD: 06000287
# Đã ghi dữ liệu thành công cho SBD: 06000288
# Đã ghi dữ liệu thành công cho SBD: 06000289
# Đã ghi dữ liệu thành công cho SBD: 06000290
# Đã ghi dữ liệu thành công cho SBD: 06000291
# Đã ghi dữ liệu thành công cho SBD: 06000292
# Đã ghi dữ liệu thành công cho SBD: 06000293
# Đã ghi dữ liệu thành công cho SBD: 06000294
# Đã ghi dữ liệu thành công cho SBD: 06000295
# Đã ghi dữ liệu thành công cho SBD: 06000296
# Đã ghi dữ liệu thành công cho SBD: 06000297
# Đã ghi dữ liệu thành công cho SBD: 06000298
# Đã ghi dữ liệu thành công cho SBD: 06000299
# Đã ghi dữ liệu thành công cho SBD: 06000300
# Đã ghi dữ liệu thành công cho SBD: 06000301
# Đã ghi dữ liệu thành công cho SBD: 06000302
# Đã ghi dữ liệu thành công cho SBD: 06000303
# Đã ghi dữ liệu thành công cho SBD: 06000304
# Đã ghi dữ liệu thành công cho SBD: 06000305
# Đã ghi dữ liệu thành công cho SBD: 06000306
# Đã ghi dữ liệu thành công cho SBD: 06000307
# Đã ghi dữ liệu thành công cho SBD: 06000308
# Đã ghi dữ liệu thành công cho SBD: 06000309
# Đã ghi dữ liệu thành công cho SBD: 06000310
# Đã ghi dữ liệu thành công cho SBD: 06000311
# Đã ghi dữ liệu thành công cho SBD: 06000312
# Đã ghi dữ liệu thành công cho SBD: 06000313
# Đã ghi dữ liệu thành công cho SBD: 06000314
# Đã ghi dữ liệu thành công cho SBD: 06000315
# Đã ghi dữ liệu thành công cho SBD: 06000316
# Đã ghi dữ liệu thành công cho SBD: 06000317
# Đã ghi dữ liệu thành công cho SBD: 06000318
# Đã ghi dữ liệu thành công cho SBD: 06000319
# Đã ghi dữ liệu thành công cho SBD: 06000320
# Đã ghi dữ liệu thành công cho SBD: 06000321
# Đã ghi dữ liệu thành công cho SBD: 06000322
# Đã ghi dữ liệu thành công cho SBD: 06000323
# Đã ghi dữ liệu thành công cho SBD: 06000324
# Đã ghi dữ liệu thành công cho SBD: 06000325
# Đã ghi dữ liệu thành công cho SBD: 06000326
# Đã ghi dữ liệu thành công cho SBD: 06000327
# Đã ghi dữ liệu thành công cho SBD: 06000328
# Đã ghi dữ liệu thành công cho SBD: 06000329
# Đã ghi dữ liệu thành công cho SBD: 06000330
# Đã ghi dữ liệu thành công cho SBD: 06000331
# Đã ghi dữ liệu thành công cho SBD: 06000332
# Đã ghi dữ liệu thành công cho SBD: 06000333
# Đã ghi dữ liệu thành công cho SBD: 06000334
# Đã ghi dữ liệu thành công cho SBD: 06000335
# Đã ghi dữ liệu thành công cho SBD: 06000336
# Đã ghi dữ liệu thành công cho SBD: 06000337
# Đã ghi dữ liệu thành công cho SBD: 06000338
# Đã ghi dữ liệu thành công cho SBD: 06000339
# Đã ghi dữ liệu thành công cho SBD: 06000340
# Đã ghi dữ liệu thành công cho SBD: 06000341
# Đã ghi dữ liệu thành công cho SBD: 06000342
# Đã ghi dữ liệu thành công cho SBD: 06000343
# Đã ghi dữ liệu thành công cho SBD: 06000344
# Đã ghi dữ liệu thành công cho SBD: 06000345
# Đã ghi dữ liệu thành công cho SBD: 06000346
# Đã ghi dữ liệu thành công cho SBD: 06000347
# Đã ghi dữ liệu thành công cho SBD: 06000348
# Đã ghi dữ liệu thành công cho SBD: 06000349
# Đã ghi dữ liệu thành công cho SBD: 06000350
# Đã ghi dữ liệu thành công cho SBD: 06000351
# Đã ghi dữ liệu thành công cho SBD: 06000352
# Đã ghi dữ liệu thành công cho SBD: 06000353
# Đã ghi dữ liệu thành công cho SBD: 06000354
# Đã ghi dữ liệu thành công cho SBD: 06000355
# Đã ghi dữ liệu thành công cho SBD: 06000356
# Đã ghi dữ liệu thành công cho SBD: 06000357
# Đã ghi dữ liệu thành công cho SBD: 06000358
# Đã ghi dữ liệu thành công cho SBD: 06000359
# Đã ghi dữ liệu thành công cho SBD: 06000360
# Đã ghi dữ liệu thành công cho SBD: 06000361
# Đã ghi dữ liệu thành công cho SBD: 06000362
# Đã ghi dữ liệu thành công cho SBD: 06000363
# Đã ghi dữ liệu thành công cho SBD: 06000364
# Đã ghi dữ liệu thành công cho SBD: 06000365
# Đã ghi dữ liệu thành công cho SBD: 06000366
# Đã ghi dữ liệu thành công cho SBD: 06000367
# Đã ghi dữ liệu thành công cho SBD: 06000368
# Đã ghi dữ liệu thành công cho SBD: 06000369
# Đã ghi dữ liệu thành công cho SBD: 06000370
# Đã ghi dữ liệu thành công cho SBD: 06000371
# Đã ghi dữ liệu thành công cho SBD: 06000372
# Đã ghi dữ liệu thành công cho SBD: 06000373
# Đã ghi dữ liệu thành công cho SBD: 06000374
# Đã ghi dữ liệu thành công cho SBD: 06000375
# Đã ghi dữ liệu thành công cho SBD: 06000376
# Đã ghi dữ liệu thành công cho SBD: 06000377
# Đã ghi dữ liệu thành công cho SBD: 06000378
# Đã ghi dữ liệu thành công cho SBD: 06000379
# Đã ghi dữ liệu thành công cho SBD: 06000380
# Đã ghi dữ liệu thành công cho SBD: 06000381
# Đã ghi dữ liệu thành công cho SBD: 06000382
# Đã ghi dữ liệu thành công cho SBD: 06000383
# Đã ghi dữ liệu thành công cho SBD: 06000384
# Đã ghi dữ liệu thành công cho SBD: 06000385
# Đã ghi dữ liệu thành công cho SBD: 06000386
# Đã ghi dữ liệu thành công cho SBD: 06000387
# Đã ghi dữ liệu thành công cho SBD: 06000388
# Đã ghi dữ liệu thành công cho SBD: 06000389
# Đã ghi dữ liệu thành công cho SBD: 06000390
# Đã ghi dữ liệu thành công cho SBD: 06000391
# Đã ghi dữ liệu thành công cho SBD: 06000392
# Đã ghi dữ liệu thành công cho SBD: 06000393
# Đã ghi dữ liệu thành công cho SBD: 06000394
# Đã ghi dữ liệu thành công cho SBD: 06000395
# Đã ghi dữ liệu thành công cho SBD: 06000396
# Đã ghi dữ liệu thành công cho SBD: 06000397
# Đã ghi dữ liệu thành công cho SBD: 06000398
# Đã ghi dữ liệu thành công cho SBD: 06000399
# Đã ghi dữ liệu thành công cho SBD: 06000400
# Đã ghi dữ liệu thành công cho SBD: 06000401
# Đã ghi dữ liệu thành công cho SBD: 06000402
# Đã ghi dữ liệu thành công cho SBD: 06000403
# Đã ghi dữ liệu thành công cho SBD: 06000404
# Đã ghi dữ liệu thành công cho SBD: 06000405
# Đã ghi dữ liệu thành công cho SBD: 06000406
# Đã ghi dữ liệu thành công cho SBD: 06000407
# Đã ghi dữ liệu thành công cho SBD: 06000408
# Đã ghi dữ liệu thành công cho SBD: 06000409
# Đã ghi dữ liệu thành công cho SBD: 06000410
# Đã ghi dữ liệu thành công cho SBD: 06000411
# Đã ghi dữ liệu thành công cho SBD: 06000412
# Đã ghi dữ liệu thành công cho SBD: 06000413
# Đã ghi dữ liệu thành công cho SBD: 06000414
# Đã ghi dữ liệu thành công cho SBD: 06000415
# Đã ghi dữ liệu thành công cho SBD: 06000416
# Đã ghi dữ liệu thành công cho SBD: 06000417
# Đã ghi dữ liệu thành công cho SBD: 06000418
# Đã ghi dữ liệu thành công cho SBD: 06000419
# Đã ghi dữ liệu thành công cho SBD: 06000420
# Đã ghi dữ liệu thành công cho SBD: 06000421
# Đã ghi dữ liệu thành công cho SBD: 06000422
# Đã ghi dữ liệu thành công cho SBD: 06000423
# Đã ghi dữ liệu thành công cho SBD: 06000424
# Đã ghi dữ liệu thành công cho SBD: 06000425
# Đã ghi dữ liệu thành công cho SBD: 06000426
# Đã ghi dữ liệu thành công cho SBD: 06000427
# Đã ghi dữ liệu thành công cho SBD: 06000428
# Đã ghi dữ liệu thành công cho SBD: 06000429
# Đã ghi dữ liệu thành công cho SBD: 06000430
# Đã ghi dữ liệu thành công cho SBD: 06000431
# Đã ghi dữ liệu thành công cho SBD: 06000432
# Đã ghi dữ liệu thành công cho SBD: 06000433
# Đã ghi dữ liệu thành công cho SBD: 06000434
# Đã ghi dữ liệu thành công cho SBD: 06000435
# Đã ghi dữ liệu thành công cho SBD: 06000436
# Đã ghi dữ liệu thành công cho SBD: 06000437
# Đã ghi dữ liệu thành công cho SBD: 06000438
# Đã ghi dữ liệu thành công cho SBD: 06000439
# Đã ghi dữ liệu thành công cho SBD: 06000440
# Đã ghi dữ liệu thành công cho SBD: 06000441
# Đã ghi dữ liệu thành công cho SBD: 06000442
# Đã ghi dữ liệu thành công cho SBD: 06000443
# Đã ghi dữ liệu thành công cho SBD: 06000444
# Đã ghi dữ liệu thành công cho SBD: 06000445
# Đã ghi dữ liệu thành công cho SBD: 06000446
# Đã ghi dữ liệu thành công cho SBD: 06000447
# Đã ghi dữ liệu thành công cho SBD: 06000448
# Đã ghi dữ liệu thành công cho SBD: 06000449
# Đã ghi dữ liệu thành công cho SBD: 06000450
# Đã ghi dữ liệu thành công cho SBD: 06000451
# Đã ghi dữ liệu thành công cho SBD: 06000452
# Đã ghi dữ liệu thành công cho SBD: 06000453
# Đã ghi dữ liệu thành công cho SBD: 06000454
# Đã ghi dữ liệu thành công cho SBD: 06000455
# Đã ghi dữ liệu thành công cho SBD: 06000456
# Đã ghi dữ liệu thành công cho SBD: 06000457
# Đã ghi dữ liệu thành công cho SBD: 06000458
# Đã ghi dữ liệu thành công cho SBD: 06000459
# Đã ghi dữ liệu thành công cho SBD: 06000460
# Đã ghi dữ liệu thành công cho SBD: 06000461
# Đã ghi dữ liệu thành công cho SBD: 06000462
# Đã ghi dữ liệu thành công cho SBD: 06000463
# Đã ghi dữ liệu thành công cho SBD: 06000464
# Đã ghi dữ liệu thành công cho SBD: 06000465
# Đã ghi dữ liệu thành công cho SBD: 06000466
# Đã ghi dữ liệu thành công cho SBD: 06000467
# Đã ghi dữ liệu thành công cho SBD: 06000468
# Đã ghi dữ liệu thành công cho SBD: 06000469
# Đã ghi dữ liệu thành công cho SBD: 06000470
# Đã ghi dữ liệu thành công cho SBD: 06000471
# Đã ghi dữ liệu thành công cho SBD: 06000472
# Đã ghi dữ liệu thành công cho SBD: 06000473
# Đã ghi dữ liệu thành công cho SBD: 06000474
# Đã ghi dữ liệu thành công cho SBD: 06000475
# Đã ghi dữ liệu thành công cho SBD: 06000476
# Đã ghi dữ liệu thành công cho SBD: 06000477
# Đã ghi dữ liệu thành công cho SBD: 06000478
# Đã ghi dữ liệu thành công cho SBD: 06000479
# Đã ghi dữ liệu thành công cho SBD: 06000480
# Đã ghi dữ liệu thành công cho SBD: 06000481
# Đã ghi dữ liệu thành công cho SBD: 06000482
# Đã ghi dữ liệu thành công cho SBD: 06000483
# Đã ghi dữ liệu thành công cho SBD: 06000484
# Đã ghi dữ liệu thành công cho SBD: 06000485
# Đã ghi dữ liệu thành công cho SBD: 06000486
# Đã ghi dữ liệu thành công cho SBD: 06000487
# Đã ghi dữ liệu thành công cho SBD: 06000488
# Đã ghi dữ liệu thành công cho SBD: 06000489
# Đã ghi dữ liệu thành công cho SBD: 06000490
# Đã ghi dữ liệu thành công cho SBD: 06000491
# Đã ghi dữ liệu thành công cho SBD: 06000492
# Đã ghi dữ liệu thành công cho SBD: 06000493
# Đã ghi dữ liệu thành công cho SBD: 06000494
# Đã ghi dữ liệu thành công cho SBD: 06000495
# Đã ghi dữ liệu thành công cho SBD: 06000496
# Đã ghi dữ liệu thành công cho SBD: 06000497
# Đã ghi dữ liệu thành công cho SBD: 06000498
# Đã ghi dữ liệu thành công cho SBD: 06000499
# Đã ghi dữ liệu thành công cho SBD: 06000500
# Đã ghi dữ liệu thành công cho SBD: 06000501
# Đã ghi dữ liệu thành công cho SBD: 06000502
# Đã ghi dữ liệu thành công cho SBD: 06000503
# Đã ghi dữ liệu thành công cho SBD: 06000504
# Đã ghi dữ liệu thành công cho SBD: 06000505
# Đã ghi dữ liệu thành công cho SBD: 06000506
# Đã ghi dữ liệu thành công cho SBD: 06000507
# Đã ghi dữ liệu thành công cho SBD: 06000508
# Đã ghi dữ liệu thành công cho SBD: 06000509
# Đã ghi dữ liệu thành công cho SBD: 06000510
# Đã ghi dữ liệu thành công cho SBD: 06000511
# Đã ghi dữ liệu thành công cho SBD: 06000512
# Đã ghi dữ liệu thành công cho SBD: 06000513
# Đã ghi dữ liệu thành công cho SBD: 06000514
# Đã ghi dữ liệu thành công cho SBD: 06000515
# Đã ghi dữ liệu thành công cho SBD: 06000516
# Đã ghi dữ liệu thành công cho SBD: 06000517
# Đã ghi dữ liệu thành công cho SBD: 06000518
# Đã ghi dữ liệu thành công cho SBD: 06000519
# Đã ghi dữ liệu thành công cho SBD: 06000520
# Đã ghi dữ liệu thành công cho SBD: 06000521
# Đã ghi dữ liệu thành công cho SBD: 06000522
# Đã ghi dữ liệu thành công cho SBD: 06000523
# Đã ghi dữ liệu thành công cho SBD: 06000524
# Đã ghi dữ liệu thành công cho SBD: 06000525
# Đã ghi dữ liệu thành công cho SBD: 06000526
# Đã ghi dữ liệu thành công cho SBD: 06000527
# Đã ghi dữ liệu thành công cho SBD: 06000528
# Đã ghi dữ liệu thành công cho SBD: 06000529
# Đã ghi dữ liệu thành công cho SBD: 06000530
# Đã ghi dữ liệu thành công cho SBD: 06000531
# Đã ghi dữ liệu thành công cho SBD: 06000532
# Đã ghi dữ liệu thành công cho SBD: 06000533
# Đã ghi dữ liệu thành công cho SBD: 06000534
# Đã ghi dữ liệu thành công cho SBD: 06000535
# Đã ghi dữ liệu thành công cho SBD: 06000536
# Đã ghi dữ liệu thành công cho SBD: 06000537
# Đã ghi dữ liệu thành công cho SBD: 06000538
# Đã ghi dữ liệu thành công cho SBD: 06000539
# Đã ghi dữ liệu thành công cho SBD: 06000540
# Đã ghi dữ liệu thành công cho SBD: 06000541
# Đã ghi dữ liệu thành công cho SBD: 06000542
# Đã ghi dữ liệu thành công cho SBD: 06000543
# Đã ghi dữ liệu thành công cho SBD: 06000544
# Đã ghi dữ liệu thành công cho SBD: 06000545
# Đã ghi dữ liệu thành công cho SBD: 06000546
# Đã ghi dữ liệu thành công cho SBD: 06000547
# Đã ghi dữ liệu thành công cho SBD: 06000548
# Đã ghi dữ liệu thành công cho SBD: 06000549
# Đã ghi dữ liệu thành công cho SBD: 06000550
# Đã ghi dữ liệu thành công cho SBD: 06000551
# Đã ghi dữ liệu thành công cho SBD: 06000552
# Đã ghi dữ liệu thành công cho SBD: 06000553
# Đã ghi dữ liệu thành công cho SBD: 06000554
# Đã ghi dữ liệu thành công cho SBD: 06000555
# Đã ghi dữ liệu thành công cho SBD: 06000556
# Đã ghi dữ liệu thành công cho SBD: 06000557
# Đã ghi dữ liệu thành công cho SBD: 06000558
# Đã ghi dữ liệu thành công cho SBD: 06000559
# Đã ghi dữ liệu thành công cho SBD: 06000560
# Đã ghi dữ liệu thành công cho SBD: 06000561
# Đã ghi dữ liệu thành công cho SBD: 06000562
# Đã ghi dữ liệu thành công cho SBD: 06000563
# Đã ghi dữ liệu thành công cho SBD: 06000564
# Đã ghi dữ liệu thành công cho SBD: 06000565
# Đã ghi dữ liệu thành công cho SBD: 06000566
# Đã ghi dữ liệu thành công cho SBD: 06000567
# Đã ghi dữ liệu thành công cho SBD: 06000568
# Đã ghi dữ liệu thành công cho SBD: 06000569
# Đã ghi dữ liệu thành công cho SBD: 06000570
# Đã ghi dữ liệu thành công cho SBD: 06000571
# Đã ghi dữ liệu thành công cho SBD: 06000572
# Đã ghi dữ liệu thành công cho SBD: 06000573
# Đã ghi dữ liệu thành công cho SBD: 06000574
# Đã ghi dữ liệu thành công cho SBD: 06000575
# Đã ghi dữ liệu thành công cho SBD: 06000576
# Đã ghi dữ liệu thành công cho SBD: 06000577
# Đã ghi dữ liệu thành công cho SBD: 06000578
# Đã ghi dữ liệu thành công cho SBD: 06000579
# Đã ghi dữ liệu thành công cho SBD: 06000580
# Đã ghi dữ liệu thành công cho SBD: 06000581
# Đã ghi dữ liệu thành công cho SBD: 06000582
# Đã ghi dữ liệu thành công cho SBD: 06000583
# Đã ghi dữ liệu thành công cho SBD: 06000584
# Đã ghi dữ liệu thành công cho SBD: 06000585
# Đã ghi dữ liệu thành công cho SBD: 06000586
# Đã ghi dữ liệu thành công cho SBD: 06000587
# Đã ghi dữ liệu thành công cho SBD: 06000588
# Đã ghi dữ liệu thành công cho SBD: 06000589
# Đã ghi dữ liệu thành công cho SBD: 06000590
# Đã ghi dữ liệu thành công cho SBD: 06000591
# Đã ghi dữ liệu thành công cho SBD: 06000592
# Đã ghi dữ liệu thành công cho SBD: 06000593
# Đã ghi dữ liệu thành công cho SBD: 06000594
# Đã ghi dữ liệu thành công cho SBD: 06000595
# Đã ghi dữ liệu thành công cho SBD: 06000596
# Đã ghi dữ liệu thành công cho SBD: 06000597
# Đã ghi dữ liệu thành công cho SBD: 06000598
# Đã ghi dữ liệu thành công cho SBD: 06000599
# Đã ghi dữ liệu thành công cho SBD: 06000600
# Đã ghi dữ liệu thành công cho SBD: 06000601
# Đã ghi dữ liệu thành công cho SBD: 06000602
# Đã ghi dữ liệu thành công cho SBD: 06000603
# Đã ghi dữ liệu thành công cho SBD: 06000604
# Đã ghi dữ liệu thành công cho SBD: 06000605
# Đã ghi dữ liệu thành công cho SBD: 06000606
# Đã ghi dữ liệu thành công cho SBD: 06000607
# Đã ghi dữ liệu thành công cho SBD: 06000608
# Đã ghi dữ liệu thành công cho SBD: 06000609
# Đã ghi dữ liệu thành công cho SBD: 06000610
# Đã ghi dữ liệu thành công cho SBD: 06000611
# Đã ghi dữ liệu thành công cho SBD: 06000612
# Đã ghi dữ liệu thành công cho SBD: 06000613
# Đã ghi dữ liệu thành công cho SBD: 06000614
# Đã ghi dữ liệu thành công cho SBD: 06000615
# Đã ghi dữ liệu thành công cho SBD: 06000616
# Đã ghi dữ liệu thành công cho SBD: 06000617
# Đã ghi dữ liệu thành công cho SBD: 06000618
# Đã ghi dữ liệu thành công cho SBD: 06000619
# Đã ghi dữ liệu thành công cho SBD: 06000620
# Đã ghi dữ liệu thành công cho SBD: 06000621
# Đã ghi dữ liệu thành công cho SBD: 06000622
# Đã ghi dữ liệu thành công cho SBD: 06000623
# Đã ghi dữ liệu thành công cho SBD: 06000624
# Đã ghi dữ liệu thành công cho SBD: 06000625
# Đã ghi dữ liệu thành công cho SBD: 06000626
# Đã ghi dữ liệu thành công cho SBD: 06000627
# Đã ghi dữ liệu thành công cho SBD: 06000628
# Đã ghi dữ liệu thành công cho SBD: 06000629
# Đã ghi dữ liệu thành công cho SBD: 06000630
# Đã ghi dữ liệu thành công cho SBD: 06000631
# Đã ghi dữ liệu thành công cho SBD: 06000632
# Đã ghi dữ liệu thành công cho SBD: 06000633
# Đã ghi dữ liệu thành công cho SBD: 06000634
# Đã ghi dữ liệu thành công cho SBD: 06000635
# Đã ghi dữ liệu thành công cho SBD: 06000636
# Đã ghi dữ liệu thành công cho SBD: 06000637
# Đã ghi dữ liệu thành công cho SBD: 06000638
# Đã ghi dữ liệu thành công cho SBD: 06000639
# Đã ghi dữ liệu thành công cho SBD: 06000640
# Đã ghi dữ liệu thành công cho SBD: 06000641
# Đã ghi dữ liệu thành công cho SBD: 06000642
# Đã ghi dữ liệu thành công cho SBD: 06000643
# Đã ghi dữ liệu thành công cho SBD: 06000644
# Đã ghi dữ liệu thành công cho SBD: 06000645
# Đã ghi dữ liệu thành công cho SBD: 06000646
# Đã ghi dữ liệu thành công cho SBD: 06000647
# Đã ghi dữ liệu thành công cho SBD: 06000648
# Đã ghi dữ liệu thành công cho SBD: 06000649
# Đã ghi dữ liệu thành công cho SBD: 06000650
# Đã ghi dữ liệu thành công cho SBD: 06000651
# Đã ghi dữ liệu thành công cho SBD: 06000652
# Đã ghi dữ liệu thành công cho SBD: 06000653
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 06000655
# Đã ghi dữ liệu thành công cho SBD: 06000656
# Đã ghi dữ liệu thành công cho SBD: 06000657
# Đã ghi dữ liệu thành công cho SBD: 06000658
# Đã ghi dữ liệu thành công cho SBD: 06000659
# Đã ghi dữ liệu thành công cho SBD: 06000660
# Đã ghi dữ liệu thành công cho SBD: 06000661
# Đã ghi dữ liệu thành công cho SBD: 06000662
# Đã ghi dữ liệu thành công cho SBD: 06000663
# Đã ghi dữ liệu thành công cho SBD: 06000664
# Đã ghi dữ liệu thành công cho SBD: 06000665
# Đã ghi dữ liệu thành công cho SBD: 06000666
# Đã ghi dữ liệu thành công cho SBD: 06000667
# Đã ghi dữ liệu thành công cho SBD: 06000668
# Đã ghi dữ liệu thành công cho SBD: 06000669
# Đã ghi dữ liệu thành công cho SBD: 06000670
# Đã ghi dữ liệu thành công cho SBD: 06000671
# Đã ghi dữ liệu thành công cho SBD: 06000672
# Đã ghi dữ liệu thành công cho SBD: 06000673
# Đã ghi dữ liệu thành công cho SBD: 06000674
# Đã ghi dữ liệu thành công cho SBD: 06000675
# Đã ghi dữ liệu thành công cho SBD: 06000676
# Đã ghi dữ liệu thành công cho SBD: 06000677
# Đã ghi dữ liệu thành công cho SBD: 06000678
# Đã ghi dữ liệu thành công cho SBD: 06000679
# Đã ghi dữ liệu thành công cho SBD: 06000680
# Đã ghi dữ liệu thành công cho SBD: 06000681
# Đã ghi dữ liệu thành công cho SBD: 06000682
# Đã ghi dữ liệu thành công cho SBD: 06000683
# Đã ghi dữ liệu thành công cho SBD: 06000684
# Đã ghi dữ liệu thành công cho SBD: 06000685
# Đã ghi dữ liệu thành công cho SBD: 06000686
# Đã ghi dữ liệu thành công cho SBD: 06000687
# Đã ghi dữ liệu thành công cho SBD: 06000688
# Đã ghi dữ liệu thành công cho SBD: 06000689
# Đã ghi dữ liệu thành công cho SBD: 06000690
# Đã ghi dữ liệu thành công cho SBD: 06000691
# Đã ghi dữ liệu thành công cho SBD: 06000692
# Đã ghi dữ liệu thành công cho SBD: 06000693
# Đã ghi dữ liệu thành công cho SBD: 06000694
# Đã ghi dữ liệu thành công cho SBD: 06000695
# Đã ghi dữ liệu thành công cho SBD: 06000696
# Đã ghi dữ liệu thành công cho SBD: 06000697
# Đã ghi dữ liệu thành công cho SBD: 06000698
# Đã ghi dữ liệu thành công cho SBD: 06000699
# Đã ghi dữ liệu thành công cho SBD: 06000700
# Đã ghi dữ liệu thành công cho SBD: 06000701
# Đã ghi dữ liệu thành công cho SBD: 06000702
# Đã ghi dữ liệu thành công cho SBD: 06000703
# Đã ghi dữ liệu thành công cho SBD: 06000704
# Đã ghi dữ liệu thành công cho SBD: 06000705
# Đã ghi dữ liệu thành công cho SBD: 06000706
# Đã ghi dữ liệu thành công cho SBD: 06000707
# Đã ghi dữ liệu thành công cho SBD: 06000708
# Đã ghi dữ liệu thành công cho SBD: 06000709
# Đã ghi dữ liệu thành công cho SBD: 06000710
# Đã ghi dữ liệu thành công cho SBD: 06000711
# Đã ghi dữ liệu thành công cho SBD: 06000712
# Đã ghi dữ liệu thành công cho SBD: 06000713
# Đã ghi dữ liệu thành công cho SBD: 06000714
# Đã ghi dữ liệu thành công cho SBD: 06000715
# Đã ghi dữ liệu thành công cho SBD: 06000716
# Đã ghi dữ liệu thành công cho SBD: 06000717
# Đã ghi dữ liệu thành công cho SBD: 06000718
# Đã ghi dữ liệu thành công cho SBD: 06000719
# Đã ghi dữ liệu thành công cho SBD: 06000720
# Đã ghi dữ liệu thành công cho SBD: 06000721
# Đã ghi dữ liệu thành công cho SBD: 06000722
# Đã ghi dữ liệu thành công cho SBD: 06000723
# Đã ghi dữ liệu thành công cho SBD: 06000724
# Đã ghi dữ liệu thành công cho SBD: 06000725
# Đã ghi dữ liệu thành công cho SBD: 06000726
# Đã ghi dữ liệu thành công cho SBD: 06000727
# Đã ghi dữ liệu thành công cho SBD: 06000728
# Đã ghi dữ liệu thành công cho SBD: 06000729
# Đã ghi dữ liệu thành công cho SBD: 06000730
# Đã ghi dữ liệu thành công cho SBD: 06000731
# Đã ghi dữ liệu thành công cho SBD: 06000732
# Đã ghi dữ liệu thành công cho SBD: 06000733
# Đã ghi dữ liệu thành công cho SBD: 06000734
# Đã ghi dữ liệu thành công cho SBD: 06000735
# Đã ghi dữ liệu thành công cho SBD: 06000736
# Đã ghi dữ liệu thành công cho SBD: 06000737
# Đã ghi dữ liệu thành công cho SBD: 06000738
# Đã ghi dữ liệu thành công cho SBD: 06000739
# Đã ghi dữ liệu thành công cho SBD: 06000740
# Đã ghi dữ liệu thành công cho SBD: 06000741
# Đã ghi dữ liệu thành công cho SBD: 06000742
# Đã ghi dữ liệu thành công cho SBD: 06000743
# Đã ghi dữ liệu thành công cho SBD: 06000744
# Đã ghi dữ liệu thành công cho SBD: 06000745
# Đã ghi dữ liệu thành công cho SBD: 06000746
# Đã ghi dữ liệu thành công cho SBD: 06000747
# Đã ghi dữ liệu thành công cho SBD: 06000748
# Đã ghi dữ liệu thành công cho SBD: 06000749
# Đã ghi dữ liệu thành công cho SBD: 06000750
# Đã ghi dữ liệu thành công cho SBD: 06000751
# Đã ghi dữ liệu thành công cho SBD: 06000752
# Đã ghi dữ liệu thành công cho SBD: 06000753
# Đã ghi dữ liệu thành công cho SBD: 06000754
# Đã ghi dữ liệu thành công cho SBD: 06000755
# Đã ghi dữ liệu thành công cho SBD: 06000756
# Đã ghi dữ liệu thành công cho SBD: 06000757
# Đã ghi dữ liệu thành công cho SBD: 06000758
# Đã ghi dữ liệu thành công cho SBD: 06000759
# Đã ghi dữ liệu thành công cho SBD: 06000760
# Đã ghi dữ liệu thành công cho SBD: 06000761
# Đã ghi dữ liệu thành công cho SBD: 06000762
# Đã ghi dữ liệu thành công cho SBD: 06000763
# Đã ghi dữ liệu thành công cho SBD: 06000764
# Đã ghi dữ liệu thành công cho SBD: 06000765
# Đã ghi dữ liệu thành công cho SBD: 06000766
# Đã ghi dữ liệu thành công cho SBD: 06000767
# Đã ghi dữ liệu thành công cho SBD: 06000768
# Đã ghi dữ liệu thành công cho SBD: 06000769
# Đã ghi dữ liệu thành công cho SBD: 06000770
# Đã ghi dữ liệu thành công cho SBD: 06000771
# Đã ghi dữ liệu thành công cho SBD: 06000772
# Đã ghi dữ liệu thành công cho SBD: 06000773
# Đã ghi dữ liệu thành công cho SBD: 06000774
# Đã ghi dữ liệu thành công cho SBD: 06000775
# Đã ghi dữ liệu thành công cho SBD: 06000776
# Đã ghi dữ liệu thành công cho SBD: 06000777
# Đã ghi dữ liệu thành công cho SBD: 06000778
# Đã ghi dữ liệu thành công cho SBD: 06000779
# Đã ghi dữ liệu thành công cho SBD: 06000780
# Đã ghi dữ liệu thành công cho SBD: 06000781
# Đã ghi dữ liệu thành công cho SBD: 06000782
# Đã ghi dữ liệu thành công cho SBD: 06000783
# Đã ghi dữ liệu thành công cho SBD: 06000784
# Đã ghi dữ liệu thành công cho SBD: 06000785
# Đã ghi dữ liệu thành công cho SBD: 06000786
# Đã ghi dữ liệu thành công cho SBD: 06000787
# Đã ghi dữ liệu thành công cho SBD: 06000788
# Đã ghi dữ liệu thành công cho SBD: 06000789
# Đã ghi dữ liệu thành công cho SBD: 06000790
# Đã ghi dữ liệu thành công cho SBD: 06000791
# Đã ghi dữ liệu thành công cho SBD: 06000792
# Đã ghi dữ liệu thành công cho SBD: 06000793
# Đã ghi dữ liệu thành công cho SBD: 06000794
# Đã ghi dữ liệu thành công cho SBD: 06000795
# Đã ghi dữ liệu thành công cho SBD: 06000796
# Đã ghi dữ liệu thành công cho SBD: 06000797
# Đã ghi dữ liệu thành công cho SBD: 06000798
# Đã ghi dữ liệu thành công cho SBD: 06000799
# Đã ghi dữ liệu thành công cho SBD: 06000800
# Đã ghi dữ liệu thành công cho SBD: 06000801
# Đã ghi dữ liệu thành công cho SBD: 06000802
# Đã ghi dữ liệu thành công cho SBD: 06000803
# Đã ghi dữ liệu thành công cho SBD: 06000804
# Đã ghi dữ liệu thành công cho SBD: 06000805
# Đã ghi dữ liệu thành công cho SBD: 06000806
# Đã ghi dữ liệu thành công cho SBD: 06000807
# Đã ghi dữ liệu thành công cho SBD: 06000808
# Đã ghi dữ liệu thành công cho SBD: 06000809
# Đã ghi dữ liệu thành công cho SBD: 06000810
# Đã ghi dữ liệu thành công cho SBD: 06000811
# Đã ghi dữ liệu thành công cho SBD: 06000812
# Đã ghi dữ liệu thành công cho SBD: 06000813
# Đã ghi dữ liệu thành công cho SBD: 06000814
# Đã ghi dữ liệu thành công cho SBD: 06000815
# Đã ghi dữ liệu thành công cho SBD: 06000816
# Đã ghi dữ liệu thành công cho SBD: 06000817
# Đã ghi dữ liệu thành công cho SBD: 06000818
# Đã ghi dữ liệu thành công cho SBD: 06000819
# Đã ghi dữ liệu thành công cho SBD: 06000820
# Đã ghi dữ liệu thành công cho SBD: 06000821
# Đã ghi dữ liệu thành công cho SBD: 06000822
# Đã ghi dữ liệu thành công cho SBD: 06000823
# Đã ghi dữ liệu thành công cho SBD: 06000824
# Đã ghi dữ liệu thành công cho SBD: 06000825
# Đã ghi dữ liệu thành công cho SBD: 06000826
# Đã ghi dữ liệu thành công cho SBD: 06000827
# Đã ghi dữ liệu thành công cho SBD: 06000828
# Đã ghi dữ liệu thành công cho SBD: 06000829
# Đã ghi dữ liệu thành công cho SBD: 06000830
# Đã ghi dữ liệu thành công cho SBD: 06000831
# Đã ghi dữ liệu thành công cho SBD: 06000832
# Đã ghi dữ liệu thành công cho SBD: 06000833
# Đã ghi dữ liệu thành công cho SBD: 06000834
# Đã ghi dữ liệu thành công cho SBD: 06000835
# Đã ghi dữ liệu thành công cho SBD: 06000836
# Đã ghi dữ liệu thành công cho SBD: 06000837
# Đã ghi dữ liệu thành công cho SBD: 06000838
# Đã ghi dữ liệu thành công cho SBD: 06000839
# Đã ghi dữ liệu thành công cho SBD: 06000840
# Đã ghi dữ liệu thành công cho SBD: 06000841
# Đã ghi dữ liệu thành công cho SBD: 06000842
# Đã ghi dữ liệu thành công cho SBD: 06000843
# Đã ghi dữ liệu thành công cho SBD: 06000844
# Đã ghi dữ liệu thành công cho SBD: 06000845
# Đã ghi dữ liệu thành công cho SBD: 06000846
# Đã ghi dữ liệu thành công cho SBD: 06000847
# Đã ghi dữ liệu thành công cho SBD: 06000848
# Đã ghi dữ liệu thành công cho SBD: 06000849
# Đã ghi dữ liệu thành công cho SBD: 06000850
# Đã ghi dữ liệu thành công cho SBD: 06000851
# Đã ghi dữ liệu thành công cho SBD: 06000852
# Đã ghi dữ liệu thành công cho SBD: 06000853
# Đã ghi dữ liệu thành công cho SBD: 06000854
# Đã ghi dữ liệu thành công cho SBD: 06000855
# Đã ghi dữ liệu thành công cho SBD: 06000856
# Đã ghi dữ liệu thành công cho SBD: 06000857
# Đã ghi dữ liệu thành công cho SBD: 06000858
# Đã ghi dữ liệu thành công cho SBD: 06000859
# Đã ghi dữ liệu thành công cho SBD: 06000860
# Đã ghi dữ liệu thành công cho SBD: 06000861
# Đã ghi dữ liệu thành công cho SBD: 06000862
# Đã ghi dữ liệu thành công cho SBD: 06000863
# Đã ghi dữ liệu thành công cho SBD: 06000864
# Đã ghi dữ liệu thành công cho SBD: 06000865
# Đã ghi dữ liệu thành công cho SBD: 06000866
# Đã ghi dữ liệu thành công cho SBD: 06000867
# Đã ghi dữ liệu thành công cho SBD: 06000868
# Đã ghi dữ liệu thành công cho SBD: 06000869
# Đã ghi dữ liệu thành công cho SBD: 06000870
# Đã ghi dữ liệu thành công cho SBD: 06000871
# Đã ghi dữ liệu thành công cho SBD: 06000872
# Đã ghi dữ liệu thành công cho SBD: 06000873
# Đã ghi dữ liệu thành công cho SBD: 06000874
# Đã ghi dữ liệu thành công cho SBD: 06000875
# Đã ghi dữ liệu thành công cho SBD: 06000876
# Đã ghi dữ liệu thành công cho SBD: 06000877
# Đã ghi dữ liệu thành công cho SBD: 06000878
# Đã ghi dữ liệu thành công cho SBD: 06000879
# Đã ghi dữ liệu thành công cho SBD: 06000880
# Đã ghi dữ liệu thành công cho SBD: 06000881
# Đã ghi dữ liệu thành công cho SBD: 06000882
# Đã ghi dữ liệu thành công cho SBD: 06000883
# Đã ghi dữ liệu thành công cho SBD: 06000884
# Đã ghi dữ liệu thành công cho SBD: 06000885
# Đã ghi dữ liệu thành công cho SBD: 06000886
# Đã ghi dữ liệu thành công cho SBD: 06000887
# Đã ghi dữ liệu thành công cho SBD: 06000888
# Đã ghi dữ liệu thành công cho SBD: 06000889
# Đã ghi dữ liệu thành công cho SBD: 06000890
# Đã ghi dữ liệu thành công cho SBD: 06000891
# Đã ghi dữ liệu thành công cho SBD: 06000892
# Đã ghi dữ liệu thành công cho SBD: 06000893
# Đã ghi dữ liệu thành công cho SBD: 06000894
# Đã ghi dữ liệu thành công cho SBD: 06000895
# Đã ghi dữ liệu thành công cho SBD: 06000896
# Đã ghi dữ liệu thành công cho SBD: 06000897
# Đã ghi dữ liệu thành công cho SBD: 06000898
# Đã ghi dữ liệu thành công cho SBD: 06000899
# Đã ghi dữ liệu thành công cho SBD: 06000900
# Đã ghi dữ liệu thành công cho SBD: 06000901
# Đã ghi dữ liệu thành công cho SBD: 06000902
# Đã ghi dữ liệu thành công cho SBD: 06000903
# Đã ghi dữ liệu thành công cho SBD: 06000904
# Đã ghi dữ liệu thành công cho SBD: 06000905
# Đã ghi dữ liệu thành công cho SBD: 06000906
# Đã ghi dữ liệu thành công cho SBD: 06000907
# Đã ghi dữ liệu thành công cho SBD: 06000908
# Đã ghi dữ liệu thành công cho SBD: 06000909
# Đã ghi dữ liệu thành công cho SBD: 06000910
# Đã ghi dữ liệu thành công cho SBD: 06000911
# Đã ghi dữ liệu thành công cho SBD: 06000912
# Đã ghi dữ liệu thành công cho SBD: 06000913
# Đã ghi dữ liệu thành công cho SBD: 06000914
# Đã ghi dữ liệu thành công cho SBD: 06000915
# Đã ghi dữ liệu thành công cho SBD: 06000916
# Đã ghi dữ liệu thành công cho SBD: 06000917
# Đã ghi dữ liệu thành công cho SBD: 06000918
# Đã ghi dữ liệu thành công cho SBD: 06000919
# Đã ghi dữ liệu thành công cho SBD: 06000920
# Đã ghi dữ liệu thành công cho SBD: 06000921
# Đã ghi dữ liệu thành công cho SBD: 06000922
# Đã ghi dữ liệu thành công cho SBD: 06000923
# Đã ghi dữ liệu thành công cho SBD: 06000924
# Đã ghi dữ liệu thành công cho SBD: 06000925
# Đã ghi dữ liệu thành công cho SBD: 06000926
# Đã ghi dữ liệu thành công cho SBD: 06000927
# Đã ghi dữ liệu thành công cho SBD: 06000928
# Đã ghi dữ liệu thành công cho SBD: 06000929
# Đã ghi dữ liệu thành công cho SBD: 06000930
# Đã ghi dữ liệu thành công cho SBD: 06000931
# Đã ghi dữ liệu thành công cho SBD: 06000932
# Đã ghi dữ liệu thành công cho SBD: 06000933
# Đã ghi dữ liệu thành công cho SBD: 06000934
# Đã ghi dữ liệu thành công cho SBD: 06000935
# Đã ghi dữ liệu thành công cho SBD: 06000936
# Đã ghi dữ liệu thành công cho SBD: 06000937
# Đã ghi dữ liệu thành công cho SBD: 06000938
# Đã ghi dữ liệu thành công cho SBD: 06000939
# Đã ghi dữ liệu thành công cho SBD: 06000940
# Đã ghi dữ liệu thành công cho SBD: 06000941
# Đã ghi dữ liệu thành công cho SBD: 06000942
# Đã ghi dữ liệu thành công cho SBD: 06000943
# Đã ghi dữ liệu thành công cho SBD: 06000944
# Đã ghi dữ liệu thành công cho SBD: 06000945
# Đã ghi dữ liệu thành công cho SBD: 06000946
# Đã ghi dữ liệu thành công cho SBD: 06000947
# Đã ghi dữ liệu thành công cho SBD: 06000948
# Đã ghi dữ liệu thành công cho SBD: 06000949
# Đã ghi dữ liệu thành công cho SBD: 06000950
# Đã ghi dữ liệu thành công cho SBD: 06000951
# Đã ghi dữ liệu thành công cho SBD: 06000952
# Đã ghi dữ liệu thành công cho SBD: 06000953
# Đã ghi dữ liệu thành công cho SBD: 06000954
# Đã ghi dữ liệu thành công cho SBD: 06000955
# Đã ghi dữ liệu thành công cho SBD: 06000956
# Đã ghi dữ liệu thành công cho SBD: 06000957
# Đã ghi dữ liệu thành công cho SBD: 06000958
# Đã ghi dữ liệu thành công cho SBD: 06000959
# Đã ghi dữ liệu thành công cho SBD: 06000960
# Đã ghi dữ liệu thành công cho SBD: 06000961
# Đã ghi dữ liệu thành công cho SBD: 06000962
# Đã ghi dữ liệu thành công cho SBD: 06000963
# Đã ghi dữ liệu thành công cho SBD: 06000964
# Đã ghi dữ liệu thành công cho SBD: 06000965
# Đã ghi dữ liệu thành công cho SBD: 06000966
# Đã ghi dữ liệu thành công cho SBD: 06000967
# Đã ghi dữ liệu thành công cho SBD: 06000968
# Đã ghi dữ liệu thành công cho SBD: 06000969
# Đã ghi dữ liệu thành công cho SBD: 06000970
# Đã ghi dữ liệu thành công cho SBD: 06000971
# Đã ghi dữ liệu thành công cho SBD: 06000972
# Đã ghi dữ liệu thành công cho SBD: 06000973
# Đã ghi dữ liệu thành công cho SBD: 06000974
# Đã ghi dữ liệu thành công cho SBD: 06000975
# Đã ghi dữ liệu thành công cho SBD: 06000976
# Đã ghi dữ liệu thành công cho SBD: 06000977
# Đã ghi dữ liệu thành công cho SBD: 06000978
# Đã ghi dữ liệu thành công cho SBD: 06000979
# Đã ghi dữ liệu thành công cho SBD: 06000980
# Đã ghi dữ liệu thành công cho SBD: 06000981
# Đã ghi dữ liệu thành công cho SBD: 06000982
# Đã ghi dữ liệu thành công cho SBD: 06000983
# Đã ghi dữ liệu thành công cho SBD: 06000984
# Đã ghi dữ liệu thành công cho SBD: 06000985
# Đã ghi dữ liệu thành công cho SBD: 06000986
# Đã ghi dữ liệu thành công cho SBD: 06000987
# Đã ghi dữ liệu thành công cho SBD: 06000988
# Đã ghi dữ liệu thành công cho SBD: 06000989
# Đã ghi dữ liệu thành công cho SBD: 06000990
# Đã ghi dữ liệu thành công cho SBD: 06000991
# Đã ghi dữ liệu thành công cho SBD: 06000992
# Đã ghi dữ liệu thành công cho SBD: 06000993
# Đã ghi dữ liệu thành công cho SBD: 06000994
# Đã ghi dữ liệu thành công cho SBD: 06000995
# Đã ghi dữ liệu thành công cho SBD: 06000996
# Đã ghi dữ liệu thành công cho SBD: 06000997
# Đã ghi dữ liệu thành công cho SBD: 06000998
# Đã ghi dữ liệu thành công cho SBD: 06000999
# Đã ghi dữ liệu thành công cho SBD: 06001000
# Đã ghi dữ liệu thành công cho SBD: 06001001
# Đã ghi dữ liệu thành công cho SBD: 06001002
# Đã ghi dữ liệu thành công cho SBD: 06001003
# Đã ghi dữ liệu thành công cho SBD: 06001004
# Đã ghi dữ liệu thành công cho SBD: 06001005
# Đã ghi dữ liệu thành công cho SBD: 06001006
# Đã ghi dữ liệu thành công cho SBD: 06001007
# Đã ghi dữ liệu thành công cho SBD: 06001008
# Đã ghi dữ liệu thành công cho SBD: 06001009
# Đã ghi dữ liệu thành công cho SBD: 06001010
# Đã ghi dữ liệu thành công cho SBD: 06001011
# Đã ghi dữ liệu thành công cho SBD: 06001012
# Đã ghi dữ liệu thành công cho SBD: 06001013
# Đã ghi dữ liệu thành công cho SBD: 06001014
# Đã ghi dữ liệu thành công cho SBD: 06001015
# Đã ghi dữ liệu thành công cho SBD: 06001016
# Đã ghi dữ liệu thành công cho SBD: 06001017
# Đã ghi dữ liệu thành công cho SBD: 06001018
# Đã ghi dữ liệu thành công cho SBD: 06001019
# Đã ghi dữ liệu thành công cho SBD: 06001020
# Đã ghi dữ liệu thành công cho SBD: 06001021
# Đã ghi dữ liệu thành công cho SBD: 06001022
# Đã ghi dữ liệu thành công cho SBD: 06001023
# Đã ghi dữ liệu thành công cho SBD: 06001024
# Đã ghi dữ liệu thành công cho SBD: 06001025
# Đã ghi dữ liệu thành công cho SBD: 06001026
# Đã ghi dữ liệu thành công cho SBD: 06001027
# Đã ghi dữ liệu thành công cho SBD: 06001028
# Đã ghi dữ liệu thành công cho SBD: 06001029
# Đã ghi dữ liệu thành công cho SBD: 06001030
# Đã ghi dữ liệu thành công cho SBD: 06001031
# Đã ghi dữ liệu thành công cho SBD: 06001032
# Đã ghi dữ liệu thành công cho SBD: 06001033
# Đã ghi dữ liệu thành công cho SBD: 06001034
# Đã ghi dữ liệu thành công cho SBD: 06001035
# Đã ghi dữ liệu thành công cho SBD: 06001036
# Đã ghi dữ liệu thành công cho SBD: 06001037
# Đã ghi dữ liệu thành công cho SBD: 06001038
# Đã ghi dữ liệu thành công cho SBD: 06001039
# Đã ghi dữ liệu thành công cho SBD: 06001040
# Đã ghi dữ liệu thành công cho SBD: 06001041
# Đã ghi dữ liệu thành công cho SBD: 06001042
# Đã ghi dữ liệu thành công cho SBD: 06001043
# Đã ghi dữ liệu thành công cho SBD: 06001044
# Đã ghi dữ liệu thành công cho SBD: 06001045
# Đã ghi dữ liệu thành công cho SBD: 06001046
# Đã ghi dữ liệu thành công cho SBD: 06001047
# Đã ghi dữ liệu thành công cho SBD: 06001048
# Đã ghi dữ liệu thành công cho SBD: 06001049
# Đã ghi dữ liệu thành công cho SBD: 06001050
# Đã ghi dữ liệu thành công cho SBD: 06001051
# Đã ghi dữ liệu thành công cho SBD: 06001052
# Đã ghi dữ liệu thành công cho SBD: 06001053
# Đã ghi dữ liệu thành công cho SBD: 06001054
# Đã ghi dữ liệu thành công cho SBD: 06001055
# Đã ghi dữ liệu thành công cho SBD: 06001056
# Đã ghi dữ liệu thành công cho SBD: 06001057
# Đã ghi dữ liệu thành công cho SBD: 06001058
# Đã ghi dữ liệu thành công cho SBD: 06001059
# Đã ghi dữ liệu thành công cho SBD: 06001060
# Đã ghi dữ liệu thành công cho SBD: 06001061
# Đã ghi dữ liệu thành công cho SBD: 06001062
# Đã ghi dữ liệu thành công cho SBD: 06001063
# Đã ghi dữ liệu thành công cho SBD: 06001064
# Đã ghi dữ liệu thành công cho SBD: 06001065
# Đã ghi dữ liệu thành công cho SBD: 06001066
# Đã ghi dữ liệu thành công cho SBD: 06001067
# Đã ghi dữ liệu thành công cho SBD: 06001068
# Đã ghi dữ liệu thành công cho SBD: 06001069
# Đã ghi dữ liệu thành công cho SBD: 06001070
# Đã ghi dữ liệu thành công cho SBD: 06001071
# Đã ghi dữ liệu thành công cho SBD: 06001072
# Đã ghi dữ liệu thành công cho SBD: 06001073
# Đã ghi dữ liệu thành công cho SBD: 06001074
# Đã ghi dữ liệu thành công cho SBD: 06001075
# Đã ghi dữ liệu thành công cho SBD: 06001076
# Đã ghi dữ liệu thành công cho SBD: 06001077
# Đã ghi dữ liệu thành công cho SBD: 06001078
# Đã ghi dữ liệu thành công cho SBD: 06001079
# Đã ghi dữ liệu thành công cho SBD: 06001080
# Đã ghi dữ liệu thành công cho SBD: 06001081
# Đã ghi dữ liệu thành công cho SBD: 06001082
# Đã ghi dữ liệu thành công cho SBD: 06001083
# Đã ghi dữ liệu thành công cho SBD: 06001084
# Đã ghi dữ liệu thành công cho SBD: 06001085
# Đã ghi dữ liệu thành công cho SBD: 06001086
# Đã ghi dữ liệu thành công cho SBD: 06001087
# Đã ghi dữ liệu thành công cho SBD: 06001088
# Đã ghi dữ liệu thành công cho SBD: 06001089
# Đã ghi dữ liệu thành công cho SBD: 06001090
# Đã ghi dữ liệu thành công cho SBD: 06001091
# ...
# Đã ghi dữ liệu thành công cho SBD: 06005497
# Đã ghi dữ liệu thành công cho SBD: 06005498
# Đã ghi dữ liệu thành công cho SBD: 06005499
# Đã ghi dữ liệu thành công cho SBD: 06005500
# Đã ghi dữ liệu thành công cho SBD: 06005501
# Đã ghi dữ liệu thành công cho SBD: 06005502
# Đã ghi dữ liệu thành công cho SBD: 06005503
# Đã ghi dữ liệu thành công cho SBD: 06005504
# Đã ghi dữ liệu thành công cho SBD: 06005505
# Đã ghi dữ liệu thành công cho SBD: 06005506
# Đã ghi dữ liệu thành công cho SBD: 06005507
# Đã ghi dữ liệu thành công cho SBD: 06005508
# Đã ghi dữ liệu thành công cho SBD: 06005509
# Đã ghi dữ liệu thành công cho SBD: 06005510
# Đã ghi dữ liệu thành công cho SBD: 06005511
# Đã ghi dữ liệu thành công cho SBD: 06005512
# Đã ghi dữ liệu thành công cho SBD: 06005513
# Đã ghi dữ liệu thành công cho SBD: 06005514
# Đã ghi dữ liệu thành công cho SBD: 06005515
# Đã ghi dữ liệu thành công cho SBD: 06005516
# Đã ghi dữ liệu thành công cho SBD: 06005517
# Đã ghi dữ liệu thành công cho SBD: 06005518
# Đã ghi dữ liệu thành công cho SBD: 06005519
# Đã ghi dữ liệu thành công cho SBD: 06005520
# Đã ghi dữ liệu thành công cho SBD: 06005521
# Đã ghi dữ liệu thành công cho SBD: 06005522
# Đã ghi dữ liệu thành công cho SBD: 06005523
# Đã ghi dữ liệu thành công cho SBD: 06005524
# Đã ghi dữ liệu thành công cho SBD: 06005525
# Đã ghi dữ liệu thành công cho SBD: 06005526
# Đã ghi dữ liệu thành công cho SBD: 06005527
# Đã ghi dữ liệu thành công cho SBD: 06005528
# Đã ghi dữ liệu thành công cho SBD: 06005529
# Đã ghi dữ liệu thành công cho SBD: 06005530
# Đã ghi dữ liệu thành công cho SBD: 06005531
# Đã ghi dữ liệu thành công cho SBD: 06005532
# Đã ghi dữ liệu thành công cho SBD: 06005533
# Đã ghi dữ liệu thành công cho SBD: 06005534
# Đã ghi dữ liệu thành công cho SBD: 06005535
# Đã ghi dữ liệu thành công cho SBD: 06005536
# Đã ghi dữ liệu thành công cho SBD: 06005537
# Đã ghi dữ liệu thành công cho SBD: 06005538
# Đã ghi dữ liệu thành công cho SBD: 06005539
# Đã ghi dữ liệu thành công cho SBD: 06005540
# Đã ghi dữ liệu thành công cho SBD: 06005541
# Đã ghi dữ liệu thành công cho SBD: 06005542
# Đã ghi dữ liệu thành công cho SBD: 06005543
# Đã ghi dữ liệu thành công cho SBD: 06005544
# Đã ghi dữ liệu thành công cho SBD: 06005545
# Đã ghi dữ liệu thành công cho SBD: 06005546
# Đã ghi dữ liệu thành công cho SBD: 06005547
# Đã ghi dữ liệu thành công cho SBD: 06005548
# Đã ghi dữ liệu thành công cho SBD: 06005549
# Đã ghi dữ liệu thành công cho SBD: 06005550
# Đã ghi dữ liệu thành công cho SBD: 06005551
# Đã ghi dữ liệu thành công cho SBD: 06005552
# Đã ghi dữ liệu thành công cho SBD: 06005553
# Đã ghi dữ liệu thành công cho SBD: 06005554
# Đã ghi dữ liệu thành công cho SBD: 06005555
# Đã ghi dữ liệu thành công cho SBD: 06005556
# Đã ghi dữ liệu thành công cho SBD: 06005557
# Đã ghi dữ liệu thành công cho SBD: 06005558
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 66
#      63     print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
#      65 # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
# ---> 66 time.sleep(0.4)
#
# KeyboardInterrupt:

# %%
import requests
import time
import csv

# Đường dẫn đến file CSV
file_path = r"E:\\DA\\Crawl\\07_LaiChau.csv"

# Mở file CSV để ghi dữ liệu
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Ghi tiêu đề cột
    writer.writerow([
        'SBD', 'Toan', 'Van', 'NgoaiNgu', 'VatLy', 'HoaHoc', 'SinhHoc',
        'TBKHTN', 'LichSu', 'DiaLy', 'GDCD', 'TBKHXH'
    ])
    
    # Vòng lặp lấy dữ liệu
    for x in range(7000001, 8000001):
        scraping_url = f"https://dantri.com.vn/thpt/1/0/99/{x}/2024/0.2/search-gradle.htm"
        
        try:
            # Gửi yêu cầu
            response = requests.get(scraping_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            
            # Phân tích phản hồi JSON
            data = response.json()
            
            # Kiểm tra nếu có khóa 'student' trong phản hồi
            if 'student' in data:
                info = data['student']
                
                # Ghi dữ liệu vào file CSV
                writer.writerow([
                    info.get('sbd', 'None'),
                    info.get('toan', 'None'),
                    info.get('van', 'None'),
                    info.get('ngoaiNgu', 'None'),
                    info.get('vatLy', 'None'),
                    info.get('hoaHoc', 'None'),
                    info.get('sinhHoc', 'None'),
                    info.get('diemTBTuNhien', 'None'),
                    info.get('lichSu', 'None'),
                    info.get('diaLy', 'None'),
                    info.get('gdcd', 'None'),
                    info.get('diemTBXaHoi', 'None')
                ])
                
                # Hiển thị thông báo đã ghi dữ liệu thành công
                print(f"Đã ghi dữ liệu thành công cho SBD: {info.get('sbd', 'Unknown')}")

                # Đảm bảo dữ liệu được ghi vào tệp ngay lập tức
                file.flush()
            else:
                print(f"Không có khóa 'student' trong phản hồi cho URL: {scraping_url}")
            
        except requests.RequestException as e:
            print(f"Yêu cầu không thành công cho URL {scraping_url}: {e}")
        except ValueError as e:
            print(f"Lỗi khi phân tích cú pháp JSON cho URL {scraping_url}: {e}")
        except csv.Error as e:
            print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
        
        # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
        time.sleep(0.4)
# Out:
# Đã ghi dữ liệu thành công cho SBD: 07000001
# Đã ghi dữ liệu thành công cho SBD: 07000002
# Đã ghi dữ liệu thành công cho SBD: 07000003
# Đã ghi dữ liệu thành công cho SBD: 07000004
# Đã ghi dữ liệu thành công cho SBD: 07000005
# Đã ghi dữ liệu thành công cho SBD: 07000006
# Đã ghi dữ liệu thành công cho SBD: 07000007
# Đã ghi dữ liệu thành công cho SBD: 07000008
# Đã ghi dữ liệu thành công cho SBD: 07000009
# Đã ghi dữ liệu thành công cho SBD: 07000010
# Đã ghi dữ liệu thành công cho SBD: 07000011
# Đã ghi dữ liệu thành công cho SBD: 07000012
# Đã ghi dữ liệu thành công cho SBD: 07000013
# Đã ghi dữ liệu thành công cho SBD: 07000014
# Đã ghi dữ liệu thành công cho SBD: 07000015
# Đã ghi dữ liệu thành công cho SBD: 07000016
# Đã ghi dữ liệu thành công cho SBD: 07000017
# Đã ghi dữ liệu thành công cho SBD: 07000018
# Đã ghi dữ liệu thành công cho SBD: 07000019
# Đã ghi dữ liệu thành công cho SBD: 07000020
# Đã ghi dữ liệu thành công cho SBD: 07000021
# Đã ghi dữ liệu thành công cho SBD: 07000022
# Đã ghi dữ liệu thành công cho SBD: 07000023
# Đã ghi dữ liệu thành công cho SBD: 07000024
# Đã ghi dữ liệu thành công cho SBD: 07000025
# Đã ghi dữ liệu thành công cho SBD: 07000026
# Đã ghi dữ liệu thành công cho SBD: 07000027
# Đã ghi dữ liệu thành công cho SBD: 07000028
# Đã ghi dữ liệu thành công cho SBD: 07000029
# Đã ghi dữ liệu thành công cho SBD: 07000030
# Đã ghi dữ liệu thành công cho SBD: 07000031
# Đã ghi dữ liệu thành công cho SBD: 07000032
# Đã ghi dữ liệu thành công cho SBD: 07000033
# Đã ghi dữ liệu thành công cho SBD: 07000034
# Đã ghi dữ liệu thành công cho SBD: 07000035
# Đã ghi dữ liệu thành công cho SBD: 07000036
# Đã ghi dữ liệu thành công cho SBD: 07000037
# Đã ghi dữ liệu thành công cho SBD: 07000038
# Đã ghi dữ liệu thành công cho SBD: 07000039
# Đã ghi dữ liệu thành công cho SBD: 07000040
# Đã ghi dữ liệu thành công cho SBD: 07000041
# Đã ghi dữ liệu thành công cho SBD: 07000042
# Đã ghi dữ liệu thành công cho SBD: 07000043
# Đã ghi dữ liệu thành công cho SBD: 07000044
# Đã ghi dữ liệu thành công cho SBD: 07000045
# Đã ghi dữ liệu thành công cho SBD: 07000046
# Đã ghi dữ liệu thành công cho SBD: 07000047
# Đã ghi dữ liệu thành công cho SBD: 07000048
# Đã ghi dữ liệu thành công cho SBD: 07000049
# Đã ghi dữ liệu thành công cho SBD: 07000050
# Đã ghi dữ liệu thành công cho SBD: 07000051
# Đã ghi dữ liệu thành công cho SBD: 07000052
# Đã ghi dữ liệu thành công cho SBD: 07000053
# Đã ghi dữ liệu thành công cho SBD: 07000054
# Đã ghi dữ liệu thành công cho SBD: 07000055
# Đã ghi dữ liệu thành công cho SBD: 07000056
# Đã ghi dữ liệu thành công cho SBD: 07000057
# Đã ghi dữ liệu thành công cho SBD: 07000058
# Đã ghi dữ liệu thành công cho SBD: 07000059
# Đã ghi dữ liệu thành công cho SBD: 07000060
# Đã ghi dữ liệu thành công cho SBD: 07000061
# Đã ghi dữ liệu thành công cho SBD: 07000062
# Đã ghi dữ liệu thành công cho SBD: 07000063
# Đã ghi dữ liệu thành công cho SBD: 07000064
# Đã ghi dữ liệu thành công cho SBD: 07000065
# Đã ghi dữ liệu thành công cho SBD: 07000066
# Đã ghi dữ liệu thành công cho SBD: 07000067
# Đã ghi dữ liệu thành công cho SBD: 07000068
# Đã ghi dữ liệu thành công cho SBD: 07000069
# Đã ghi dữ liệu thành công cho SBD: 07000070
# Đã ghi dữ liệu thành công cho SBD: 07000071
# Đã ghi dữ liệu thành công cho SBD: 07000072
# Đã ghi dữ liệu thành công cho SBD: 07000073
# Đã ghi dữ liệu thành công cho SBD: 07000074
# Đã ghi dữ liệu thành công cho SBD: 07000075
# Đã ghi dữ liệu thành công cho SBD: 07000076
# Đã ghi dữ liệu thành công cho SBD: 07000077
# Đã ghi dữ liệu thành công cho SBD: 07000078
# Đã ghi dữ liệu thành công cho SBD: 07000079
# Đã ghi dữ liệu thành công cho SBD: 07000080
# Đã ghi dữ liệu thành công cho SBD: 07000081
# Đã ghi dữ liệu thành công cho SBD: 07000082
# Đã ghi dữ liệu thành công cho SBD: 07000083
# Đã ghi dữ liệu thành công cho SBD: 07000084
# Đã ghi dữ liệu thành công cho SBD: 07000085
# Đã ghi dữ liệu thành công cho SBD: 07000086
# Đã ghi dữ liệu thành công cho SBD: 07000087
# Đã ghi dữ liệu thành công cho SBD: 07000088
# Đã ghi dữ liệu thành công cho SBD: 07000089
# Đã ghi dữ liệu thành công cho SBD: 07000090
# Đã ghi dữ liệu thành công cho SBD: 07000091
# Đã ghi dữ liệu thành công cho SBD: 07000092
# Đã ghi dữ liệu thành công cho SBD: 07000093
# Đã ghi dữ liệu thành công cho SBD: 07000094
# Đã ghi dữ liệu thành công cho SBD: 07000095
# Đã ghi dữ liệu thành công cho SBD: 07000096
# Đã ghi dữ liệu thành công cho SBD: 07000097
# Đã ghi dữ liệu thành công cho SBD: 07000098
# Đã ghi dữ liệu thành công cho SBD: 07000099
# Đã ghi dữ liệu thành công cho SBD: 07000100
# Đã ghi dữ liệu thành công cho SBD: 07000101
# Đã ghi dữ liệu thành công cho SBD: 07000102
# Đã ghi dữ liệu thành công cho SBD: 07000103
# Đã ghi dữ liệu thành công cho SBD: 07000104
# Đã ghi dữ liệu thành công cho SBD: 07000105
# Đã ghi dữ liệu thành công cho SBD: 07000106
# Đã ghi dữ liệu thành công cho SBD: 07000107
# Đã ghi dữ liệu thành công cho SBD: 07000108
# Đã ghi dữ liệu thành công cho SBD: 07000109
# Đã ghi dữ liệu thành công cho SBD: 07000110
# Đã ghi dữ liệu thành công cho SBD: 07000111
# Đã ghi dữ liệu thành công cho SBD: 07000112
# Đã ghi dữ liệu thành công cho SBD: 07000113
# Đã ghi dữ liệu thành công cho SBD: 07000114
# Đã ghi dữ liệu thành công cho SBD: 07000115
# Đã ghi dữ liệu thành công cho SBD: 07000116
# Đã ghi dữ liệu thành công cho SBD: 07000117
# Đã ghi dữ liệu thành công cho SBD: 07000118
# Đã ghi dữ liệu thành công cho SBD: 07000119
# Đã ghi dữ liệu thành công cho SBD: 07000120
# Đã ghi dữ liệu thành công cho SBD: 07000121
# Đã ghi dữ liệu thành công cho SBD: 07000122
# Đã ghi dữ liệu thành công cho SBD: 07000123
# Đã ghi dữ liệu thành công cho SBD: 07000124
# Đã ghi dữ liệu thành công cho SBD: 07000125
# Đã ghi dữ liệu thành công cho SBD: 07000126
# Đã ghi dữ liệu thành công cho SBD: 07000127
# Đã ghi dữ liệu thành công cho SBD: 07000128
# Đã ghi dữ liệu thành công cho SBD: 07000129
# Đã ghi dữ liệu thành công cho SBD: 07000130
# Đã ghi dữ liệu thành công cho SBD: 07000131
# Đã ghi dữ liệu thành công cho SBD: 07000132
# Đã ghi dữ liệu thành công cho SBD: 07000133
# Đã ghi dữ liệu thành công cho SBD: 07000134
# Đã ghi dữ liệu thành công cho SBD: 07000135
# Đã ghi dữ liệu thành công cho SBD: 07000136
# Đã ghi dữ liệu thành công cho SBD: 07000137
# Đã ghi dữ liệu thành công cho SBD: 07000138
# Đã ghi dữ liệu thành công cho SBD: 07000139
# Đã ghi dữ liệu thành công cho SBD: 07000140
# Đã ghi dữ liệu thành công cho SBD: 07000141
# Đã ghi dữ liệu thành công cho SBD: 07000142
# Đã ghi dữ liệu thành công cho SBD: 07000143
# Đã ghi dữ liệu thành công cho SBD: 07000144
# Đã ghi dữ liệu thành công cho SBD: 07000145
# Đã ghi dữ liệu thành công cho SBD: 07000146
# Đã ghi dữ liệu thành công cho SBD: 07000147
# Đã ghi dữ liệu thành công cho SBD: 07000148
# Đã ghi dữ liệu thành công cho SBD: 07000149
# Đã ghi dữ liệu thành công cho SBD: 07000150
# Đã ghi dữ liệu thành công cho SBD: 07000151
# Đã ghi dữ liệu thành công cho SBD: 07000152
# Đã ghi dữ liệu thành công cho SBD: 07000153
# Đã ghi dữ liệu thành công cho SBD: 07000154
# Đã ghi dữ liệu thành công cho SBD: 07000155
# Đã ghi dữ liệu thành công cho SBD: 07000156
# Đã ghi dữ liệu thành công cho SBD: 07000157
# Đã ghi dữ liệu thành công cho SBD: 07000158
# Đã ghi dữ liệu thành công cho SBD: 07000159
# Đã ghi dữ liệu thành công cho SBD: 07000160
# Đã ghi dữ liệu thành công cho SBD: 07000161
# Đã ghi dữ liệu thành công cho SBD: 07000162
# Đã ghi dữ liệu thành công cho SBD: 07000163
# Đã ghi dữ liệu thành công cho SBD: 07000164
# Đã ghi dữ liệu thành công cho SBD: 07000165
# Đã ghi dữ liệu thành công cho SBD: 07000166
# Đã ghi dữ liệu thành công cho SBD: 07000167
# Đã ghi dữ liệu thành công cho SBD: 07000168
# Đã ghi dữ liệu thành công cho SBD: 07000169
# Đã ghi dữ liệu thành công cho SBD: 07000170
# Đã ghi dữ liệu thành công cho SBD: 07000171
# Đã ghi dữ liệu thành công cho SBD: 07000172
# Đã ghi dữ liệu thành công cho SBD: 07000173
# Đã ghi dữ liệu thành công cho SBD: 07000174
# Đã ghi dữ liệu thành công cho SBD: 07000175
# Đã ghi dữ liệu thành công cho SBD: 07000176
# Đã ghi dữ liệu thành công cho SBD: 07000177
# Đã ghi dữ liệu thành công cho SBD: 07000178
# Đã ghi dữ liệu thành công cho SBD: 07000179
# Đã ghi dữ liệu thành công cho SBD: 07000180
# Đã ghi dữ liệu thành công cho SBD: 07000181
# Đã ghi dữ liệu thành công cho SBD: 07000182
# Đã ghi dữ liệu thành công cho SBD: 07000183
# Đã ghi dữ liệu thành công cho SBD: 07000184
# Đã ghi dữ liệu thành công cho SBD: 07000185
# Đã ghi dữ liệu thành công cho SBD: 07000186
# Đã ghi dữ liệu thành công cho SBD: 07000187
# Đã ghi dữ liệu thành công cho SBD: 07000188
# Đã ghi dữ liệu thành công cho SBD: 07000189
# Đã ghi dữ liệu thành công cho SBD: 07000190
# Đã ghi dữ liệu thành công cho SBD: 07000191
# Đã ghi dữ liệu thành công cho SBD: 07000192
# Đã ghi dữ liệu thành công cho SBD: 07000193
# Đã ghi dữ liệu thành công cho SBD: 07000194
# Đã ghi dữ liệu thành công cho SBD: 07000195
# Đã ghi dữ liệu thành công cho SBD: 07000196
# Đã ghi dữ liệu thành công cho SBD: 07000197
# Đã ghi dữ liệu thành công cho SBD: 07000198
# Đã ghi dữ liệu thành công cho SBD: 07000199
# Đã ghi dữ liệu thành công cho SBD: 07000200
# Đã ghi dữ liệu thành công cho SBD: 07000201
# Đã ghi dữ liệu thành công cho SBD: 07000202
# Đã ghi dữ liệu thành công cho SBD: 07000203
# Đã ghi dữ liệu thành công cho SBD: 07000204
# Đã ghi dữ liệu thành công cho SBD: 07000205
# Đã ghi dữ liệu thành công cho SBD: 07000206
# Đã ghi dữ liệu thành công cho SBD: 07000207
# Đã ghi dữ liệu thành công cho SBD: 07000208
# Đã ghi dữ liệu thành công cho SBD: 07000209
# Đã ghi dữ liệu thành công cho SBD: 07000210
# Đã ghi dữ liệu thành công cho SBD: 07000211
# Đã ghi dữ liệu thành công cho SBD: 07000212
# Đã ghi dữ liệu thành công cho SBD: 07000213
# Đã ghi dữ liệu thành công cho SBD: 07000214
# Đã ghi dữ liệu thành công cho SBD: 07000215
# Đã ghi dữ liệu thành công cho SBD: 07000216
# Đã ghi dữ liệu thành công cho SBD: 07000217
# Đã ghi dữ liệu thành công cho SBD: 07000218
# Đã ghi dữ liệu thành công cho SBD: 07000219
# Đã ghi dữ liệu thành công cho SBD: 07000220
# Đã ghi dữ liệu thành công cho SBD: 07000221
# Đã ghi dữ liệu thành công cho SBD: 07000222
# Đã ghi dữ liệu thành công cho SBD: 07000223
# Đã ghi dữ liệu thành công cho SBD: 07000224
# Đã ghi dữ liệu thành công cho SBD: 07000225
# Đã ghi dữ liệu thành công cho SBD: 07000226
# Đã ghi dữ liệu thành công cho SBD: 07000227
# Đã ghi dữ liệu thành công cho SBD: 07000228
# Đã ghi dữ liệu thành công cho SBD: 07000229
# Đã ghi dữ liệu thành công cho SBD: 07000230
# Đã ghi dữ liệu thành công cho SBD: 07000231
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 07000233
# Đã ghi dữ liệu thành công cho SBD: 07000234
# Đã ghi dữ liệu thành công cho SBD: 07000235
# Đã ghi dữ liệu thành công cho SBD: 07000236
# Đã ghi dữ liệu thành công cho SBD: 07000237
# Đã ghi dữ liệu thành công cho SBD: 07000238
# Đã ghi dữ liệu thành công cho SBD: 07000239
# Đã ghi dữ liệu thành công cho SBD: 07000240
# Đã ghi dữ liệu thành công cho SBD: 07000241
# Đã ghi dữ liệu thành công cho SBD: 07000242
# Đã ghi dữ liệu thành công cho SBD: 07000243
# Đã ghi dữ liệu thành công cho SBD: 07000244
# Đã ghi dữ liệu thành công cho SBD: 07000245
# Đã ghi dữ liệu thành công cho SBD: 07000246
# Đã ghi dữ liệu thành công cho SBD: 07000247
# Đã ghi dữ liệu thành công cho SBD: 07000248
# Đã ghi dữ liệu thành công cho SBD: 07000249
# Đã ghi dữ liệu thành công cho SBD: 07000250
# Đã ghi dữ liệu thành công cho SBD: 07000251
# Đã ghi dữ liệu thành công cho SBD: 07000252
# Đã ghi dữ liệu thành công cho SBD: 07000253
# Đã ghi dữ liệu thành công cho SBD: 07000254
# Đã ghi dữ liệu thành công cho SBD: 07000255
# Đã ghi dữ liệu thành công cho SBD: 07000256
# Đã ghi dữ liệu thành công cho SBD: 07000257
# Đã ghi dữ liệu thành công cho SBD: 07000258
# Đã ghi dữ liệu thành công cho SBD: 07000259
# Đã ghi dữ liệu thành công cho SBD: 07000260
# Đã ghi dữ liệu thành công cho SBD: 07000261
# Đã ghi dữ liệu thành công cho SBD: 07000262
# Đã ghi dữ liệu thành công cho SBD: 07000263
# Đã ghi dữ liệu thành công cho SBD: 07000264
# Đã ghi dữ liệu thành công cho SBD: 07000265
# Đã ghi dữ liệu thành công cho SBD: 07000266
# Đã ghi dữ liệu thành công cho SBD: 07000267
# Đã ghi dữ liệu thành công cho SBD: 07000268
# Đã ghi dữ liệu thành công cho SBD: 07000269
# Đã ghi dữ liệu thành công cho SBD: 07000270
# Đã ghi dữ liệu thành công cho SBD: 07000271
# Đã ghi dữ liệu thành công cho SBD: 07000272
# Đã ghi dữ liệu thành công cho SBD: 07000273
# Đã ghi dữ liệu thành công cho SBD: 07000274
# Đã ghi dữ liệu thành công cho SBD: 07000275
# Đã ghi dữ liệu thành công cho SBD: 07000276
# Đã ghi dữ liệu thành công cho SBD: 07000277
# Đã ghi dữ liệu thành công cho SBD: 07000278
# Đã ghi dữ liệu thành công cho SBD: 07000279
# Đã ghi dữ liệu thành công cho SBD: 07000280
# Đã ghi dữ liệu thành công cho SBD: 07000281
# Đã ghi dữ liệu thành công cho SBD: 07000282
# Đã ghi dữ liệu thành công cho SBD: 07000283
# Đã ghi dữ liệu thành công cho SBD: 07000284
# Đã ghi dữ liệu thành công cho SBD: 07000285
# Đã ghi dữ liệu thành công cho SBD: 07000286
# Đã ghi dữ liệu thành công cho SBD: 07000287
# Đã ghi dữ liệu thành công cho SBD: 07000288
# Đã ghi dữ liệu thành công cho SBD: 07000289
# Đã ghi dữ liệu thành công cho SBD: 07000290
# Đã ghi dữ liệu thành công cho SBD: 07000291
# Đã ghi dữ liệu thành công cho SBD: 07000292
# Đã ghi dữ liệu thành công cho SBD: 07000293
# Đã ghi dữ liệu thành công cho SBD: 07000294
# Đã ghi dữ liệu thành công cho SBD: 07000295
# Đã ghi dữ liệu thành công cho SBD: 07000296
# Đã ghi dữ liệu thành công cho SBD: 07000297
# Đã ghi dữ liệu thành công cho SBD: 07000298
# Đã ghi dữ liệu thành công cho SBD: 07000299
# Đã ghi dữ liệu thành công cho SBD: 07000300
# Đã ghi dữ liệu thành công cho SBD: 07000301
# Đã ghi dữ liệu thành công cho SBD: 07000302
# Đã ghi dữ liệu thành công cho SBD: 07000303
# Đã ghi dữ liệu thành công cho SBD: 07000304
# Đã ghi dữ liệu thành công cho SBD: 07000305
# Đã ghi dữ liệu thành công cho SBD: 07000306
# Đã ghi dữ liệu thành công cho SBD: 07000307
# Đã ghi dữ liệu thành công cho SBD: 07000308
# Đã ghi dữ liệu thành công cho SBD: 07000309
# Đã ghi dữ liệu thành công cho SBD: 07000310
# Đã ghi dữ liệu thành công cho SBD: 07000311
# Đã ghi dữ liệu thành công cho SBD: 07000312
# Đã ghi dữ liệu thành công cho SBD: 07000313
# Đã ghi dữ liệu thành công cho SBD: 07000314
# Đã ghi dữ liệu thành công cho SBD: 07000315
# Đã ghi dữ liệu thành công cho SBD: 07000316
# Đã ghi dữ liệu thành công cho SBD: 07000317
# Đã ghi dữ liệu thành công cho SBD: 07000318
# Đã ghi dữ liệu thành công cho SBD: 07000319
# Đã ghi dữ liệu thành công cho SBD: 07000320
# Đã ghi dữ liệu thành công cho SBD: 07000321
# Đã ghi dữ liệu thành công cho SBD: 07000322
# Đã ghi dữ liệu thành công cho SBD: 07000323
# Đã ghi dữ liệu thành công cho SBD: 07000324
# Đã ghi dữ liệu thành công cho SBD: 07000325
# Đã ghi dữ liệu thành công cho SBD: 07000326
# Đã ghi dữ liệu thành công cho SBD: 07000327
# Đã ghi dữ liệu thành công cho SBD: 07000328
# Đã ghi dữ liệu thành công cho SBD: 07000329
# Đã ghi dữ liệu thành công cho SBD: 07000330
# Đã ghi dữ liệu thành công cho SBD: 07000331
# Đã ghi dữ liệu thành công cho SBD: 07000332
# Đã ghi dữ liệu thành công cho SBD: 07000333
# Đã ghi dữ liệu thành công cho SBD: 07000334
# Đã ghi dữ liệu thành công cho SBD: 07000335
# Đã ghi dữ liệu thành công cho SBD: 07000336
# Đã ghi dữ liệu thành công cho SBD: 07000337
# Đã ghi dữ liệu thành công cho SBD: 07000338
# Đã ghi dữ liệu thành công cho SBD: 07000339
# Đã ghi dữ liệu thành công cho SBD: 07000340
# Đã ghi dữ liệu thành công cho SBD: 07000341
# Đã ghi dữ liệu thành công cho SBD: 07000342
# Đã ghi dữ liệu thành công cho SBD: 07000343
# Đã ghi dữ liệu thành công cho SBD: 07000344
# Đã ghi dữ liệu thành công cho SBD: 07000345
# Đã ghi dữ liệu thành công cho SBD: 07000346
# Đã ghi dữ liệu thành công cho SBD: 07000347
# Đã ghi dữ liệu thành công cho SBD: 07000348
# Đã ghi dữ liệu thành công cho SBD: 07000349
# Đã ghi dữ liệu thành công cho SBD: 07000350
# Đã ghi dữ liệu thành công cho SBD: 07000351
# Đã ghi dữ liệu thành công cho SBD: 07000352
# Đã ghi dữ liệu thành công cho SBD: 07000353
# Đã ghi dữ liệu thành công cho SBD: 07000354
# Đã ghi dữ liệu thành công cho SBD: 07000355
# Đã ghi dữ liệu thành công cho SBD: 07000356
# Đã ghi dữ liệu thành công cho SBD: 07000357
# Đã ghi dữ liệu thành công cho SBD: 07000358
# Đã ghi dữ liệu thành công cho SBD: 07000359
# Đã ghi dữ liệu thành công cho SBD: 07000360
# Đã ghi dữ liệu thành công cho SBD: 07000361
# Đã ghi dữ liệu thành công cho SBD: 07000362
# Đã ghi dữ liệu thành công cho SBD: 07000363
# Đã ghi dữ liệu thành công cho SBD: 07000364
# Đã ghi dữ liệu thành công cho SBD: 07000365
# Đã ghi dữ liệu thành công cho SBD: 07000366
# Đã ghi dữ liệu thành công cho SBD: 07000367
# Đã ghi dữ liệu thành công cho SBD: 07000368
# Đã ghi dữ liệu thành công cho SBD: 07000369
# Đã ghi dữ liệu thành công cho SBD: 07000370
# Đã ghi dữ liệu thành công cho SBD: 07000371
# Đã ghi dữ liệu thành công cho SBD: 07000372
# Đã ghi dữ liệu thành công cho SBD: 07000373
# Đã ghi dữ liệu thành công cho SBD: 07000374
# Đã ghi dữ liệu thành công cho SBD: 07000375
# Đã ghi dữ liệu thành công cho SBD: 07000376
# Đã ghi dữ liệu thành công cho SBD: 07000377
# Đã ghi dữ liệu thành công cho SBD: 07000378
# Đã ghi dữ liệu thành công cho SBD: 07000379
# Đã ghi dữ liệu thành công cho SBD: 07000380
# Đã ghi dữ liệu thành công cho SBD: 07000381
# Đã ghi dữ liệu thành công cho SBD: 07000382
# Đã ghi dữ liệu thành công cho SBD: 07000383
# Đã ghi dữ liệu thành công cho SBD: 07000384
# Đã ghi dữ liệu thành công cho SBD: 07000385
# Đã ghi dữ liệu thành công cho SBD: 07000386
# Đã ghi dữ liệu thành công cho SBD: 07000387
# Đã ghi dữ liệu thành công cho SBD: 07000388
# Đã ghi dữ liệu thành công cho SBD: 07000389
# Đã ghi dữ liệu thành công cho SBD: 07000390
# Đã ghi dữ liệu thành công cho SBD: 07000391
# Đã ghi dữ liệu thành công cho SBD: 07000392
# Đã ghi dữ liệu thành công cho SBD: 07000393
# Đã ghi dữ liệu thành công cho SBD: 07000394
# Đã ghi dữ liệu thành công cho SBD: 07000395
# Đã ghi dữ liệu thành công cho SBD: 07000396
# Đã ghi dữ liệu thành công cho SBD: 07000397
# Đã ghi dữ liệu thành công cho SBD: 07000398
# Đã ghi dữ liệu thành công cho SBD: 07000399
# Đã ghi dữ liệu thành công cho SBD: 07000400
# Đã ghi dữ liệu thành công cho SBD: 07000401
# Đã ghi dữ liệu thành công cho SBD: 07000402
# Đã ghi dữ liệu thành công cho SBD: 07000403
# Đã ghi dữ liệu thành công cho SBD: 07000404
# Đã ghi dữ liệu thành công cho SBD: 07000405
# Đã ghi dữ liệu thành công cho SBD: 07000406
# Đã ghi dữ liệu thành công cho SBD: 07000407
# Đã ghi dữ liệu thành công cho SBD: 07000408
# Đã ghi dữ liệu thành công cho SBD: 07000409
# Đã ghi dữ liệu thành công cho SBD: 07000410
# Đã ghi dữ liệu thành công cho SBD: 07000411
# Đã ghi dữ liệu thành công cho SBD: 07000412
# Đã ghi dữ liệu thành công cho SBD: 07000413
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 07000415
# Đã ghi dữ liệu thành công cho SBD: 07000416
# Đã ghi dữ liệu thành công cho SBD: 07000417
# Đã ghi dữ liệu thành công cho SBD: 07000418
# Đã ghi dữ liệu thành công cho SBD: 07000419
# Đã ghi dữ liệu thành công cho SBD: 07000420
# Đã ghi dữ liệu thành công cho SBD: 07000421
# Đã ghi dữ liệu thành công cho SBD: 07000422
# Đã ghi dữ liệu thành công cho SBD: 07000423
# Đã ghi dữ liệu thành công cho SBD: 07000424
# Đã ghi dữ liệu thành công cho SBD: 07000425
# Đã ghi dữ liệu thành công cho SBD: 07000426
# Đã ghi dữ liệu thành công cho SBD: 07000427
# Đã ghi dữ liệu thành công cho SBD: 07000428
# Đã ghi dữ liệu thành công cho SBD: 07000429
# Đã ghi dữ liệu thành công cho SBD: 07000430
# Đã ghi dữ liệu thành công cho SBD: 07000431
# Đã ghi dữ liệu thành công cho SBD: 07000432
# Đã ghi dữ liệu thành công cho SBD: 07000433
# Đã ghi dữ liệu thành công cho SBD: 07000434
# Đã ghi dữ liệu thành công cho SBD: 07000435
# Đã ghi dữ liệu thành công cho SBD: 07000436
# Đã ghi dữ liệu thành công cho SBD: 07000437
# Đã ghi dữ liệu thành công cho SBD: 07000438
# Đã ghi dữ liệu thành công cho SBD: 07000439
# Đã ghi dữ liệu thành công cho SBD: 07000440
# Đã ghi dữ liệu thành công cho SBD: 07000441
# Đã ghi dữ liệu thành công cho SBD: 07000442
# Đã ghi dữ liệu thành công cho SBD: 07000443
# Đã ghi dữ liệu thành công cho SBD: 07000444
# Đã ghi dữ liệu thành công cho SBD: 07000445
# Đã ghi dữ liệu thành công cho SBD: 07000446
# Đã ghi dữ liệu thành công cho SBD: 07000447
# Đã ghi dữ liệu thành công cho SBD: 07000448
# Đã ghi dữ liệu thành công cho SBD: 07000449
# Đã ghi dữ liệu thành công cho SBD: 07000450
# Đã ghi dữ liệu thành công cho SBD: 07000451
# Đã ghi dữ liệu thành công cho SBD: 07000452
# Đã ghi dữ liệu thành công cho SBD: 07000453
# Đã ghi dữ liệu thành công cho SBD: 07000454
# Đã ghi dữ liệu thành công cho SBD: 07000455
# Đã ghi dữ liệu thành công cho SBD: 07000456
# Đã ghi dữ liệu thành công cho SBD: 07000457
# Đã ghi dữ liệu thành công cho SBD: 07000458
# Đã ghi dữ liệu thành công cho SBD: 07000459
# Đã ghi dữ liệu thành công cho SBD: 07000460
# Đã ghi dữ liệu thành công cho SBD: 07000461
# Đã ghi dữ liệu thành công cho SBD: 07000462
# Đã ghi dữ liệu thành công cho SBD: 07000463
# Đã ghi dữ liệu thành công cho SBD: 07000464
# Đã ghi dữ liệu thành công cho SBD: 07000465
# Đã ghi dữ liệu thành công cho SBD: 07000466
# Đã ghi dữ liệu thành công cho SBD: 07000467
# Đã ghi dữ liệu thành công cho SBD: 07000468
# Đã ghi dữ liệu thành công cho SBD: 07000469
# Đã ghi dữ liệu thành công cho SBD: 07000470
# Đã ghi dữ liệu thành công cho SBD: 07000471
# Đã ghi dữ liệu thành công cho SBD: 07000472
# Đã ghi dữ liệu thành công cho SBD: 07000473
# Đã ghi dữ liệu thành công cho SBD: 07000474
# Đã ghi dữ liệu thành công cho SBD: 07000475
# Đã ghi dữ liệu thành công cho SBD: 07000476
# Đã ghi dữ liệu thành công cho SBD: 07000477
# Đã ghi dữ liệu thành công cho SBD: 07000478
# Đã ghi dữ liệu thành công cho SBD: 07000479
# Đã ghi dữ liệu thành công cho SBD: 07000480
# Đã ghi dữ liệu thành công cho SBD: 07000481
# Đã ghi dữ liệu thành công cho SBD: 07000482
# Đã ghi dữ liệu thành công cho SBD: 07000483
# Đã ghi dữ liệu thành công cho SBD: 07000484
# Đã ghi dữ liệu thành công cho SBD: 07000485
# Đã ghi dữ liệu thành công cho SBD: 07000486
# Đã ghi dữ liệu thành công cho SBD: 07000487
# Đã ghi dữ liệu thành công cho SBD: 07000488
# Đã ghi dữ liệu thành công cho SBD: 07000489
# Đã ghi dữ liệu thành công cho SBD: 07000490
# Đã ghi dữ liệu thành công cho SBD: 07000491
# Đã ghi dữ liệu thành công cho SBD: 07000492
# Đã ghi dữ liệu thành công cho SBD: 07000493
# Đã ghi dữ liệu thành công cho SBD: 07000494
# Đã ghi dữ liệu thành công cho SBD: 07000495
# Đã ghi dữ liệu thành công cho SBD: 07000496
# Đã ghi dữ liệu thành công cho SBD: 07000497
# Đã ghi dữ liệu thành công cho SBD: 07000498
# Đã ghi dữ liệu thành công cho SBD: 07000499
# Đã ghi dữ liệu thành công cho SBD: 07000500
# Đã ghi dữ liệu thành công cho SBD: 07000501
# Đã ghi dữ liệu thành công cho SBD: 07000502
# Đã ghi dữ liệu thành công cho SBD: 07000503
# Đã ghi dữ liệu thành công cho SBD: 07000504
# Đã ghi dữ liệu thành công cho SBD: 07000505
# Đã ghi dữ liệu thành công cho SBD: 07000506
# Đã ghi dữ liệu thành công cho SBD: 07000507
# Đã ghi dữ liệu thành công cho SBD: 07000508
# Đã ghi dữ liệu thành công cho SBD: 07000509
# Đã ghi dữ liệu thành công cho SBD: 07000510
# Đã ghi dữ liệu thành công cho SBD: 07000511
# Đã ghi dữ liệu thành công cho SBD: 07000512
# Đã ghi dữ liệu thành công cho SBD: 07000513
# Đã ghi dữ liệu thành công cho SBD: 07000514
# Đã ghi dữ liệu thành công cho SBD: 07000515
# Đã ghi dữ liệu thành công cho SBD: 07000516
# Đã ghi dữ liệu thành công cho SBD: 07000517
# Đã ghi dữ liệu thành công cho SBD: 07000518
# Đã ghi dữ liệu thành công cho SBD: 07000519
# Đã ghi dữ liệu thành công cho SBD: 07000520
# Đã ghi dữ liệu thành công cho SBD: 07000521
# Đã ghi dữ liệu thành công cho SBD: 07000522
# Đã ghi dữ liệu thành công cho SBD: 07000523
# Đã ghi dữ liệu thành công cho SBD: 07000524
# Đã ghi dữ liệu thành công cho SBD: 07000525
# Đã ghi dữ liệu thành công cho SBD: 07000526
# Đã ghi dữ liệu thành công cho SBD: 07000527
# Đã ghi dữ liệu thành công cho SBD: 07000528
# Đã ghi dữ liệu thành công cho SBD: 07000529
# Đã ghi dữ liệu thành công cho SBD: 07000530
# Đã ghi dữ liệu thành công cho SBD: 07000531
# Đã ghi dữ liệu thành công cho SBD: 07000532
# Đã ghi dữ liệu thành công cho SBD: 07000533
# Đã ghi dữ liệu thành công cho SBD: 07000534
# Đã ghi dữ liệu thành công cho SBD: 07000535
# Đã ghi dữ liệu thành công cho SBD: 07000536
# Đã ghi dữ liệu thành công cho SBD: 07000537
# Đã ghi dữ liệu thành công cho SBD: 07000538
# Đã ghi dữ liệu thành công cho SBD: 07000539
# Đã ghi dữ liệu thành công cho SBD: 07000540
# Đã ghi dữ liệu thành công cho SBD: 07000541
# Đã ghi dữ liệu thành công cho SBD: 07000542
# Đã ghi dữ liệu thành công cho SBD: 07000543
# Đã ghi dữ liệu thành công cho SBD: 07000544
# Đã ghi dữ liệu thành công cho SBD: 07000545
# Đã ghi dữ liệu thành công cho SBD: 07000546
# Đã ghi dữ liệu thành công cho SBD: 07000547
# Đã ghi dữ liệu thành công cho SBD: 07000548
# Đã ghi dữ liệu thành công cho SBD: 07000549
# Đã ghi dữ liệu thành công cho SBD: 07000550
# Đã ghi dữ liệu thành công cho SBD: 07000551
# Đã ghi dữ liệu thành công cho SBD: 07000552
# Đã ghi dữ liệu thành công cho SBD: 07000553
# Đã ghi dữ liệu thành công cho SBD: 07000554
# Đã ghi dữ liệu thành công cho SBD: 07000555
# Đã ghi dữ liệu thành công cho SBD: 07000556
# Đã ghi dữ liệu thành công cho SBD: 07000557
# Đã ghi dữ liệu thành công cho SBD: 07000558
# Đã ghi dữ liệu thành công cho SBD: 07000559
# Đã ghi dữ liệu thành công cho SBD: 07000560
# Đã ghi dữ liệu thành công cho SBD: 07000561
# Đã ghi dữ liệu thành công cho SBD: 07000562
# Đã ghi dữ liệu thành công cho SBD: 07000563
# Đã ghi dữ liệu thành công cho SBD: 07000564
# Đã ghi dữ liệu thành công cho SBD: 07000565
# Đã ghi dữ liệu thành công cho SBD: 07000566
# Đã ghi dữ liệu thành công cho SBD: 07000567
# Đã ghi dữ liệu thành công cho SBD: 07000568
# Đã ghi dữ liệu thành công cho SBD: 07000569
# Đã ghi dữ liệu thành công cho SBD: 07000570
# Đã ghi dữ liệu thành công cho SBD: 07000571
# Đã ghi dữ liệu thành công cho SBD: 07000572
# Đã ghi dữ liệu thành công cho SBD: 07000573
# Đã ghi dữ liệu thành công cho SBD: 07000574
# Đã ghi dữ liệu thành công cho SBD: 07000575
# Đã ghi dữ liệu thành công cho SBD: 07000576
# Đã ghi dữ liệu thành công cho SBD: 07000577
# Đã ghi dữ liệu thành công cho SBD: 07000578
# Đã ghi dữ liệu thành công cho SBD: 07000579
# Đã ghi dữ liệu thành công cho SBD: 07000580
# Đã ghi dữ liệu thành công cho SBD: 07000581
# Đã ghi dữ liệu thành công cho SBD: 07000582
# Đã ghi dữ liệu thành công cho SBD: 07000583
# Đã ghi dữ liệu thành công cho SBD: 07000584
# Đã ghi dữ liệu thành công cho SBD: 07000585
# Đã ghi dữ liệu thành công cho SBD: 07000586
# Đã ghi dữ liệu thành công cho SBD: 07000587
# Đã ghi dữ liệu thành công cho SBD: 07000588
# Đã ghi dữ liệu thành công cho SBD: 07000589
# Đã ghi dữ liệu thành công cho SBD: 07000590
# Đã ghi dữ liệu thành công cho SBD: 07000591
# Đã ghi dữ liệu thành công cho SBD: 07000592
# Đã ghi dữ liệu thành công cho SBD: 07000593
# Đã ghi dữ liệu thành công cho SBD: 07000594
# Đã ghi dữ liệu thành công cho SBD: 07000595
# Đã ghi dữ liệu thành công cho SBD: 07000596
# Đã ghi dữ liệu thành công cho SBD: 07000597
# Đã ghi dữ liệu thành công cho SBD: 07000598
# Đã ghi dữ liệu thành công cho SBD: 07000599
# Đã ghi dữ liệu thành công cho SBD: 07000600
# Đã ghi dữ liệu thành công cho SBD: 07000601
# Đã ghi dữ liệu thành công cho SBD: 07000602
# Đã ghi dữ liệu thành công cho SBD: 07000603
# Đã ghi dữ liệu thành công cho SBD: 07000604
# Đã ghi dữ liệu thành công cho SBD: 07000605
# Đã ghi dữ liệu thành công cho SBD: 07000606
# Đã ghi dữ liệu thành công cho SBD: 07000607
# Đã ghi dữ liệu thành công cho SBD: 07000608
# Đã ghi dữ liệu thành công cho SBD: 07000609
# Đã ghi dữ liệu thành công cho SBD: 07000610
# Đã ghi dữ liệu thành công cho SBD: 07000611
# Đã ghi dữ liệu thành công cho SBD: 07000612
# Đã ghi dữ liệu thành công cho SBD: 07000613
# Đã ghi dữ liệu thành công cho SBD: 07000614
# Đã ghi dữ liệu thành công cho SBD: 07000615
# Đã ghi dữ liệu thành công cho SBD: 07000616
# Đã ghi dữ liệu thành công cho SBD: 07000617
# Đã ghi dữ liệu thành công cho SBD: 07000618
# Đã ghi dữ liệu thành công cho SBD: 07000619
# Đã ghi dữ liệu thành công cho SBD: 07000620
# Đã ghi dữ liệu thành công cho SBD: 07000621
# Đã ghi dữ liệu thành công cho SBD: 07000622
# Đã ghi dữ liệu thành công cho SBD: 07000623
# Đã ghi dữ liệu thành công cho SBD: 07000624
# Đã ghi dữ liệu thành công cho SBD: 07000625
# Đã ghi dữ liệu thành công cho SBD: 07000626
# Đã ghi dữ liệu thành công cho SBD: 07000627
# Đã ghi dữ liệu thành công cho SBD: 07000628
# Đã ghi dữ liệu thành công cho SBD: 07000629
# Đã ghi dữ liệu thành công cho SBD: 07000630
# Đã ghi dữ liệu thành công cho SBD: 07000631
# Đã ghi dữ liệu thành công cho SBD: 07000632
# Đã ghi dữ liệu thành công cho SBD: 07000633
# Đã ghi dữ liệu thành công cho SBD: 07000634
# Đã ghi dữ liệu thành công cho SBD: 07000635
# Đã ghi dữ liệu thành công cho SBD: 07000636
# Đã ghi dữ liệu thành công cho SBD: 07000637
# Đã ghi dữ liệu thành công cho SBD: 07000638
# Đã ghi dữ liệu thành công cho SBD: 07000639
# Đã ghi dữ liệu thành công cho SBD: 07000640
# Đã ghi dữ liệu thành công cho SBD: 07000641
# Đã ghi dữ liệu thành công cho SBD: 07000642
# Đã ghi dữ liệu thành công cho SBD: 07000643
# Đã ghi dữ liệu thành công cho SBD: 07000644
# Đã ghi dữ liệu thành công cho SBD: 07000645
# Đã ghi dữ liệu thành công cho SBD: 07000646
# Đã ghi dữ liệu thành công cho SBD: 07000647
# Đã ghi dữ liệu thành công cho SBD: 07000648
# Đã ghi dữ liệu thành công cho SBD: 07000649
# Đã ghi dữ liệu thành công cho SBD: 07000650
# Đã ghi dữ liệu thành công cho SBD: 07000651
# Đã ghi dữ liệu thành công cho SBD: 07000652
# Đã ghi dữ liệu thành công cho SBD: 07000653
# Đã ghi dữ liệu thành công cho SBD: 07000654
# Đã ghi dữ liệu thành công cho SBD: 07000655
# Đã ghi dữ liệu thành công cho SBD: 07000656
# Đã ghi dữ liệu thành công cho SBD: 07000657
# Đã ghi dữ liệu thành công cho SBD: 07000658
# Đã ghi dữ liệu thành công cho SBD: 07000659
# Đã ghi dữ liệu thành công cho SBD: 07000660
# Đã ghi dữ liệu thành công cho SBD: 07000661
# Đã ghi dữ liệu thành công cho SBD: 07000662
# Đã ghi dữ liệu thành công cho SBD: 07000663
# Đã ghi dữ liệu thành công cho SBD: 07000664
# Đã ghi dữ liệu thành công cho SBD: 07000665
# Đã ghi dữ liệu thành công cho SBD: 07000666
# Đã ghi dữ liệu thành công cho SBD: 07000667
# Đã ghi dữ liệu thành công cho SBD: 07000668
# Đã ghi dữ liệu thành công cho SBD: 07000669
# Đã ghi dữ liệu thành công cho SBD: 07000670
# Đã ghi dữ liệu thành công cho SBD: 07000671
# Đã ghi dữ liệu thành công cho SBD: 07000672
# Đã ghi dữ liệu thành công cho SBD: 07000673
# Đã ghi dữ liệu thành công cho SBD: 07000674
# Đã ghi dữ liệu thành công cho SBD: 07000675
# Đã ghi dữ liệu thành công cho SBD: 07000676
# Đã ghi dữ liệu thành công cho SBD: 07000677
# Đã ghi dữ liệu thành công cho SBD: 07000678
# Đã ghi dữ liệu thành công cho SBD: 07000679
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 07000681
# Đã ghi dữ liệu thành công cho SBD: 07000682
# Đã ghi dữ liệu thành công cho SBD: 07000683
# Đã ghi dữ liệu thành công cho SBD: 07000684
# Đã ghi dữ liệu thành công cho SBD: 07000685
# Đã ghi dữ liệu thành công cho SBD: 07000686
# Đã ghi dữ liệu thành công cho SBD: 07000687
# Đã ghi dữ liệu thành công cho SBD: 07000688
# Đã ghi dữ liệu thành công cho SBD: 07000689
# Đã ghi dữ liệu thành công cho SBD: 07000690
# Đã ghi dữ liệu thành công cho SBD: 07000691
# Đã ghi dữ liệu thành công cho SBD: 07000692
# Đã ghi dữ liệu thành công cho SBD: 07000693
# Đã ghi dữ liệu thành công cho SBD: 07000694
# Đã ghi dữ liệu thành công cho SBD: 07000695
# Đã ghi dữ liệu thành công cho SBD: 07000696
# Đã ghi dữ liệu thành công cho SBD: 07000697
# Đã ghi dữ liệu thành công cho SBD: 07000698
# Đã ghi dữ liệu thành công cho SBD: 07000699
# Đã ghi dữ liệu thành công cho SBD: 07000700
# Đã ghi dữ liệu thành công cho SBD: 07000701
# Đã ghi dữ liệu thành công cho SBD: 07000702
# Đã ghi dữ liệu thành công cho SBD: 07000703
# Đã ghi dữ liệu thành công cho SBD: 07000704
# Đã ghi dữ liệu thành công cho SBD: 07000705
# Đã ghi dữ liệu thành công cho SBD: 07000706
# Đã ghi dữ liệu thành công cho SBD: 07000707
# Đã ghi dữ liệu thành công cho SBD: 07000708
# Đã ghi dữ liệu thành công cho SBD: 07000709
# Đã ghi dữ liệu thành công cho SBD: 07000710
# Đã ghi dữ liệu thành công cho SBD: 07000711
# Đã ghi dữ liệu thành công cho SBD: 07000712
# Đã ghi dữ liệu thành công cho SBD: 07000713
# Đã ghi dữ liệu thành công cho SBD: 07000714
# Đã ghi dữ liệu thành công cho SBD: 07000715
# Đã ghi dữ liệu thành công cho SBD: 07000716
# Đã ghi dữ liệu thành công cho SBD: 07000717
# Đã ghi dữ liệu thành công cho SBD: 07000718
# Đã ghi dữ liệu thành công cho SBD: 07000719
# Đã ghi dữ liệu thành công cho SBD: 07000720
# Đã ghi dữ liệu thành công cho SBD: 07000721
# Đã ghi dữ liệu thành công cho SBD: 07000722
# Đã ghi dữ liệu thành công cho SBD: 07000723
# Đã ghi dữ liệu thành công cho SBD: 07000724
# Đã ghi dữ liệu thành công cho SBD: 07000725
# Đã ghi dữ liệu thành công cho SBD: 07000726
# Đã ghi dữ liệu thành công cho SBD: 07000727
# Đã ghi dữ liệu thành công cho SBD: 07000728
# Đã ghi dữ liệu thành công cho SBD: 07000729
# Đã ghi dữ liệu thành công cho SBD: 07000730
# Đã ghi dữ liệu thành công cho SBD: 07000731
# Đã ghi dữ liệu thành công cho SBD: 07000732
# Đã ghi dữ liệu thành công cho SBD: 07000733
# Đã ghi dữ liệu thành công cho SBD: 07000734
# Đã ghi dữ liệu thành công cho SBD: 07000735
# Đã ghi dữ liệu thành công cho SBD: 07000736
# Đã ghi dữ liệu thành công cho SBD: 07000737
# Đã ghi dữ liệu thành công cho SBD: 07000738
# Đã ghi dữ liệu thành công cho SBD: 07000739
# Đã ghi dữ liệu thành công cho SBD: 07000740
# Đã ghi dữ liệu thành công cho SBD: 07000741
# Đã ghi dữ liệu thành công cho SBD: 07000742
# Đã ghi dữ liệu thành công cho SBD: 07000743
# Đã ghi dữ liệu thành công cho SBD: 07000744
# Đã ghi dữ liệu thành công cho SBD: 07000745
# Đã ghi dữ liệu thành công cho SBD: 07000746
# Đã ghi dữ liệu thành công cho SBD: 07000747
# Đã ghi dữ liệu thành công cho SBD: 07000748
# Đã ghi dữ liệu thành công cho SBD: 07000749
# Đã ghi dữ liệu thành công cho SBD: 07000750
# Đã ghi dữ liệu thành công cho SBD: 07000751
# Đã ghi dữ liệu thành công cho SBD: 07000752
# Đã ghi dữ liệu thành công cho SBD: 07000753
# Đã ghi dữ liệu thành công cho SBD: 07000754
# Đã ghi dữ liệu thành công cho SBD: 07000755
# Đã ghi dữ liệu thành công cho SBD: 07000756
# Đã ghi dữ liệu thành công cho SBD: 07000757
# Đã ghi dữ liệu thành công cho SBD: 07000758
# Đã ghi dữ liệu thành công cho SBD: 07000759
# Đã ghi dữ liệu thành công cho SBD: 07000760
# Đã ghi dữ liệu thành công cho SBD: 07000761
# Đã ghi dữ liệu thành công cho SBD: 07000762
# Đã ghi dữ liệu thành công cho SBD: 07000763
# Đã ghi dữ liệu thành công cho SBD: 07000764
# Đã ghi dữ liệu thành công cho SBD: 07000765
# Đã ghi dữ liệu thành công cho SBD: 07000766
# Đã ghi dữ liệu thành công cho SBD: 07000767
# Đã ghi dữ liệu thành công cho SBD: 07000768
# Đã ghi dữ liệu thành công cho SBD: 07000769
# Đã ghi dữ liệu thành công cho SBD: 07000770
# Đã ghi dữ liệu thành công cho SBD: 07000771
# Đã ghi dữ liệu thành công cho SBD: 07000772
# Đã ghi dữ liệu thành công cho SBD: 07000773
# Đã ghi dữ liệu thành công cho SBD: 07000774
# Đã ghi dữ liệu thành công cho SBD: 07000775
# Đã ghi dữ liệu thành công cho SBD: 07000776
# Đã ghi dữ liệu thành công cho SBD: 07000777
# Đã ghi dữ liệu thành công cho SBD: 07000778
# Đã ghi dữ liệu thành công cho SBD: 07000779
# Đã ghi dữ liệu thành công cho SBD: 07000780
# Đã ghi dữ liệu thành công cho SBD: 07000781
# Đã ghi dữ liệu thành công cho SBD: 07000782
# Đã ghi dữ liệu thành công cho SBD: 07000783
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 07000785
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 07000787
# Đã ghi dữ liệu thành công cho SBD: 07000788
# Đã ghi dữ liệu thành công cho SBD: 07000789
# Đã ghi dữ liệu thành công cho SBD: 07000790
# Đã ghi dữ liệu thành công cho SBD: 07000791
# Đã ghi dữ liệu thành công cho SBD: 07000792
# Đã ghi dữ liệu thành công cho SBD: 07000793
# Đã ghi dữ liệu thành công cho SBD: 07000794
# Đã ghi dữ liệu thành công cho SBD: 07000795
# Đã ghi dữ liệu thành công cho SBD: 07000796
# Đã ghi dữ liệu thành công cho SBD: 07000797
# Đã ghi dữ liệu thành công cho SBD: 07000798
# Đã ghi dữ liệu thành công cho SBD: 07000799
# Đã ghi dữ liệu thành công cho SBD: 07000800
# Đã ghi dữ liệu thành công cho SBD: 07000801
# Đã ghi dữ liệu thành công cho SBD: 07000802
# Đã ghi dữ liệu thành công cho SBD: 07000803
# Đã ghi dữ liệu thành công cho SBD: 07000804
# Đã ghi dữ liệu thành công cho SBD: 07000805
# Đã ghi dữ liệu thành công cho SBD: 07000806
# Đã ghi dữ liệu thành công cho SBD: 07000807
# Đã ghi dữ liệu thành công cho SBD: 07000808
# Đã ghi dữ liệu thành công cho SBD: 07000809
# Đã ghi dữ liệu thành công cho SBD: 07000810
# Đã ghi dữ liệu thành công cho SBD: 07000811
# Đã ghi dữ liệu thành công cho SBD: 07000812
# Đã ghi dữ liệu thành công cho SBD: 07000813
# Đã ghi dữ liệu thành công cho SBD: 07000814
# Đã ghi dữ liệu thành công cho SBD: 07000815
# Đã ghi dữ liệu thành công cho SBD: 07000816
# Đã ghi dữ liệu thành công cho SBD: 07000817
# Đã ghi dữ liệu thành công cho SBD: 07000818
# Đã ghi dữ liệu thành công cho SBD: 07000819
# Đã ghi dữ liệu thành công cho SBD: 07000820
# Đã ghi dữ liệu thành công cho SBD: 07000821
# Đã ghi dữ liệu thành công cho SBD: 07000822
# Đã ghi dữ liệu thành công cho SBD: 07000823
# Đã ghi dữ liệu thành công cho SBD: 07000824
# Đã ghi dữ liệu thành công cho SBD: 07000825
# Đã ghi dữ liệu thành công cho SBD: 07000826
# Đã ghi dữ liệu thành công cho SBD: 07000827
# Đã ghi dữ liệu thành công cho SBD: 07000828
# Đã ghi dữ liệu thành công cho SBD: 07000829
# Đã ghi dữ liệu thành công cho SBD: 07000830
# Đã ghi dữ liệu thành công cho SBD: 07000831
# Đã ghi dữ liệu thành công cho SBD: 07000832
# Đã ghi dữ liệu thành công cho SBD: 07000833
# Đã ghi dữ liệu thành công cho SBD: 07000834
# Đã ghi dữ liệu thành công cho SBD: 07000835
# Đã ghi dữ liệu thành công cho SBD: 07000836
# Đã ghi dữ liệu thành công cho SBD: 07000837
# Đã ghi dữ liệu thành công cho SBD: 07000838
# Đã ghi dữ liệu thành công cho SBD: 07000839
# Đã ghi dữ liệu thành công cho SBD: 07000840
# Đã ghi dữ liệu thành công cho SBD: 07000841
# Đã ghi dữ liệu thành công cho SBD: 07000842
# Đã ghi dữ liệu thành công cho SBD: 07000843
# Đã ghi dữ liệu thành công cho SBD: 07000844
# Đã ghi dữ liệu thành công cho SBD: 07000845
# Đã ghi dữ liệu thành công cho SBD: 07000846
# Đã ghi dữ liệu thành công cho SBD: 07000847
# Đã ghi dữ liệu thành công cho SBD: 07000848
# Đã ghi dữ liệu thành công cho SBD: 07000849
# Đã ghi dữ liệu thành công cho SBD: 07000850
# Đã ghi dữ liệu thành công cho SBD: 07000851
# Đã ghi dữ liệu thành công cho SBD: 07000852
# Đã ghi dữ liệu thành công cho SBD: 07000853
# Đã ghi dữ liệu thành công cho SBD: 07000854
# Đã ghi dữ liệu thành công cho SBD: 07000855
# Đã ghi dữ liệu thành công cho SBD: 07000856
# Đã ghi dữ liệu thành công cho SBD: 07000857
# Đã ghi dữ liệu thành công cho SBD: 07000858
# Đã ghi dữ liệu thành công cho SBD: 07000859
# Đã ghi dữ liệu thành công cho SBD: 07000860
# Đã ghi dữ liệu thành công cho SBD: 07000861
# Đã ghi dữ liệu thành công cho SBD: 07000862
# Đã ghi dữ liệu thành công cho SBD: 07000863
# Đã ghi dữ liệu thành công cho SBD: 07000864
# Đã ghi dữ liệu thành công cho SBD: 07000865
# Đã ghi dữ liệu thành công cho SBD: 07000866
# Đã ghi dữ liệu thành công cho SBD: 07000867
# Đã ghi dữ liệu thành công cho SBD: 07000868
# Đã ghi dữ liệu thành công cho SBD: 07000869
# Đã ghi dữ liệu thành công cho SBD: 07000870
# Đã ghi dữ liệu thành công cho SBD: 07000871
# Đã ghi dữ liệu thành công cho SBD: 07000872
# Đã ghi dữ liệu thành công cho SBD: 07000873
# Đã ghi dữ liệu thành công cho SBD: 07000874
# Đã ghi dữ liệu thành công cho SBD: 07000875
# Đã ghi dữ liệu thành công cho SBD: 07000876
# Đã ghi dữ liệu thành công cho SBD: 07000877
# Đã ghi dữ liệu thành công cho SBD: 07000878
# Đã ghi dữ liệu thành công cho SBD: 07000879
# Đã ghi dữ liệu thành công cho SBD: 07000880
# Đã ghi dữ liệu thành công cho SBD: 07000881
# Đã ghi dữ liệu thành công cho SBD: 07000882
# Đã ghi dữ liệu thành công cho SBD: 07000883
# Đã ghi dữ liệu thành công cho SBD: 07000884
# Đã ghi dữ liệu thành công cho SBD: 07000885
# Đã ghi dữ liệu thành công cho SBD: 07000886
# Đã ghi dữ liệu thành công cho SBD: 07000887
# Đã ghi dữ liệu thành công cho SBD: 07000888
# Đã ghi dữ liệu thành công cho SBD: 07000889
# Đã ghi dữ liệu thành công cho SBD: 07000890
# Đã ghi dữ liệu thành công cho SBD: 07000891
# Đã ghi dữ liệu thành công cho SBD: 07000892
# Đã ghi dữ liệu thành công cho SBD: 07000893
# Đã ghi dữ liệu thành công cho SBD: 07000894
# Đã ghi dữ liệu thành công cho SBD: 07000895
# Đã ghi dữ liệu thành công cho SBD: 07000896
# Đã ghi dữ liệu thành công cho SBD: 07000897
# Đã ghi dữ liệu thành công cho SBD: 07000898
# Đã ghi dữ liệu thành công cho SBD: 07000899
# Đã ghi dữ liệu thành công cho SBD: 07000900
# Đã ghi dữ liệu thành công cho SBD: 07000901
# Đã ghi dữ liệu thành công cho SBD: 07000902
# Đã ghi dữ liệu thành công cho SBD: 07000903
# Đã ghi dữ liệu thành công cho SBD: 07000904
# Đã ghi dữ liệu thành công cho SBD: 07000905
# Đã ghi dữ liệu thành công cho SBD: 07000906
# Đã ghi dữ liệu thành công cho SBD: 07000907
# Đã ghi dữ liệu thành công cho SBD: 07000908
# Đã ghi dữ liệu thành công cho SBD: 07000909
# Đã ghi dữ liệu thành công cho SBD: 07000910
# Đã ghi dữ liệu thành công cho SBD: 07000911
# Đã ghi dữ liệu thành công cho SBD: 07000912
# Đã ghi dữ liệu thành công cho SBD: 07000913
# Đã ghi dữ liệu thành công cho SBD: 07000914
# Đã ghi dữ liệu thành công cho SBD: 07000915
# Đã ghi dữ liệu thành công cho SBD: 07000916
# Đã ghi dữ liệu thành công cho SBD: 07000917
# Đã ghi dữ liệu thành công cho SBD: 07000918
# Đã ghi dữ liệu thành công cho SBD: 07000919
# Đã ghi dữ liệu thành công cho SBD: 07000920
# Đã ghi dữ liệu thành công cho SBD: 07000921
# Đã ghi dữ liệu thành công cho SBD: 07000922
# Đã ghi dữ liệu thành công cho SBD: 07000923
# Đã ghi dữ liệu thành công cho SBD: 07000924
# Đã ghi dữ liệu thành công cho SBD: 07000925
# Đã ghi dữ liệu thành công cho SBD: 07000926
# Đã ghi dữ liệu thành công cho SBD: 07000927
# Đã ghi dữ liệu thành công cho SBD: 07000928
# Đã ghi dữ liệu thành công cho SBD: 07000929
# Đã ghi dữ liệu thành công cho SBD: 07000930
# Đã ghi dữ liệu thành công cho SBD: 07000931
# Đã ghi dữ liệu thành công cho SBD: 07000932
# Đã ghi dữ liệu thành công cho SBD: 07000933
# Đã ghi dữ liệu thành công cho SBD: 07000934
# Đã ghi dữ liệu thành công cho SBD: 07000935
# Đã ghi dữ liệu thành công cho SBD: 07000936
# Đã ghi dữ liệu thành công cho SBD: 07000937
# Đã ghi dữ liệu thành công cho SBD: 07000938
# Đã ghi dữ liệu thành công cho SBD: 07000939
# Đã ghi dữ liệu thành công cho SBD: 07000940
# Đã ghi dữ liệu thành công cho SBD: 07000941
# Đã ghi dữ liệu thành công cho SBD: 07000942
# Đã ghi dữ liệu thành công cho SBD: 07000943
# Đã ghi dữ liệu thành công cho SBD: 07000944
# Đã ghi dữ liệu thành công cho SBD: 07000945
# Đã ghi dữ liệu thành công cho SBD: 07000946
# Đã ghi dữ liệu thành công cho SBD: 07000947
# Đã ghi dữ liệu thành công cho SBD: 07000948
# Đã ghi dữ liệu thành công cho SBD: 07000949
# Đã ghi dữ liệu thành công cho SBD: 07000950
# Đã ghi dữ liệu thành công cho SBD: 07000951
# Đã ghi dữ liệu thành công cho SBD: 07000952
# Đã ghi dữ liệu thành công cho SBD: 07000953
# Đã ghi dữ liệu thành công cho SBD: 07000954
# Đã ghi dữ liệu thành công cho SBD: 07000955
# Đã ghi dữ liệu thành công cho SBD: 07000956
# Đã ghi dữ liệu thành công cho SBD: 07000957
# Đã ghi dữ liệu thành công cho SBD: 07000958
# Đã ghi dữ liệu thành công cho SBD: 07000959
# Đã ghi dữ liệu thành công cho SBD: 07000960
# Đã ghi dữ liệu thành công cho SBD: 07000961
# Đã ghi dữ liệu thành công cho SBD: 07000962
# Đã ghi dữ liệu thành công cho SBD: 07000963
# Đã ghi dữ liệu thành công cho SBD: 07000964
# Đã ghi dữ liệu thành công cho SBD: 07000965
# Đã ghi dữ liệu thành công cho SBD: 07000966
# Đã ghi dữ liệu thành công cho SBD: 07000967
# Đã ghi dữ liệu thành công cho SBD: 07000968
# Đã ghi dữ liệu thành công cho SBD: 07000969
# Đã ghi dữ liệu thành công cho SBD: 07000970
# Đã ghi dữ liệu thành công cho SBD: 07000971
# Đã ghi dữ liệu thành công cho SBD: 07000972
# Đã ghi dữ liệu thành công cho SBD: 07000973
# Đã ghi dữ liệu thành công cho SBD: 07000974
# Đã ghi dữ liệu thành công cho SBD: 07000975
# Đã ghi dữ liệu thành công cho SBD: 07000976
# Đã ghi dữ liệu thành công cho SBD: 07000977
# Đã ghi dữ liệu thành công cho SBD: 07000978
# Đã ghi dữ liệu thành công cho SBD: 07000979
# Đã ghi dữ liệu thành công cho SBD: 07000980
# Đã ghi dữ liệu thành công cho SBD: 07000981
# Đã ghi dữ liệu thành công cho SBD: 07000982
# Đã ghi dữ liệu thành công cho SBD: 07000983
# Đã ghi dữ liệu thành công cho SBD: 07000984
# Đã ghi dữ liệu thành công cho SBD: 07000985
# Đã ghi dữ liệu thành công cho SBD: 07000986
# Đã ghi dữ liệu thành công cho SBD: 07000987
# Đã ghi dữ liệu thành công cho SBD: 07000988
# Đã ghi dữ liệu thành công cho SBD: 07000989
# Đã ghi dữ liệu thành công cho SBD: 07000990
# Đã ghi dữ liệu thành công cho SBD: 07000991
# Đã ghi dữ liệu thành công cho SBD: 07000992
# Đã ghi dữ liệu thành công cho SBD: 07000993
# Đã ghi dữ liệu thành công cho SBD: 07000994
# Đã ghi dữ liệu thành công cho SBD: 07000995
# Đã ghi dữ liệu thành công cho SBD: 07000996
# Đã ghi dữ liệu thành công cho SBD: 07000997
# Đã ghi dữ liệu thành công cho SBD: 07000998
# Đã ghi dữ liệu thành công cho SBD: 07000999
# Đã ghi dữ liệu thành công cho SBD: 07001000
# Đã ghi dữ liệu thành công cho SBD: 07001001
# Đã ghi dữ liệu thành công cho SBD: 07001002
# Đã ghi dữ liệu thành công cho SBD: 07001003
# Đã ghi dữ liệu thành công cho SBD: 07001004
# Đã ghi dữ liệu thành công cho SBD: 07001005
# Đã ghi dữ liệu thành công cho SBD: 07001006
# Đã ghi dữ liệu thành công cho SBD: 07001007
# Đã ghi dữ liệu thành công cho SBD: 07001008
# Đã ghi dữ liệu thành công cho SBD: 07001009
# Đã ghi dữ liệu thành công cho SBD: 07001010
# Đã ghi dữ liệu thành công cho SBD: 07001011
# Đã ghi dữ liệu thành công cho SBD: 07001012
# Đã ghi dữ liệu thành công cho SBD: 07001013
# Đã ghi dữ liệu thành công cho SBD: 07001014
# Đã ghi dữ liệu thành công cho SBD: 07001015
# Đã ghi dữ liệu thành công cho SBD: 07001016
# Đã ghi dữ liệu thành công cho SBD: 07001017
# Đã ghi dữ liệu thành công cho SBD: 07001018
# Đã ghi dữ liệu thành công cho SBD: 07001019
# Đã ghi dữ liệu thành công cho SBD: 07001020
# Đã ghi dữ liệu thành công cho SBD: 07001021
# Đã ghi dữ liệu thành công cho SBD: 07001022
# Đã ghi dữ liệu thành công cho SBD: 07001023
# Đã ghi dữ liệu thành công cho SBD: 07001024
# Đã ghi dữ liệu thành công cho SBD: 07001025
# Đã ghi dữ liệu thành công cho SBD: 07001026
# Đã ghi dữ liệu thành công cho SBD: 07001027
# Đã ghi dữ liệu thành công cho SBD: 07001028
# Đã ghi dữ liệu thành công cho SBD: 07001029
# Đã ghi dữ liệu thành công cho SBD: 07001030
# Đã ghi dữ liệu thành công cho SBD: 07001031
# Đã ghi dữ liệu thành công cho SBD: 07001032
# Đã ghi dữ liệu thành công cho SBD: 07001033
# Đã ghi dữ liệu thành công cho SBD: 07001034
# Đã ghi dữ liệu thành công cho SBD: 07001035
# Đã ghi dữ liệu thành công cho SBD: 07001036
# Đã ghi dữ liệu thành công cho SBD: 07001037
# Đã ghi dữ liệu thành công cho SBD: 07001038
# Đã ghi dữ liệu thành công cho SBD: 07001039
# Đã ghi dữ liệu thành công cho SBD: 07001040
# Đã ghi dữ liệu thành công cho SBD: 07001041
# Đã ghi dữ liệu thành công cho SBD: 07001042
# Đã ghi dữ liệu thành công cho SBD: 07001043
# Đã ghi dữ liệu thành công cho SBD: 07001044
# Đã ghi dữ liệu thành công cho SBD: 07001045
# Đã ghi dữ liệu thành công cho SBD: 07001046
# Đã ghi dữ liệu thành công cho SBD: 07001047
# Đã ghi dữ liệu thành công cho SBD: 07001048
# Đã ghi dữ liệu thành công cho SBD: 07001049
# Đã ghi dữ liệu thành công cho SBD: 07001050
# Đã ghi dữ liệu thành công cho SBD: 07001051
# Đã ghi dữ liệu thành công cho SBD: 07001052
# Đã ghi dữ liệu thành công cho SBD: 07001053
# Đã ghi dữ liệu thành công cho SBD: 07001054
# Đã ghi dữ liệu thành công cho SBD: 07001055
# Đã ghi dữ liệu thành công cho SBD: 07001056
# Đã ghi dữ liệu thành công cho SBD: 07001057
# Đã ghi dữ liệu thành công cho SBD: 07001058
# Đã ghi dữ liệu thành công cho SBD: 07001059
# Đã ghi dữ liệu thành công cho SBD: 07001060
# Đã ghi dữ liệu thành công cho SBD: 07001061
# Đã ghi dữ liệu thành công cho SBD: 07001062
# Đã ghi dữ liệu thành công cho SBD: 07001063
# Đã ghi dữ liệu thành công cho SBD: 07001064
# Đã ghi dữ liệu thành công cho SBD: 07001065
# Đã ghi dữ liệu thành công cho SBD: 07001066
# Đã ghi dữ liệu thành công cho SBD: 07001067
# Đã ghi dữ liệu thành công cho SBD: 07001068
# Đã ghi dữ liệu thành công cho SBD: 07001069
# Đã ghi dữ liệu thành công cho SBD: 07001070
# Đã ghi dữ liệu thành công cho SBD: 07001071
# Đã ghi dữ liệu thành công cho SBD: 07001072
# Đã ghi dữ liệu thành công cho SBD: 07001073
# Đã ghi dữ liệu thành công cho SBD: 07001074
# Đã ghi dữ liệu thành công cho SBD: 07001075
# Đã ghi dữ liệu thành công cho SBD: 07001076
# Đã ghi dữ liệu thành công cho SBD: 07001077
# Đã ghi dữ liệu thành công cho SBD: 07001078
# Đã ghi dữ liệu thành công cho SBD: 07001079
# Đã ghi dữ liệu thành công cho SBD: 07001080
# Đã ghi dữ liệu thành công cho SBD: 07001081
# Đã ghi dữ liệu thành công cho SBD: 07001082
# Đã ghi dữ liệu thành công cho SBD: 07001083
# Đã ghi dữ liệu thành công cho SBD: 07001084
# Đã ghi dữ liệu thành công cho SBD: 07001085
# Đã ghi dữ liệu thành công cho SBD: 07001086
# Đã ghi dữ liệu thành công cho SBD: 07001087
# Đã ghi dữ liệu thành công cho SBD: 07001088
# Đã ghi dữ liệu thành công cho SBD: 07001089
# Đã ghi dữ liệu thành công cho SBD: 07001090
# Đã ghi dữ liệu thành công cho SBD: 07001091
# ...
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 66
#      63     print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
#      65 # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
# ---> 66 time.sleep(0.4)
#
# KeyboardInterrupt:

# %%
import requests
import time
import csv

# Đường dẫn đến file CSV
file_path = r"E:\\DA\\Crawl\\08_LaoCai.csv"

# Mở file CSV để ghi dữ liệu
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Ghi tiêu đề cột
    writer.writerow([
        'SBD', 'Toan', 'Van', 'NgoaiNgu', 'VatLy', 'HoaHoc', 'SinhHoc',
        'TBKHTN', 'LichSu', 'DiaLy', 'GDCD', 'TBKHXH'
    ])
    
    # Vòng lặp lấy dữ liệu
    for x in range(8000001, 8008385):
        scraping_url = f"https://dantri.com.vn/thpt/1/0/99/{x}/2024/0.2/search-gradle.htm"
        
        try:
            # Gửi yêu cầu
            response = requests.get(scraping_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            
            # Phân tích phản hồi JSON
            data = response.json()
            
            # Kiểm tra nếu có khóa 'student' trong phản hồi
            if 'student' in data:
                info = data['student']
                
                # Ghi dữ liệu vào file CSV
                writer.writerow([
                    info.get('sbd', 'None'),
                    info.get('toan', 'None'),
                    info.get('van', 'None'),
                    info.get('ngoaiNgu', 'None'),
                    info.get('vatLy', 'None'),
                    info.get('hoaHoc', 'None'),
                    info.get('sinhHoc', 'None'),
                    info.get('diemTBTuNhien', 'None'),
                    info.get('lichSu', 'None'),
                    info.get('diaLy', 'None'),
                    info.get('gdcd', 'None'),
                    info.get('diemTBXaHoi', 'None')
                ])
                
                # Hiển thị thông báo đã ghi dữ liệu thành công
                print(f"Đã ghi dữ liệu thành công cho SBD: {info.get('sbd', 'Unknown')}")

                # Đảm bảo dữ liệu được ghi vào tệp ngay lập tức
                file.flush()
            else:
                print(f"Không có khóa 'student' trong phản hồi cho URL: {scraping_url}")
            
        except requests.RequestException as e:
            print(f"Yêu cầu không thành công cho URL {scraping_url}: {e}")
        except ValueError as e:
            print(f"Lỗi khi phân tích cú pháp JSON cho URL {scraping_url}: {e}")
        except csv.Error as e:
            print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
        
        # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
        time.sleep(0.4)
# Out:
# Đã ghi dữ liệu thành công cho SBD: 08000001
# Đã ghi dữ liệu thành công cho SBD: 08000002
# Đã ghi dữ liệu thành công cho SBD: 08000003
# Đã ghi dữ liệu thành công cho SBD: 08000004
# Đã ghi dữ liệu thành công cho SBD: 08000005
# Đã ghi dữ liệu thành công cho SBD: 08000006
# Đã ghi dữ liệu thành công cho SBD: 08000007
# Đã ghi dữ liệu thành công cho SBD: 08000008
# Đã ghi dữ liệu thành công cho SBD: 08000009
# Đã ghi dữ liệu thành công cho SBD: 08000010
# Đã ghi dữ liệu thành công cho SBD: 08000011
# Đã ghi dữ liệu thành công cho SBD: 08000012
# Đã ghi dữ liệu thành công cho SBD: 08000013
# Đã ghi dữ liệu thành công cho SBD: 08000014
# Đã ghi dữ liệu thành công cho SBD: 08000015
# Đã ghi dữ liệu thành công cho SBD: 08000016
# Đã ghi dữ liệu thành công cho SBD: 08000017
# Đã ghi dữ liệu thành công cho SBD: 08000018
# Đã ghi dữ liệu thành công cho SBD: 08000019
# Đã ghi dữ liệu thành công cho SBD: 08000020
# Đã ghi dữ liệu thành công cho SBD: 08000021
# Đã ghi dữ liệu thành công cho SBD: 08000022
# Đã ghi dữ liệu thành công cho SBD: 08000023
# Đã ghi dữ liệu thành công cho SBD: 08000024
# Đã ghi dữ liệu thành công cho SBD: 08000025
# Đã ghi dữ liệu thành công cho SBD: 08000026
# Đã ghi dữ liệu thành công cho SBD: 08000027
# Đã ghi dữ liệu thành công cho SBD: 08000028
# Đã ghi dữ liệu thành công cho SBD: 08000029
# Đã ghi dữ liệu thành công cho SBD: 08000030
# Đã ghi dữ liệu thành công cho SBD: 08000031
# Đã ghi dữ liệu thành công cho SBD: 08000032
# Đã ghi dữ liệu thành công cho SBD: 08000033
# Đã ghi dữ liệu thành công cho SBD: 08000034
# Đã ghi dữ liệu thành công cho SBD: 08000035
# Đã ghi dữ liệu thành công cho SBD: 08000036
# Đã ghi dữ liệu thành công cho SBD: 08000037
# Đã ghi dữ liệu thành công cho SBD: 08000038
# Đã ghi dữ liệu thành công cho SBD: 08000039
# Đã ghi dữ liệu thành công cho SBD: 08000040
# Đã ghi dữ liệu thành công cho SBD: 08000041
# Đã ghi dữ liệu thành công cho SBD: 08000042
# Đã ghi dữ liệu thành công cho SBD: 08000043
# Đã ghi dữ liệu thành công cho SBD: 08000044
# Đã ghi dữ liệu thành công cho SBD: 08000045
# Đã ghi dữ liệu thành công cho SBD: 08000046
# Đã ghi dữ liệu thành công cho SBD: 08000047
# Đã ghi dữ liệu thành công cho SBD: 08000048
# Đã ghi dữ liệu thành công cho SBD: 08000049
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 08000051
# Đã ghi dữ liệu thành công cho SBD: 08000052
# Đã ghi dữ liệu thành công cho SBD: 08000053
# Đã ghi dữ liệu thành công cho SBD: 08000054
# Đã ghi dữ liệu thành công cho SBD: 08000055
# Đã ghi dữ liệu thành công cho SBD: 08000056
# Đã ghi dữ liệu thành công cho SBD: 08000057
# Đã ghi dữ liệu thành công cho SBD: 08000058
# Đã ghi dữ liệu thành công cho SBD: 08000059
# Đã ghi dữ liệu thành công cho SBD: 08000060
# Đã ghi dữ liệu thành công cho SBD: 08000061
# Đã ghi dữ liệu thành công cho SBD: 08000062
# Đã ghi dữ liệu thành công cho SBD: 08000063
# Đã ghi dữ liệu thành công cho SBD: 08000064
# Đã ghi dữ liệu thành công cho SBD: 08000065
# Đã ghi dữ liệu thành công cho SBD: 08000066
# Đã ghi dữ liệu thành công cho SBD: 08000067
# Đã ghi dữ liệu thành công cho SBD: 08000068
# Đã ghi dữ liệu thành công cho SBD: 08000069
# Đã ghi dữ liệu thành công cho SBD: 08000070
# Đã ghi dữ liệu thành công cho SBD: 08000071
# Đã ghi dữ liệu thành công cho SBD: 08000072
# Đã ghi dữ liệu thành công cho SBD: 08000073
# Đã ghi dữ liệu thành công cho SBD: 08000074
# Đã ghi dữ liệu thành công cho SBD: 08000075
# Đã ghi dữ liệu thành công cho SBD: 08000076
# Đã ghi dữ liệu thành công cho SBD: 08000077
# Đã ghi dữ liệu thành công cho SBD: 08000078
# Đã ghi dữ liệu thành công cho SBD: 08000079
# Đã ghi dữ liệu thành công cho SBD: 08000080
# Đã ghi dữ liệu thành công cho SBD: 08000081
# Đã ghi dữ liệu thành công cho SBD: 08000082
# Đã ghi dữ liệu thành công cho SBD: 08000083
# Đã ghi dữ liệu thành công cho SBD: 08000084
# Đã ghi dữ liệu thành công cho SBD: 08000085
# Đã ghi dữ liệu thành công cho SBD: 08000086
# Đã ghi dữ liệu thành công cho SBD: 08000087
# Đã ghi dữ liệu thành công cho SBD: 08000088
# Đã ghi dữ liệu thành công cho SBD: 08000089
# Đã ghi dữ liệu thành công cho SBD: 08000090
# Đã ghi dữ liệu thành công cho SBD: 08000091
# Đã ghi dữ liệu thành công cho SBD: 08000092
# Đã ghi dữ liệu thành công cho SBD: 08000093
# Đã ghi dữ liệu thành công cho SBD: 08000094
# Đã ghi dữ liệu thành công cho SBD: 08000095
# Đã ghi dữ liệu thành công cho SBD: 08000096
# Đã ghi dữ liệu thành công cho SBD: 08000097
# Đã ghi dữ liệu thành công cho SBD: 08000098
# Đã ghi dữ liệu thành công cho SBD: 08000099
# Đã ghi dữ liệu thành công cho SBD: 08000100
# Đã ghi dữ liệu thành công cho SBD: 08000101
# Đã ghi dữ liệu thành công cho SBD: 08000102
# Đã ghi dữ liệu thành công cho SBD: 08000103
# Đã ghi dữ liệu thành công cho SBD: 08000104
# Đã ghi dữ liệu thành công cho SBD: 08000105
# Đã ghi dữ liệu thành công cho SBD: 08000106
# Đã ghi dữ liệu thành công cho SBD: 08000107
# Đã ghi dữ liệu thành công cho SBD: 08000108
# Đã ghi dữ liệu thành công cho SBD: 08000109
# Đã ghi dữ liệu thành công cho SBD: 08000110
# Đã ghi dữ liệu thành công cho SBD: 08000111
# Đã ghi dữ liệu thành công cho SBD: 08000112
# Đã ghi dữ liệu thành công cho SBD: 08000113
# Đã ghi dữ liệu thành công cho SBD: 08000114
# Đã ghi dữ liệu thành công cho SBD: 08000115
# Đã ghi dữ liệu thành công cho SBD: 08000116
# Đã ghi dữ liệu thành công cho SBD: 08000117
# Đã ghi dữ liệu thành công cho SBD: 08000118
# Đã ghi dữ liệu thành công cho SBD: 08000119
# Đã ghi dữ liệu thành công cho SBD: 08000120
# Đã ghi dữ liệu thành công cho SBD: 08000121
# Đã ghi dữ liệu thành công cho SBD: 08000122
# Đã ghi dữ liệu thành công cho SBD: 08000123
# Đã ghi dữ liệu thành công cho SBD: 08000124
# Đã ghi dữ liệu thành công cho SBD: 08000125
# Đã ghi dữ liệu thành công cho SBD: 08000126
# Đã ghi dữ liệu thành công cho SBD: 08000127
# Đã ghi dữ liệu thành công cho SBD: 08000128
# Đã ghi dữ liệu thành công cho SBD: 08000129
# Đã ghi dữ liệu thành công cho SBD: 08000130
# Đã ghi dữ liệu thành công cho SBD: 08000131
# Đã ghi dữ liệu thành công cho SBD: 08000132
# Đã ghi dữ liệu thành công cho SBD: 08000133
# Đã ghi dữ liệu thành công cho SBD: 08000134
# Đã ghi dữ liệu thành công cho SBD: 08000135
# Đã ghi dữ liệu thành công cho SBD: 08000136
# Đã ghi dữ liệu thành công cho SBD: 08000137
# Đã ghi dữ liệu thành công cho SBD: 08000138
# Đã ghi dữ liệu thành công cho SBD: 08000139
# Đã ghi dữ liệu thành công cho SBD: 08000140
# Đã ghi dữ liệu thành công cho SBD: 08000141
# Đã ghi dữ liệu thành công cho SBD: 08000142
# Đã ghi dữ liệu thành công cho SBD: 08000143
# Đã ghi dữ liệu thành công cho SBD: 08000144
# Đã ghi dữ liệu thành công cho SBD: 08000145
# Đã ghi dữ liệu thành công cho SBD: 08000146
# Đã ghi dữ liệu thành công cho SBD: 08000147
# Đã ghi dữ liệu thành công cho SBD: 08000148
# Đã ghi dữ liệu thành công cho SBD: 08000149
# Đã ghi dữ liệu thành công cho SBD: 08000150
# Đã ghi dữ liệu thành công cho SBD: 08000151
# Đã ghi dữ liệu thành công cho SBD: 08000152
# Đã ghi dữ liệu thành công cho SBD: 08000153
# Đã ghi dữ liệu thành công cho SBD: 08000154
# Đã ghi dữ liệu thành công cho SBD: 08000155
# Đã ghi dữ liệu thành công cho SBD: 08000156
# Đã ghi dữ liệu thành công cho SBD: 08000157
# Đã ghi dữ liệu thành công cho SBD: 08000158
# Đã ghi dữ liệu thành công cho SBD: 08000159
# Đã ghi dữ liệu thành công cho SBD: 08000160
# Đã ghi dữ liệu thành công cho SBD: 08000161
# Đã ghi dữ liệu thành công cho SBD: 08000162
# Đã ghi dữ liệu thành công cho SBD: 08000163
# Đã ghi dữ liệu thành công cho SBD: 08000164
# Đã ghi dữ liệu thành công cho SBD: 08000165
# Đã ghi dữ liệu thành công cho SBD: 08000166
# Đã ghi dữ liệu thành công cho SBD: 08000167
# Đã ghi dữ liệu thành công cho SBD: 08000168
# Đã ghi dữ liệu thành công cho SBD: 08000169
# Đã ghi dữ liệu thành công cho SBD: 08000170
# Đã ghi dữ liệu thành công cho SBD: 08000171
# Đã ghi dữ liệu thành công cho SBD: 08000172
# Đã ghi dữ liệu thành công cho SBD: 08000173
# Đã ghi dữ liệu thành công cho SBD: 08000174
# Đã ghi dữ liệu thành công cho SBD: 08000175
# Đã ghi dữ liệu thành công cho SBD: 08000176
# Đã ghi dữ liệu thành công cho SBD: 08000177
# Đã ghi dữ liệu thành công cho SBD: 08000178
# Đã ghi dữ liệu thành công cho SBD: 08000179
# Đã ghi dữ liệu thành công cho SBD: 08000180
# Đã ghi dữ liệu thành công cho SBD: 08000181
# Đã ghi dữ liệu thành công cho SBD: 08000182
# Đã ghi dữ liệu thành công cho SBD: 08000183
# Đã ghi dữ liệu thành công cho SBD: 08000184
# Đã ghi dữ liệu thành công cho SBD: 08000185
# Đã ghi dữ liệu thành công cho SBD: 08000186
# Đã ghi dữ liệu thành công cho SBD: 08000187
# Đã ghi dữ liệu thành công cho SBD: 08000188
# Đã ghi dữ liệu thành công cho SBD: 08000189
# Đã ghi dữ liệu thành công cho SBD: 08000190
# Đã ghi dữ liệu thành công cho SBD: 08000191
# Đã ghi dữ liệu thành công cho SBD: 08000192
# Đã ghi dữ liệu thành công cho SBD: 08000193
# Đã ghi dữ liệu thành công cho SBD: 08000194
# Đã ghi dữ liệu thành công cho SBD: 08000195
# Đã ghi dữ liệu thành công cho SBD: 08000196
# Đã ghi dữ liệu thành công cho SBD: 08000197
# Đã ghi dữ liệu thành công cho SBD: 08000198
# Đã ghi dữ liệu thành công cho SBD: 08000199
# Đã ghi dữ liệu thành công cho SBD: 08000200
# Đã ghi dữ liệu thành công cho SBD: 08000201
# Đã ghi dữ liệu thành công cho SBD: 08000202
# Đã ghi dữ liệu thành công cho SBD: 08000203
# Đã ghi dữ liệu thành công cho SBD: 08000204
# Đã ghi dữ liệu thành công cho SBD: 08000205
# Đã ghi dữ liệu thành công cho SBD: 08000206
# Đã ghi dữ liệu thành công cho SBD: 08000207
# Đã ghi dữ liệu thành công cho SBD: 08000208
# Đã ghi dữ liệu thành công cho SBD: 08000209
# Đã ghi dữ liệu thành công cho SBD: 08000210
# Đã ghi dữ liệu thành công cho SBD: 08000211
# Đã ghi dữ liệu thành công cho SBD: 08000212
# Đã ghi dữ liệu thành công cho SBD: 08000213
# Đã ghi dữ liệu thành công cho SBD: 08000214
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 08000216
# Đã ghi dữ liệu thành công cho SBD: 08000217
# Đã ghi dữ liệu thành công cho SBD: 08000218
# Đã ghi dữ liệu thành công cho SBD: 08000219
# Đã ghi dữ liệu thành công cho SBD: 08000220
# Đã ghi dữ liệu thành công cho SBD: 08000221
# Đã ghi dữ liệu thành công cho SBD: 08000222
# Đã ghi dữ liệu thành công cho SBD: 08000223
# Đã ghi dữ liệu thành công cho SBD: 08000224
# Đã ghi dữ liệu thành công cho SBD: 08000225
# Đã ghi dữ liệu thành công cho SBD: 08000226
# Đã ghi dữ liệu thành công cho SBD: 08000227
# Đã ghi dữ liệu thành công cho SBD: 08000228
# Đã ghi dữ liệu thành công cho SBD: 08000229
# Đã ghi dữ liệu thành công cho SBD: 08000230
# Đã ghi dữ liệu thành công cho SBD: 08000231
# Đã ghi dữ liệu thành công cho SBD: 08000232
# Đã ghi dữ liệu thành công cho SBD: 08000233
# Đã ghi dữ liệu thành công cho SBD: 08000234
# Đã ghi dữ liệu thành công cho SBD: 08000235
# Đã ghi dữ liệu thành công cho SBD: 08000236
# Đã ghi dữ liệu thành công cho SBD: 08000237
# Đã ghi dữ liệu thành công cho SBD: 08000238
# Đã ghi dữ liệu thành công cho SBD: 08000239
# Đã ghi dữ liệu thành công cho SBD: 08000240
# Đã ghi dữ liệu thành công cho SBD: 08000241
# Đã ghi dữ liệu thành công cho SBD: 08000242
# Đã ghi dữ liệu thành công cho SBD: 08000243
# Đã ghi dữ liệu thành công cho SBD: 08000244
# Đã ghi dữ liệu thành công cho SBD: 08000245
# Đã ghi dữ liệu thành công cho SBD: 08000246
# Đã ghi dữ liệu thành công cho SBD: 08000247
# Đã ghi dữ liệu thành công cho SBD: 08000248
# Đã ghi dữ liệu thành công cho SBD: 08000249
# Đã ghi dữ liệu thành công cho SBD: 08000250
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 08000252
# Đã ghi dữ liệu thành công cho SBD: 08000253
# Đã ghi dữ liệu thành công cho SBD: 08000254
# Đã ghi dữ liệu thành công cho SBD: 08000255
# Đã ghi dữ liệu thành công cho SBD: 08000256
# Đã ghi dữ liệu thành công cho SBD: 08000257
# Đã ghi dữ liệu thành công cho SBD: 08000258
# Đã ghi dữ liệu thành công cho SBD: 08000259
# Đã ghi dữ liệu thành công cho SBD: 08000260
# Đã ghi dữ liệu thành công cho SBD: 08000261
# Đã ghi dữ liệu thành công cho SBD: 08000262
# Đã ghi dữ liệu thành công cho SBD: 08000263
# Đã ghi dữ liệu thành công cho SBD: 08000264
# Đã ghi dữ liệu thành công cho SBD: 08000265
# Đã ghi dữ liệu thành công cho SBD: 08000266
# Đã ghi dữ liệu thành công cho SBD: 08000267
# Đã ghi dữ liệu thành công cho SBD: 08000268
# Đã ghi dữ liệu thành công cho SBD: 08000269
# Đã ghi dữ liệu thành công cho SBD: 08000270
# Đã ghi dữ liệu thành công cho SBD: 08000271
# Đã ghi dữ liệu thành công cho SBD: 08000272
# Đã ghi dữ liệu thành công cho SBD: 08000273
# Đã ghi dữ liệu thành công cho SBD: 08000274
# Đã ghi dữ liệu thành công cho SBD: 08000275
# Đã ghi dữ liệu thành công cho SBD: 08000276
# Đã ghi dữ liệu thành công cho SBD: 08000277
# Đã ghi dữ liệu thành công cho SBD: 08000278
# Đã ghi dữ liệu thành công cho SBD: 08000279
# Đã ghi dữ liệu thành công cho SBD: 08000280
# Đã ghi dữ liệu thành công cho SBD: 08000281
# Đã ghi dữ liệu thành công cho SBD: 08000282
# Đã ghi dữ liệu thành công cho SBD: 08000283
# Đã ghi dữ liệu thành công cho SBD: 08000284
# Đã ghi dữ liệu thành công cho SBD: 08000285
# Đã ghi dữ liệu thành công cho SBD: 08000286
# Đã ghi dữ liệu thành công cho SBD: 08000287
# Đã ghi dữ liệu thành công cho SBD: 08000288
# Đã ghi dữ liệu thành công cho SBD: 08000289
# Đã ghi dữ liệu thành công cho SBD: 08000290
# Đã ghi dữ liệu thành công cho SBD: 08000291
# Đã ghi dữ liệu thành công cho SBD: 08000292
# Đã ghi dữ liệu thành công cho SBD: 08000293
# Đã ghi dữ liệu thành công cho SBD: 08000294
# Đã ghi dữ liệu thành công cho SBD: 08000295
# Đã ghi dữ liệu thành công cho SBD: 08000296
# Đã ghi dữ liệu thành công cho SBD: 08000297
# Đã ghi dữ liệu thành công cho SBD: 08000298
# Đã ghi dữ liệu thành công cho SBD: 08000299
# Đã ghi dữ liệu thành công cho SBD: 08000300
# Đã ghi dữ liệu thành công cho SBD: 08000301
# Đã ghi dữ liệu thành công cho SBD: 08000302
# Đã ghi dữ liệu thành công cho SBD: 08000303
# Đã ghi dữ liệu thành công cho SBD: 08000304
# Đã ghi dữ liệu thành công cho SBD: 08000305
# Đã ghi dữ liệu thành công cho SBD: 08000306
# Đã ghi dữ liệu thành công cho SBD: 08000307
# Đã ghi dữ liệu thành công cho SBD: 08000308
# Đã ghi dữ liệu thành công cho SBD: 08000309
# Đã ghi dữ liệu thành công cho SBD: 08000310
# Đã ghi dữ liệu thành công cho SBD: 08000311
# Đã ghi dữ liệu thành công cho SBD: 08000312
# Đã ghi dữ liệu thành công cho SBD: 08000313
# Đã ghi dữ liệu thành công cho SBD: 08000314
# Đã ghi dữ liệu thành công cho SBD: 08000315
# Đã ghi dữ liệu thành công cho SBD: 08000316
# Đã ghi dữ liệu thành công cho SBD: 08000317
# Đã ghi dữ liệu thành công cho SBD: 08000318
# Đã ghi dữ liệu thành công cho SBD: 08000319
# Đã ghi dữ liệu thành công cho SBD: 08000320
# Đã ghi dữ liệu thành công cho SBD: 08000321
# Đã ghi dữ liệu thành công cho SBD: 08000322
# Đã ghi dữ liệu thành công cho SBD: 08000323
# Đã ghi dữ liệu thành công cho SBD: 08000324
# Đã ghi dữ liệu thành công cho SBD: 08000325
# Đã ghi dữ liệu thành công cho SBD: 08000326
# Đã ghi dữ liệu thành công cho SBD: 08000327
# Đã ghi dữ liệu thành công cho SBD: 08000328
# Đã ghi dữ liệu thành công cho SBD: 08000329
# Đã ghi dữ liệu thành công cho SBD: 08000330
# Đã ghi dữ liệu thành công cho SBD: 08000331
# Đã ghi dữ liệu thành công cho SBD: 08000332
# Đã ghi dữ liệu thành công cho SBD: 08000333
# Đã ghi dữ liệu thành công cho SBD: 08000334
# Đã ghi dữ liệu thành công cho SBD: 08000335
# Đã ghi dữ liệu thành công cho SBD: 08000336
# Đã ghi dữ liệu thành công cho SBD: 08000337
# Đã ghi dữ liệu thành công cho SBD: 08000338
# Đã ghi dữ liệu thành công cho SBD: 08000339
# Đã ghi dữ liệu thành công cho SBD: 08000340
# Đã ghi dữ liệu thành công cho SBD: 08000341
# Đã ghi dữ liệu thành công cho SBD: 08000342
# Đã ghi dữ liệu thành công cho SBD: 08000343
# Đã ghi dữ liệu thành công cho SBD: 08000344
# Đã ghi dữ liệu thành công cho SBD: 08000345
# Đã ghi dữ liệu thành công cho SBD: 08000346
# Đã ghi dữ liệu thành công cho SBD: 08000347
# Đã ghi dữ liệu thành công cho SBD: 08000348
# Đã ghi dữ liệu thành công cho SBD: 08000349
# Đã ghi dữ liệu thành công cho SBD: 08000350
# Đã ghi dữ liệu thành công cho SBD: 08000351
# Đã ghi dữ liệu thành công cho SBD: 08000352
# Đã ghi dữ liệu thành công cho SBD: 08000353
# Đã ghi dữ liệu thành công cho SBD: 08000354
# Đã ghi dữ liệu thành công cho SBD: 08000355
# Đã ghi dữ liệu thành công cho SBD: 08000356
# Đã ghi dữ liệu thành công cho SBD: 08000357
# Đã ghi dữ liệu thành công cho SBD: 08000358
# Đã ghi dữ liệu thành công cho SBD: 08000359
# Đã ghi dữ liệu thành công cho SBD: 08000360
# Đã ghi dữ liệu thành công cho SBD: 08000361
# Đã ghi dữ liệu thành công cho SBD: 08000362
# Đã ghi dữ liệu thành công cho SBD: 08000363
# Đã ghi dữ liệu thành công cho SBD: 08000364
# Đã ghi dữ liệu thành công cho SBD: 08000365
# Đã ghi dữ liệu thành công cho SBD: 08000366
# Đã ghi dữ liệu thành công cho SBD: 08000367
# Đã ghi dữ liệu thành công cho SBD: 08000368
# Đã ghi dữ liệu thành công cho SBD: 08000369
# Đã ghi dữ liệu thành công cho SBD: 08000370
# Đã ghi dữ liệu thành công cho SBD: 08000371
# Đã ghi dữ liệu thành công cho SBD: 08000372
# Đã ghi dữ liệu thành công cho SBD: 08000373
# Đã ghi dữ liệu thành công cho SBD: 08000374
# Đã ghi dữ liệu thành công cho SBD: 08000375
# Đã ghi dữ liệu thành công cho SBD: 08000376
# Đã ghi dữ liệu thành công cho SBD: 08000377
# Đã ghi dữ liệu thành công cho SBD: 08000378
# Đã ghi dữ liệu thành công cho SBD: 08000379
# Đã ghi dữ liệu thành công cho SBD: 08000380
# Đã ghi dữ liệu thành công cho SBD: 08000381
# Đã ghi dữ liệu thành công cho SBD: 08000382
# Đã ghi dữ liệu thành công cho SBD: 08000383
# Đã ghi dữ liệu thành công cho SBD: 08000384
# Đã ghi dữ liệu thành công cho SBD: 08000385
# Đã ghi dữ liệu thành công cho SBD: 08000386
# Đã ghi dữ liệu thành công cho SBD: 08000387
# Đã ghi dữ liệu thành công cho SBD: 08000388
# Đã ghi dữ liệu thành công cho SBD: 08000389
# Đã ghi dữ liệu thành công cho SBD: 08000390
# Đã ghi dữ liệu thành công cho SBD: 08000391
# Đã ghi dữ liệu thành công cho SBD: 08000392
# Đã ghi dữ liệu thành công cho SBD: 08000393
# Đã ghi dữ liệu thành công cho SBD: 08000394
# Đã ghi dữ liệu thành công cho SBD: 08000395
# Đã ghi dữ liệu thành công cho SBD: 08000396
# Đã ghi dữ liệu thành công cho SBD: 08000397
# Đã ghi dữ liệu thành công cho SBD: 08000398
# Đã ghi dữ liệu thành công cho SBD: 08000399
# Đã ghi dữ liệu thành công cho SBD: 08000400
# Đã ghi dữ liệu thành công cho SBD: 08000401
# Đã ghi dữ liệu thành công cho SBD: 08000402
# Đã ghi dữ liệu thành công cho SBD: 08000403
# Đã ghi dữ liệu thành công cho SBD: 08000404
# Đã ghi dữ liệu thành công cho SBD: 08000405
# Đã ghi dữ liệu thành công cho SBD: 08000406
# Đã ghi dữ liệu thành công cho SBD: 08000407
# Đã ghi dữ liệu thành công cho SBD: 08000408
# Đã ghi dữ liệu thành công cho SBD: 08000409
# Đã ghi dữ liệu thành công cho SBD: 08000410
# Đã ghi dữ liệu thành công cho SBD: 08000411
# Đã ghi dữ liệu thành công cho SBD: 08000412
# Đã ghi dữ liệu thành công cho SBD: 08000413
# Đã ghi dữ liệu thành công cho SBD: 08000414
# Đã ghi dữ liệu thành công cho SBD: 08000415
# Đã ghi dữ liệu thành công cho SBD: 08000416
# Đã ghi dữ liệu thành công cho SBD: 08000417
# Đã ghi dữ liệu thành công cho SBD: 08000418
# Đã ghi dữ liệu thành công cho SBD: 08000419
# Đã ghi dữ liệu thành công cho SBD: 08000420
# Đã ghi dữ liệu thành công cho SBD: 08000421
# Đã ghi dữ liệu thành công cho SBD: 08000422
# Đã ghi dữ liệu thành công cho SBD: 08000423
# Đã ghi dữ liệu thành công cho SBD: 08000424
# Đã ghi dữ liệu thành công cho SBD: 08000425
# Đã ghi dữ liệu thành công cho SBD: 08000426
# Đã ghi dữ liệu thành công cho SBD: 08000427
# Đã ghi dữ liệu thành công cho SBD: 08000428
# Đã ghi dữ liệu thành công cho SBD: 08000429
# Đã ghi dữ liệu thành công cho SBD: 08000430
# Đã ghi dữ liệu thành công cho SBD: 08000431
# Đã ghi dữ liệu thành công cho SBD: 08000432
# Đã ghi dữ liệu thành công cho SBD: 08000433
# Đã ghi dữ liệu thành công cho SBD: 08000434
# Đã ghi dữ liệu thành công cho SBD: 08000435
# Đã ghi dữ liệu thành công cho SBD: 08000436
# Đã ghi dữ liệu thành công cho SBD: 08000437
# Đã ghi dữ liệu thành công cho SBD: 08000438
# Đã ghi dữ liệu thành công cho SBD: 08000439
# Đã ghi dữ liệu thành công cho SBD: 08000440
# Đã ghi dữ liệu thành công cho SBD: 08000441
# Đã ghi dữ liệu thành công cho SBD: 08000442
# Đã ghi dữ liệu thành công cho SBD: 08000443
# Đã ghi dữ liệu thành công cho SBD: 08000444
# Đã ghi dữ liệu thành công cho SBD: 08000445
# Đã ghi dữ liệu thành công cho SBD: 08000446
# Đã ghi dữ liệu thành công cho SBD: 08000447
# Đã ghi dữ liệu thành công cho SBD: 08000448
# Đã ghi dữ liệu thành công cho SBD: 08000449
# Đã ghi dữ liệu thành công cho SBD: 08000450
# Đã ghi dữ liệu thành công cho SBD: 08000451
# Đã ghi dữ liệu thành công cho SBD: 08000452
# Đã ghi dữ liệu thành công cho SBD: 08000453
# Đã ghi dữ liệu thành công cho SBD: 08000454
# Đã ghi dữ liệu thành công cho SBD: 08000455
# Đã ghi dữ liệu thành công cho SBD: 08000456
# Đã ghi dữ liệu thành công cho SBD: 08000457
# Đã ghi dữ liệu thành công cho SBD: 08000458
# Đã ghi dữ liệu thành công cho SBD: 08000459
# Đã ghi dữ liệu thành công cho SBD: 08000460
# Đã ghi dữ liệu thành công cho SBD: 08000461
# Đã ghi dữ liệu thành công cho SBD: 08000462
# Đã ghi dữ liệu thành công cho SBD: 08000463
# Đã ghi dữ liệu thành công cho SBD: 08000464
# Đã ghi dữ liệu thành công cho SBD: 08000465
# Đã ghi dữ liệu thành công cho SBD: 08000466
# Đã ghi dữ liệu thành công cho SBD: 08000467
# Đã ghi dữ liệu thành công cho SBD: 08000468
# Đã ghi dữ liệu thành công cho SBD: 08000469
# Đã ghi dữ liệu thành công cho SBD: 08000470
# Đã ghi dữ liệu thành công cho SBD: 08000471
# Đã ghi dữ liệu thành công cho SBD: 08000472
# Đã ghi dữ liệu thành công cho SBD: 08000473
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 08000475
# Đã ghi dữ liệu thành công cho SBD: 08000476
# Đã ghi dữ liệu thành công cho SBD: 08000477
# Đã ghi dữ liệu thành công cho SBD: 08000478
# Đã ghi dữ liệu thành công cho SBD: 08000479
# Đã ghi dữ liệu thành công cho SBD: 08000480
# Đã ghi dữ liệu thành công cho SBD: 08000481
# Đã ghi dữ liệu thành công cho SBD: 08000482
# Đã ghi dữ liệu thành công cho SBD: 08000483
# Đã ghi dữ liệu thành công cho SBD: 08000484
# Đã ghi dữ liệu thành công cho SBD: 08000485
# Đã ghi dữ liệu thành công cho SBD: 08000486
# Đã ghi dữ liệu thành công cho SBD: 08000487
# Đã ghi dữ liệu thành công cho SBD: 08000488
# Đã ghi dữ liệu thành công cho SBD: 08000489
# Đã ghi dữ liệu thành công cho SBD: 08000490
# Đã ghi dữ liệu thành công cho SBD: 08000491
# Đã ghi dữ liệu thành công cho SBD: 08000492
# Đã ghi dữ liệu thành công cho SBD: 08000493
# Đã ghi dữ liệu thành công cho SBD: 08000494
# Đã ghi dữ liệu thành công cho SBD: 08000495
# Đã ghi dữ liệu thành công cho SBD: 08000496
# Đã ghi dữ liệu thành công cho SBD: 08000497
# Đã ghi dữ liệu thành công cho SBD: 08000498
# Đã ghi dữ liệu thành công cho SBD: 08000499
# Đã ghi dữ liệu thành công cho SBD: 08000500
# Đã ghi dữ liệu thành công cho SBD: 08000501
# Đã ghi dữ liệu thành công cho SBD: 08000502
# Đã ghi dữ liệu thành công cho SBD: 08000503
# Đã ghi dữ liệu thành công cho SBD: 08000504
# Đã ghi dữ liệu thành công cho SBD: 08000505
# Đã ghi dữ liệu thành công cho SBD: 08000506
# Đã ghi dữ liệu thành công cho SBD: 08000507
# Đã ghi dữ liệu thành công cho SBD: 08000508
# Đã ghi dữ liệu thành công cho SBD: 08000509
# Đã ghi dữ liệu thành công cho SBD: 08000510
# Đã ghi dữ liệu thành công cho SBD: 08000511
# Đã ghi dữ liệu thành công cho SBD: 08000512
# Đã ghi dữ liệu thành công cho SBD: 08000513
# Đã ghi dữ liệu thành công cho SBD: 08000514
# Đã ghi dữ liệu thành công cho SBD: 08000515
# Đã ghi dữ liệu thành công cho SBD: 08000516
# Đã ghi dữ liệu thành công cho SBD: 08000517
# Đã ghi dữ liệu thành công cho SBD: 08000518
# Đã ghi dữ liệu thành công cho SBD: 08000519
# Đã ghi dữ liệu thành công cho SBD: 08000520
# Đã ghi dữ liệu thành công cho SBD: 08000521
# Đã ghi dữ liệu thành công cho SBD: 08000522
# Đã ghi dữ liệu thành công cho SBD: 08000523
# Đã ghi dữ liệu thành công cho SBD: 08000524
# Đã ghi dữ liệu thành công cho SBD: 08000525
# Đã ghi dữ liệu thành công cho SBD: 08000526
# Đã ghi dữ liệu thành công cho SBD: 08000527
# Đã ghi dữ liệu thành công cho SBD: 08000528
# Đã ghi dữ liệu thành công cho SBD: 08000529
# Đã ghi dữ liệu thành công cho SBD: 08000530
# Đã ghi dữ liệu thành công cho SBD: 08000531
# Đã ghi dữ liệu thành công cho SBD: 08000532
# Đã ghi dữ liệu thành công cho SBD: 08000533
# Đã ghi dữ liệu thành công cho SBD: 08000534
# Đã ghi dữ liệu thành công cho SBD: 08000535
# Đã ghi dữ liệu thành công cho SBD: 08000536
# Đã ghi dữ liệu thành công cho SBD: 08000537
# Đã ghi dữ liệu thành công cho SBD: 08000538
# Đã ghi dữ liệu thành công cho SBD: 08000539
# Đã ghi dữ liệu thành công cho SBD: 08000540
# Đã ghi dữ liệu thành công cho SBD: 08000541
# Đã ghi dữ liệu thành công cho SBD: 08000542
# Đã ghi dữ liệu thành công cho SBD: 08000543
# Đã ghi dữ liệu thành công cho SBD: 08000544
# Đã ghi dữ liệu thành công cho SBD: 08000545
# Đã ghi dữ liệu thành công cho SBD: 08000546
# Đã ghi dữ liệu thành công cho SBD: 08000547
# Đã ghi dữ liệu thành công cho SBD: 08000548
# Đã ghi dữ liệu thành công cho SBD: 08000549
# Đã ghi dữ liệu thành công cho SBD: 08000550
# Đã ghi dữ liệu thành công cho SBD: 08000551
# Đã ghi dữ liệu thành công cho SBD: 08000552
# Đã ghi dữ liệu thành công cho SBD: 08000553
# Đã ghi dữ liệu thành công cho SBD: 08000554
# Đã ghi dữ liệu thành công cho SBD: 08000555
# Đã ghi dữ liệu thành công cho SBD: 08000556
# Đã ghi dữ liệu thành công cho SBD: 08000557
# Đã ghi dữ liệu thành công cho SBD: 08000558
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 08000560
# Đã ghi dữ liệu thành công cho SBD: 08000561
# Đã ghi dữ liệu thành công cho SBD: 08000562
# Đã ghi dữ liệu thành công cho SBD: 08000563
# Đã ghi dữ liệu thành công cho SBD: 08000564
# Đã ghi dữ liệu thành công cho SBD: 08000565
# Đã ghi dữ liệu thành công cho SBD: 08000566
# Đã ghi dữ liệu thành công cho SBD: 08000567
# Đã ghi dữ liệu thành công cho SBD: 08000568
# Đã ghi dữ liệu thành công cho SBD: 08000569
# Đã ghi dữ liệu thành công cho SBD: 08000570
# Đã ghi dữ liệu thành công cho SBD: 08000571
# Đã ghi dữ liệu thành công cho SBD: 08000572
# Đã ghi dữ liệu thành công cho SBD: 08000573
# Đã ghi dữ liệu thành công cho SBD: 08000574
# Đã ghi dữ liệu thành công cho SBD: 08000575
# Đã ghi dữ liệu thành công cho SBD: 08000576
# Đã ghi dữ liệu thành công cho SBD: 08000577
# Đã ghi dữ liệu thành công cho SBD: 08000578
# Đã ghi dữ liệu thành công cho SBD: 08000579
# Đã ghi dữ liệu thành công cho SBD: 08000580
# Đã ghi dữ liệu thành công cho SBD: 08000581
# Đã ghi dữ liệu thành công cho SBD: 08000582
# Đã ghi dữ liệu thành công cho SBD: 08000583
# Đã ghi dữ liệu thành công cho SBD: 08000584
# Đã ghi dữ liệu thành công cho SBD: 08000585
# Đã ghi dữ liệu thành công cho SBD: 08000586
# Đã ghi dữ liệu thành công cho SBD: 08000587
# Đã ghi dữ liệu thành công cho SBD: 08000588
# Đã ghi dữ liệu thành công cho SBD: 08000589
# Đã ghi dữ liệu thành công cho SBD: 08000590
# Đã ghi dữ liệu thành công cho SBD: 08000591
# Đã ghi dữ liệu thành công cho SBD: 08000592
# Đã ghi dữ liệu thành công cho SBD: 08000593
# Đã ghi dữ liệu thành công cho SBD: 08000594
# Đã ghi dữ liệu thành công cho SBD: 08000595
# Đã ghi dữ liệu thành công cho SBD: 08000596
# Đã ghi dữ liệu thành công cho SBD: 08000597
# Đã ghi dữ liệu thành công cho SBD: 08000598
# Đã ghi dữ liệu thành công cho SBD: 08000599
# Đã ghi dữ liệu thành công cho SBD: 08000600
# Đã ghi dữ liệu thành công cho SBD: 08000601
# Đã ghi dữ liệu thành công cho SBD: 08000602
# Đã ghi dữ liệu thành công cho SBD: 08000603
# Đã ghi dữ liệu thành công cho SBD: 08000604
# Đã ghi dữ liệu thành công cho SBD: 08000605
# Đã ghi dữ liệu thành công cho SBD: 08000606
# Đã ghi dữ liệu thành công cho SBD: 08000607
# Đã ghi dữ liệu thành công cho SBD: 08000608
# Đã ghi dữ liệu thành công cho SBD: 08000609
# Đã ghi dữ liệu thành công cho SBD: 08000610
# Đã ghi dữ liệu thành công cho SBD: 08000611
# Đã ghi dữ liệu thành công cho SBD: 08000612
# Đã ghi dữ liệu thành công cho SBD: 08000613
# Đã ghi dữ liệu thành công cho SBD: 08000614
# Đã ghi dữ liệu thành công cho SBD: 08000615
# Đã ghi dữ liệu thành công cho SBD: 08000616
# Đã ghi dữ liệu thành công cho SBD: 08000617
# Đã ghi dữ liệu thành công cho SBD: 08000618
# Đã ghi dữ liệu thành công cho SBD: 08000619
# Đã ghi dữ liệu thành công cho SBD: 08000620
# Đã ghi dữ liệu thành công cho SBD: 08000621
# Đã ghi dữ liệu thành công cho SBD: 08000622
# Đã ghi dữ liệu thành công cho SBD: 08000623
# Đã ghi dữ liệu thành công cho SBD: 08000624
# Đã ghi dữ liệu thành công cho SBD: 08000625
# Đã ghi dữ liệu thành công cho SBD: 08000626
# Đã ghi dữ liệu thành công cho SBD: 08000627
# Đã ghi dữ liệu thành công cho SBD: 08000628
# Đã ghi dữ liệu thành công cho SBD: 08000629
# Đã ghi dữ liệu thành công cho SBD: 08000630
# Đã ghi dữ liệu thành công cho SBD: 08000631
# Đã ghi dữ liệu thành công cho SBD: 08000632
# Đã ghi dữ liệu thành công cho SBD: 08000633
# Đã ghi dữ liệu thành công cho SBD: 08000634
# Đã ghi dữ liệu thành công cho SBD: 08000635
# Đã ghi dữ liệu thành công cho SBD: 08000636
# Đã ghi dữ liệu thành công cho SBD: 08000637
# Đã ghi dữ liệu thành công cho SBD: 08000638
# Đã ghi dữ liệu thành công cho SBD: 08000639
# Đã ghi dữ liệu thành công cho SBD: 08000640
# Đã ghi dữ liệu thành công cho SBD: 08000641
# Đã ghi dữ liệu thành công cho SBD: 08000642
# Đã ghi dữ liệu thành công cho SBD: 08000643
# Đã ghi dữ liệu thành công cho SBD: 08000644
# Đã ghi dữ liệu thành công cho SBD: 08000645
# Đã ghi dữ liệu thành công cho SBD: 08000646
# Đã ghi dữ liệu thành công cho SBD: 08000647
# Đã ghi dữ liệu thành công cho SBD: 08000648
# Đã ghi dữ liệu thành công cho SBD: 08000649
# Đã ghi dữ liệu thành công cho SBD: 08000650
# Đã ghi dữ liệu thành công cho SBD: 08000651
# Đã ghi dữ liệu thành công cho SBD: 08000652
# Đã ghi dữ liệu thành công cho SBD: 08000653
# Đã ghi dữ liệu thành công cho SBD: 08000654
# Đã ghi dữ liệu thành công cho SBD: 08000655
# Đã ghi dữ liệu thành công cho SBD: 08000656
# Đã ghi dữ liệu thành công cho SBD: 08000657
# Đã ghi dữ liệu thành công cho SBD: 08000658
# Đã ghi dữ liệu thành công cho SBD: 08000659
# Đã ghi dữ liệu thành công cho SBD: 08000660
# Đã ghi dữ liệu thành công cho SBD: 08000661
# Đã ghi dữ liệu thành công cho SBD: 08000662
# Đã ghi dữ liệu thành công cho SBD: 08000663
# Đã ghi dữ liệu thành công cho SBD: 08000664
# Đã ghi dữ liệu thành công cho SBD: 08000665
# Đã ghi dữ liệu thành công cho SBD: 08000666
# Đã ghi dữ liệu thành công cho SBD: 08000667
# Đã ghi dữ liệu thành công cho SBD: 08000668
# Đã ghi dữ liệu thành công cho SBD: 08000669
# Đã ghi dữ liệu thành công cho SBD: 08000670
# Đã ghi dữ liệu thành công cho SBD: 08000671
# Đã ghi dữ liệu thành công cho SBD: 08000672
# Đã ghi dữ liệu thành công cho SBD: 08000673
# Đã ghi dữ liệu thành công cho SBD: 08000674
# Đã ghi dữ liệu thành công cho SBD: 08000675
# Đã ghi dữ liệu thành công cho SBD: 08000676
# Đã ghi dữ liệu thành công cho SBD: 08000677
# Đã ghi dữ liệu thành công cho SBD: 08000678
# Đã ghi dữ liệu thành công cho SBD: 08000679
# Đã ghi dữ liệu thành công cho SBD: 08000680
# Đã ghi dữ liệu thành công cho SBD: 08000681
# Đã ghi dữ liệu thành công cho SBD: 08000682
# Đã ghi dữ liệu thành công cho SBD: 08000683
# Đã ghi dữ liệu thành công cho SBD: 08000684
# Đã ghi dữ liệu thành công cho SBD: 08000685
# Đã ghi dữ liệu thành công cho SBD: 08000686
# Đã ghi dữ liệu thành công cho SBD: 08000687
# Đã ghi dữ liệu thành công cho SBD: 08000688
# Đã ghi dữ liệu thành công cho SBD: 08000689
# Đã ghi dữ liệu thành công cho SBD: 08000690
# Đã ghi dữ liệu thành công cho SBD: 08000691
# Đã ghi dữ liệu thành công cho SBD: 08000692
# Đã ghi dữ liệu thành công cho SBD: 08000693
# Đã ghi dữ liệu thành công cho SBD: 08000694
# Đã ghi dữ liệu thành công cho SBD: 08000695
# Đã ghi dữ liệu thành công cho SBD: 08000696
# Đã ghi dữ liệu thành công cho SBD: 08000697
# Đã ghi dữ liệu thành công cho SBD: 08000698
# Đã ghi dữ liệu thành công cho SBD: 08000699
# Đã ghi dữ liệu thành công cho SBD: 08000700
# Đã ghi dữ liệu thành công cho SBD: 08000701
# Đã ghi dữ liệu thành công cho SBD: 08000702
# Đã ghi dữ liệu thành công cho SBD: 08000703
# Đã ghi dữ liệu thành công cho SBD: 08000704
# Đã ghi dữ liệu thành công cho SBD: 08000705
# Đã ghi dữ liệu thành công cho SBD: 08000706
# Đã ghi dữ liệu thành công cho SBD: 08000707
# Đã ghi dữ liệu thành công cho SBD: 08000708
# Đã ghi dữ liệu thành công cho SBD: 08000709
# Đã ghi dữ liệu thành công cho SBD: 08000710
# Đã ghi dữ liệu thành công cho SBD: 08000711
# Đã ghi dữ liệu thành công cho SBD: 08000712
# Đã ghi dữ liệu thành công cho SBD: 08000713
# Đã ghi dữ liệu thành công cho SBD: 08000714
# Đã ghi dữ liệu thành công cho SBD: 08000715
# Đã ghi dữ liệu thành công cho SBD: 08000716
# Đã ghi dữ liệu thành công cho SBD: 08000717
# Đã ghi dữ liệu thành công cho SBD: 08000718
# Đã ghi dữ liệu thành công cho SBD: 08000719
# Đã ghi dữ liệu thành công cho SBD: 08000720
# Đã ghi dữ liệu thành công cho SBD: 08000721
# Đã ghi dữ liệu thành công cho SBD: 08000722
# Đã ghi dữ liệu thành công cho SBD: 08000723
# Đã ghi dữ liệu thành công cho SBD: 08000724
# Đã ghi dữ liệu thành công cho SBD: 08000725
# Đã ghi dữ liệu thành công cho SBD: 08000726
# Đã ghi dữ liệu thành công cho SBD: 08000727
# Đã ghi dữ liệu thành công cho SBD: 08000728
# Đã ghi dữ liệu thành công cho SBD: 08000729
# Đã ghi dữ liệu thành công cho SBD: 08000730
# Đã ghi dữ liệu thành công cho SBD: 08000731
# Đã ghi dữ liệu thành công cho SBD: 08000732
# Đã ghi dữ liệu thành công cho SBD: 08000733
# Đã ghi dữ liệu thành công cho SBD: 08000734
# Đã ghi dữ liệu thành công cho SBD: 08000735
# Đã ghi dữ liệu thành công cho SBD: 08000736
# Đã ghi dữ liệu thành công cho SBD: 08000737
# Đã ghi dữ liệu thành công cho SBD: 08000738
# Đã ghi dữ liệu thành công cho SBD: 08000739
# Đã ghi dữ liệu thành công cho SBD: 08000740
# Đã ghi dữ liệu thành công cho SBD: 08000741
# Đã ghi dữ liệu thành công cho SBD: 08000742
# Đã ghi dữ liệu thành công cho SBD: 08000743
# Đã ghi dữ liệu thành công cho SBD: 08000744
# Đã ghi dữ liệu thành công cho SBD: 08000745
# Đã ghi dữ liệu thành công cho SBD: 08000746
# Đã ghi dữ liệu thành công cho SBD: 08000747
# Đã ghi dữ liệu thành công cho SBD: 08000748
# Đã ghi dữ liệu thành công cho SBD: 08000749
# Đã ghi dữ liệu thành công cho SBD: 08000750
# Đã ghi dữ liệu thành công cho SBD: 08000751
# Đã ghi dữ liệu thành công cho SBD: 08000752
# Đã ghi dữ liệu thành công cho SBD: 08000753
# Đã ghi dữ liệu thành công cho SBD: 08000754
# Đã ghi dữ liệu thành công cho SBD: 08000755
# Đã ghi dữ liệu thành công cho SBD: 08000756
# Đã ghi dữ liệu thành công cho SBD: 08000757
# Đã ghi dữ liệu thành công cho SBD: 08000758
# Đã ghi dữ liệu thành công cho SBD: 08000759
# Đã ghi dữ liệu thành công cho SBD: 08000760
# Đã ghi dữ liệu thành công cho SBD: 08000761
# Đã ghi dữ liệu thành công cho SBD: 08000762
# Đã ghi dữ liệu thành công cho SBD: 08000763
# Đã ghi dữ liệu thành công cho SBD: 08000764
# Đã ghi dữ liệu thành công cho SBD: 08000765
# Đã ghi dữ liệu thành công cho SBD: 08000766
# Đã ghi dữ liệu thành công cho SBD: 08000767
# Đã ghi dữ liệu thành công cho SBD: 08000768
# Đã ghi dữ liệu thành công cho SBD: 08000769
# Đã ghi dữ liệu thành công cho SBD: 08000770
# Đã ghi dữ liệu thành công cho SBD: 08000771
# Đã ghi dữ liệu thành công cho SBD: 08000772
# Đã ghi dữ liệu thành công cho SBD: 08000773
# Đã ghi dữ liệu thành công cho SBD: 08000774
# Đã ghi dữ liệu thành công cho SBD: 08000775
# Đã ghi dữ liệu thành công cho SBD: 08000776
# Đã ghi dữ liệu thành công cho SBD: 08000777
# Đã ghi dữ liệu thành công cho SBD: 08000778
# Đã ghi dữ liệu thành công cho SBD: 08000779
# Đã ghi dữ liệu thành công cho SBD: 08000780
# Đã ghi dữ liệu thành công cho SBD: 08000781
# Đã ghi dữ liệu thành công cho SBD: 08000782
# Đã ghi dữ liệu thành công cho SBD: 08000783
# Đã ghi dữ liệu thành công cho SBD: 08000784
# Đã ghi dữ liệu thành công cho SBD: 08000785
# Đã ghi dữ liệu thành công cho SBD: 08000786
# Đã ghi dữ liệu thành công cho SBD: 08000787
# Đã ghi dữ liệu thành công cho SBD: 08000788
# Đã ghi dữ liệu thành công cho SBD: 08000789
# Đã ghi dữ liệu thành công cho SBD: 08000790
# Đã ghi dữ liệu thành công cho SBD: 08000791
# Đã ghi dữ liệu thành công cho SBD: 08000792
# Đã ghi dữ liệu thành công cho SBD: 08000793
# Đã ghi dữ liệu thành công cho SBD: 08000794
# Đã ghi dữ liệu thành công cho SBD: 08000795
# Đã ghi dữ liệu thành công cho SBD: 08000796
# Đã ghi dữ liệu thành công cho SBD: 08000797
# Đã ghi dữ liệu thành công cho SBD: 08000798
# Đã ghi dữ liệu thành công cho SBD: 08000799
# Đã ghi dữ liệu thành công cho SBD: 08000800
# Đã ghi dữ liệu thành công cho SBD: 08000801
# Đã ghi dữ liệu thành công cho SBD: 08000802
# Đã ghi dữ liệu thành công cho SBD: 08000803
# Đã ghi dữ liệu thành công cho SBD: 08000804
# Đã ghi dữ liệu thành công cho SBD: 08000805
# Đã ghi dữ liệu thành công cho SBD: 08000806
# Đã ghi dữ liệu thành công cho SBD: 08000807
# Đã ghi dữ liệu thành công cho SBD: 08000808
# Đã ghi dữ liệu thành công cho SBD: 08000809
# Đã ghi dữ liệu thành công cho SBD: 08000810
# Đã ghi dữ liệu thành công cho SBD: 08000811
# Đã ghi dữ liệu thành công cho SBD: 08000812
# Đã ghi dữ liệu thành công cho SBD: 08000813
# Đã ghi dữ liệu thành công cho SBD: 08000814
# Đã ghi dữ liệu thành công cho SBD: 08000815
# Đã ghi dữ liệu thành công cho SBD: 08000816
# Đã ghi dữ liệu thành công cho SBD: 08000817
# Đã ghi dữ liệu thành công cho SBD: 08000818
# Đã ghi dữ liệu thành công cho SBD: 08000819
# Đã ghi dữ liệu thành công cho SBD: 08000820
# Đã ghi dữ liệu thành công cho SBD: 08000821
# Đã ghi dữ liệu thành công cho SBD: 08000822
# Đã ghi dữ liệu thành công cho SBD: 08000823
# Đã ghi dữ liệu thành công cho SBD: 08000824
# Đã ghi dữ liệu thành công cho SBD: 08000825
# Đã ghi dữ liệu thành công cho SBD: 08000826
# Đã ghi dữ liệu thành công cho SBD: 08000827
# Đã ghi dữ liệu thành công cho SBD: 08000828
# Đã ghi dữ liệu thành công cho SBD: 08000829
# Đã ghi dữ liệu thành công cho SBD: 08000830
# Đã ghi dữ liệu thành công cho SBD: 08000831
# Đã ghi dữ liệu thành công cho SBD: 08000832
# Đã ghi dữ liệu thành công cho SBD: 08000833
# Đã ghi dữ liệu thành công cho SBD: 08000834
# Đã ghi dữ liệu thành công cho SBD: 08000835
# Đã ghi dữ liệu thành công cho SBD: 08000836
# Đã ghi dữ liệu thành công cho SBD: 08000837
# Đã ghi dữ liệu thành công cho SBD: 08000838
# Đã ghi dữ liệu thành công cho SBD: 08000839
# Đã ghi dữ liệu thành công cho SBD: 08000840
# Đã ghi dữ liệu thành công cho SBD: 08000841
# Đã ghi dữ liệu thành công cho SBD: 08000842
# Đã ghi dữ liệu thành công cho SBD: 08000843
# Đã ghi dữ liệu thành công cho SBD: 08000844
# Đã ghi dữ liệu thành công cho SBD: 08000845
# Đã ghi dữ liệu thành công cho SBD: 08000846
# Đã ghi dữ liệu thành công cho SBD: 08000847
# Đã ghi dữ liệu thành công cho SBD: 08000848
# Đã ghi dữ liệu thành công cho SBD: 08000849
# Đã ghi dữ liệu thành công cho SBD: 08000850
# Đã ghi dữ liệu thành công cho SBD: 08000851
# Đã ghi dữ liệu thành công cho SBD: 08000852
# Đã ghi dữ liệu thành công cho SBD: 08000853
# Đã ghi dữ liệu thành công cho SBD: 08000854
# Đã ghi dữ liệu thành công cho SBD: 08000855
# Đã ghi dữ liệu thành công cho SBD: 08000856
# Đã ghi dữ liệu thành công cho SBD: 08000857
# Đã ghi dữ liệu thành công cho SBD: 08000858
# Đã ghi dữ liệu thành công cho SBD: 08000859
# Đã ghi dữ liệu thành công cho SBD: 08000860
# Đã ghi dữ liệu thành công cho SBD: 08000861
# Đã ghi dữ liệu thành công cho SBD: 08000862
# Đã ghi dữ liệu thành công cho SBD: 08000863
# Đã ghi dữ liệu thành công cho SBD: 08000864
# Đã ghi dữ liệu thành công cho SBD: 08000865
# Đã ghi dữ liệu thành công cho SBD: 08000866
# Đã ghi dữ liệu thành công cho SBD: 08000867
# Đã ghi dữ liệu thành công cho SBD: 08000868
# Đã ghi dữ liệu thành công cho SBD: 08000869
# Đã ghi dữ liệu thành công cho SBD: 08000870
# Đã ghi dữ liệu thành công cho SBD: 08000871
# Đã ghi dữ liệu thành công cho SBD: 08000872
# Đã ghi dữ liệu thành công cho SBD: 08000873
# Đã ghi dữ liệu thành công cho SBD: 08000874
# Đã ghi dữ liệu thành công cho SBD: 08000875
# Đã ghi dữ liệu thành công cho SBD: 08000876
# Đã ghi dữ liệu thành công cho SBD: 08000877
# Đã ghi dữ liệu thành công cho SBD: 08000878
# Đã ghi dữ liệu thành công cho SBD: 08000879
# Đã ghi dữ liệu thành công cho SBD: 08000880
# Đã ghi dữ liệu thành công cho SBD: 08000881
# Đã ghi dữ liệu thành công cho SBD: 08000882
# Đã ghi dữ liệu thành công cho SBD: 08000883
# Đã ghi dữ liệu thành công cho SBD: 08000884
# Đã ghi dữ liệu thành công cho SBD: 08000885
# Đã ghi dữ liệu thành công cho SBD: 08000886
# Đã ghi dữ liệu thành công cho SBD: 08000887
# Đã ghi dữ liệu thành công cho SBD: 08000888
# Đã ghi dữ liệu thành công cho SBD: 08000889
# Đã ghi dữ liệu thành công cho SBD: 08000890
# Đã ghi dữ liệu thành công cho SBD: 08000891
# Đã ghi dữ liệu thành công cho SBD: 08000892
# Đã ghi dữ liệu thành công cho SBD: 08000893
# Đã ghi dữ liệu thành công cho SBD: 08000894
# Đã ghi dữ liệu thành công cho SBD: 08000895
# Đã ghi dữ liệu thành công cho SBD: 08000896
# Đã ghi dữ liệu thành công cho SBD: 08000897
# Đã ghi dữ liệu thành công cho SBD: 08000898
# Đã ghi dữ liệu thành công cho SBD: 08000899
# Đã ghi dữ liệu thành công cho SBD: 08000900
# Đã ghi dữ liệu thành công cho SBD: 08000901
# Đã ghi dữ liệu thành công cho SBD: 08000902
# Đã ghi dữ liệu thành công cho SBD: 08000903
# Đã ghi dữ liệu thành công cho SBD: 08000904
# Đã ghi dữ liệu thành công cho SBD: 08000905
# Đã ghi dữ liệu thành công cho SBD: 08000906
# Đã ghi dữ liệu thành công cho SBD: 08000907
# Đã ghi dữ liệu thành công cho SBD: 08000908
# Đã ghi dữ liệu thành công cho SBD: 08000909
# Đã ghi dữ liệu thành công cho SBD: 08000910
# Đã ghi dữ liệu thành công cho SBD: 08000911
# Đã ghi dữ liệu thành công cho SBD: 08000912
# Đã ghi dữ liệu thành công cho SBD: 08000913
# Đã ghi dữ liệu thành công cho SBD: 08000914
# Đã ghi dữ liệu thành công cho SBD: 08000915
# Đã ghi dữ liệu thành công cho SBD: 08000916
# Đã ghi dữ liệu thành công cho SBD: 08000917
# Đã ghi dữ liệu thành công cho SBD: 08000918
# Đã ghi dữ liệu thành công cho SBD: 08000919
# Đã ghi dữ liệu thành công cho SBD: 08000920
# Đã ghi dữ liệu thành công cho SBD: 08000921
# Đã ghi dữ liệu thành công cho SBD: 08000922
# Đã ghi dữ liệu thành công cho SBD: 08000923
# Đã ghi dữ liệu thành công cho SBD: 08000924
# Đã ghi dữ liệu thành công cho SBD: 08000925
# Đã ghi dữ liệu thành công cho SBD: 08000926
# Đã ghi dữ liệu thành công cho SBD: 08000927
# Đã ghi dữ liệu thành công cho SBD: 08000928
# Đã ghi dữ liệu thành công cho SBD: 08000929
# Đã ghi dữ liệu thành công cho SBD: 08000930
# Đã ghi dữ liệu thành công cho SBD: 08000931
# Đã ghi dữ liệu thành công cho SBD: 08000932
# Đã ghi dữ liệu thành công cho SBD: 08000933
# Đã ghi dữ liệu thành công cho SBD: 08000934
# Đã ghi dữ liệu thành công cho SBD: 08000935
# Đã ghi dữ liệu thành công cho SBD: 08000936
# Đã ghi dữ liệu thành công cho SBD: 08000937
# Đã ghi dữ liệu thành công cho SBD: 08000938
# Đã ghi dữ liệu thành công cho SBD: 08000939
# Đã ghi dữ liệu thành công cho SBD: 08000940
# Đã ghi dữ liệu thành công cho SBD: 08000941
# Đã ghi dữ liệu thành công cho SBD: 08000942
# Đã ghi dữ liệu thành công cho SBD: 08000943
# Đã ghi dữ liệu thành công cho SBD: 08000944
# Đã ghi dữ liệu thành công cho SBD: 08000945
# Đã ghi dữ liệu thành công cho SBD: 08000946
# Đã ghi dữ liệu thành công cho SBD: 08000947
# Đã ghi dữ liệu thành công cho SBD: 08000948
# Đã ghi dữ liệu thành công cho SBD: 08000949
# Đã ghi dữ liệu thành công cho SBD: 08000950
# Đã ghi dữ liệu thành công cho SBD: 08000951
# Đã ghi dữ liệu thành công cho SBD: 08000952
# Đã ghi dữ liệu thành công cho SBD: 08000953
# Đã ghi dữ liệu thành công cho SBD: 08000954
# Đã ghi dữ liệu thành công cho SBD: 08000955
# Đã ghi dữ liệu thành công cho SBD: 08000956
# Đã ghi dữ liệu thành công cho SBD: 08000957
# Đã ghi dữ liệu thành công cho SBD: 08000958
# Đã ghi dữ liệu thành công cho SBD: 08000959
# Đã ghi dữ liệu thành công cho SBD: 08000960
# Đã ghi dữ liệu thành công cho SBD: 08000961
# Đã ghi dữ liệu thành công cho SBD: 08000962
# Đã ghi dữ liệu thành công cho SBD: 08000963
# Đã ghi dữ liệu thành công cho SBD: 08000964
# Đã ghi dữ liệu thành công cho SBD: 08000965
# Đã ghi dữ liệu thành công cho SBD: 08000966
# Đã ghi dữ liệu thành công cho SBD: 08000967
# Đã ghi dữ liệu thành công cho SBD: 08000968
# Đã ghi dữ liệu thành công cho SBD: 08000969
# Đã ghi dữ liệu thành công cho SBD: 08000970
# Đã ghi dữ liệu thành công cho SBD: 08000971
# Đã ghi dữ liệu thành công cho SBD: 08000972
# Đã ghi dữ liệu thành công cho SBD: 08000973
# Đã ghi dữ liệu thành công cho SBD: 08000974
# Đã ghi dữ liệu thành công cho SBD: 08000975
# Đã ghi dữ liệu thành công cho SBD: 08000976
# Đã ghi dữ liệu thành công cho SBD: 08000977
# Đã ghi dữ liệu thành công cho SBD: 08000978
# Đã ghi dữ liệu thành công cho SBD: 08000979
# Đã ghi dữ liệu thành công cho SBD: 08000980
# Đã ghi dữ liệu thành công cho SBD: 08000981
# Đã ghi dữ liệu thành công cho SBD: 08000982
# Đã ghi dữ liệu thành công cho SBD: 08000983
# Đã ghi dữ liệu thành công cho SBD: 08000984
# Đã ghi dữ liệu thành công cho SBD: 08000985
# Đã ghi dữ liệu thành công cho SBD: 08000986
# Đã ghi dữ liệu thành công cho SBD: 08000987
# Đã ghi dữ liệu thành công cho SBD: 08000988
# Đã ghi dữ liệu thành công cho SBD: 08000989
# Đã ghi dữ liệu thành công cho SBD: 08000990
# Đã ghi dữ liệu thành công cho SBD: 08000991
# Đã ghi dữ liệu thành công cho SBD: 08000992
# Đã ghi dữ liệu thành công cho SBD: 08000993
# Đã ghi dữ liệu thành công cho SBD: 08000994
# Đã ghi dữ liệu thành công cho SBD: 08000995
# Đã ghi dữ liệu thành công cho SBD: 08000996
# Đã ghi dữ liệu thành công cho SBD: 08000997
# Đã ghi dữ liệu thành công cho SBD: 08000998
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 08001000
# Đã ghi dữ liệu thành công cho SBD: 08001001
# Đã ghi dữ liệu thành công cho SBD: 08001002
# Đã ghi dữ liệu thành công cho SBD: 08001003
# Đã ghi dữ liệu thành công cho SBD: 08001004
# Đã ghi dữ liệu thành công cho SBD: 08001005
# Đã ghi dữ liệu thành công cho SBD: 08001006
# Đã ghi dữ liệu thành công cho SBD: 08001007
# Đã ghi dữ liệu thành công cho SBD: 08001008
# Đã ghi dữ liệu thành công cho SBD: 08001009
# Đã ghi dữ liệu thành công cho SBD: 08001010
# Đã ghi dữ liệu thành công cho SBD: 08001011
# Đã ghi dữ liệu thành công cho SBD: 08001012
# Đã ghi dữ liệu thành công cho SBD: 08001013
# Đã ghi dữ liệu thành công cho SBD: 08001014
# Đã ghi dữ liệu thành công cho SBD: 08001015
# Đã ghi dữ liệu thành công cho SBD: 08001016
# Đã ghi dữ liệu thành công cho SBD: 08001017
# Đã ghi dữ liệu thành công cho SBD: 08001018
# Đã ghi dữ liệu thành công cho SBD: 08001019
# Đã ghi dữ liệu thành công cho SBD: 08001020
# Đã ghi dữ liệu thành công cho SBD: 08001021
# Đã ghi dữ liệu thành công cho SBD: 08001022
# Đã ghi dữ liệu thành công cho SBD: 08001023
# Đã ghi dữ liệu thành công cho SBD: 08001024
# Đã ghi dữ liệu thành công cho SBD: 08001025
# Đã ghi dữ liệu thành công cho SBD: 08001026
# Đã ghi dữ liệu thành công cho SBD: 08001027
# Đã ghi dữ liệu thành công cho SBD: 08001028
# Đã ghi dữ liệu thành công cho SBD: 08001029
# Đã ghi dữ liệu thành công cho SBD: 08001030
# Đã ghi dữ liệu thành công cho SBD: 08001031
# Đã ghi dữ liệu thành công cho SBD: 08001032
# Đã ghi dữ liệu thành công cho SBD: 08001033
# Đã ghi dữ liệu thành công cho SBD: 08001034
# Đã ghi dữ liệu thành công cho SBD: 08001035
# Đã ghi dữ liệu thành công cho SBD: 08001036
# Đã ghi dữ liệu thành công cho SBD: 08001037
# Đã ghi dữ liệu thành công cho SBD: 08001038
# Đã ghi dữ liệu thành công cho SBD: 08001039
# Đã ghi dữ liệu thành công cho SBD: 08001040
# Đã ghi dữ liệu thành công cho SBD: 08001041
# Đã ghi dữ liệu thành công cho SBD: 08001042
# Đã ghi dữ liệu thành công cho SBD: 08001043
# Đã ghi dữ liệu thành công cho SBD: 08001044
# Đã ghi dữ liệu thành công cho SBD: 08001045
# Đã ghi dữ liệu thành công cho SBD: 08001046
# Đã ghi dữ liệu thành công cho SBD: 08001047
# Đã ghi dữ liệu thành công cho SBD: 08001048
# Đã ghi dữ liệu thành công cho SBD: 08001049
# Đã ghi dữ liệu thành công cho SBD: 08001050
# Đã ghi dữ liệu thành công cho SBD: 08001051
# Đã ghi dữ liệu thành công cho SBD: 08001052
# Đã ghi dữ liệu thành công cho SBD: 08001053
# Đã ghi dữ liệu thành công cho SBD: 08001054
# Đã ghi dữ liệu thành công cho SBD: 08001055
# Đã ghi dữ liệu thành công cho SBD: 08001056
# Đã ghi dữ liệu thành công cho SBD: 08001057
# Đã ghi dữ liệu thành công cho SBD: 08001058
# Đã ghi dữ liệu thành công cho SBD: 08001059
# Đã ghi dữ liệu thành công cho SBD: 08001060
# Đã ghi dữ liệu thành công cho SBD: 08001061
# Đã ghi dữ liệu thành công cho SBD: 08001062
# Đã ghi dữ liệu thành công cho SBD: 08001063
# Đã ghi dữ liệu thành công cho SBD: 08001064
# Đã ghi dữ liệu thành công cho SBD: 08001065
# Đã ghi dữ liệu thành công cho SBD: 08001066
# Đã ghi dữ liệu thành công cho SBD: 08001067
# Đã ghi dữ liệu thành công cho SBD: 08001068
# Đã ghi dữ liệu thành công cho SBD: 08001069
# Đã ghi dữ liệu thành công cho SBD: 08001070
# Đã ghi dữ liệu thành công cho SBD: 08001071
# Đã ghi dữ liệu thành công cho SBD: 08001072
# Đã ghi dữ liệu thành công cho SBD: 08001073
# Đã ghi dữ liệu thành công cho SBD: 08001074
# Đã ghi dữ liệu thành công cho SBD: 08001075
# Đã ghi dữ liệu thành công cho SBD: 08001076
# Đã ghi dữ liệu thành công cho SBD: 08001077
# Đã ghi dữ liệu thành công cho SBD: 08001078
# Đã ghi dữ liệu thành công cho SBD: 08001079
# Đã ghi dữ liệu thành công cho SBD: 08001080
# Đã ghi dữ liệu thành công cho SBD: 08001081
# Đã ghi dữ liệu thành công cho SBD: 08001082
# Đã ghi dữ liệu thành công cho SBD: 08001083
# Đã ghi dữ liệu thành công cho SBD: 08001084
# Đã ghi dữ liệu thành công cho SBD: 08001085
# Đã ghi dữ liệu thành công cho SBD: 08001086
# Đã ghi dữ liệu thành công cho SBD: 08001087
# Đã ghi dữ liệu thành công cho SBD: 08001088
# Đã ghi dữ liệu thành công cho SBD: 08001089
# Đã ghi dữ liệu thành công cho SBD: 08001090
# Đã ghi dữ liệu thành công cho SBD: 08001091
# ...
# Đã ghi dữ liệu thành công cho SBD: 08003106
# Đã ghi dữ liệu thành công cho SBD: 08003107
# Đã ghi dữ liệu thành công cho SBD: 08003108
# Đã ghi dữ liệu thành công cho SBD: 08003109
# Đã ghi dữ liệu thành công cho SBD: 08003110
# Đã ghi dữ liệu thành công cho SBD: 08003111
# Đã ghi dữ liệu thành công cho SBD: 08003112
# Đã ghi dữ liệu thành công cho SBD: 08003113
# Đã ghi dữ liệu thành công cho SBD: 08003114
# Đã ghi dữ liệu thành công cho SBD: 08003115
# Đã ghi dữ liệu thành công cho SBD: 08003116
# Đã ghi dữ liệu thành công cho SBD: 08003117
# Đã ghi dữ liệu thành công cho SBD: 08003118
# Đã ghi dữ liệu thành công cho SBD: 08003119
# Đã ghi dữ liệu thành công cho SBD: 08003120
# Đã ghi dữ liệu thành công cho SBD: 08003121
# Đã ghi dữ liệu thành công cho SBD: 08003122
# Đã ghi dữ liệu thành công cho SBD: 08003123
# Đã ghi dữ liệu thành công cho SBD: 08003124
# Đã ghi dữ liệu thành công cho SBD: 08003125
# Đã ghi dữ liệu thành công cho SBD: 08003126
# Đã ghi dữ liệu thành công cho SBD: 08003127
# Đã ghi dữ liệu thành công cho SBD: 08003128
# Đã ghi dữ liệu thành công cho SBD: 08003129
# Đã ghi dữ liệu thành công cho SBD: 08003130
# Đã ghi dữ liệu thành công cho SBD: 08003131
# Đã ghi dữ liệu thành công cho SBD: 08003132
# Đã ghi dữ liệu thành công cho SBD: 08003133
# Đã ghi dữ liệu thành công cho SBD: 08003134
# Đã ghi dữ liệu thành công cho SBD: 08003135
# Đã ghi dữ liệu thành công cho SBD: 08003136
# Đã ghi dữ liệu thành công cho SBD: 08003137
# Đã ghi dữ liệu thành công cho SBD: 08003138
# Đã ghi dữ liệu thành công cho SBD: 08003139
# Đã ghi dữ liệu thành công cho SBD: 08003140
# Đã ghi dữ liệu thành công cho SBD: 08003141
# Đã ghi dữ liệu thành công cho SBD: 08003142
# Đã ghi dữ liệu thành công cho SBD: 08003143
# Đã ghi dữ liệu thành công cho SBD: 08003144
# Đã ghi dữ liệu thành công cho SBD: 08003145
# Đã ghi dữ liệu thành công cho SBD: 08003146
# Đã ghi dữ liệu thành công cho SBD: 08003147
# Đã ghi dữ liệu thành công cho SBD: 08003148
# Đã ghi dữ liệu thành công cho SBD: 08003149
# Đã ghi dữ liệu thành công cho SBD: 08003150
# Đã ghi dữ liệu thành công cho SBD: 08003151
# Đã ghi dữ liệu thành công cho SBD: 08003152
# Đã ghi dữ liệu thành công cho SBD: 08003153
# Đã ghi dữ liệu thành công cho SBD: 08003154
# Đã ghi dữ liệu thành công cho SBD: 08003155
# Đã ghi dữ liệu thành công cho SBD: 08003156
# Đã ghi dữ liệu thành công cho SBD: 08003157
# Đã ghi dữ liệu thành công cho SBD: 08003158
# Đã ghi dữ liệu thành công cho SBD: 08003159
# Đã ghi dữ liệu thành công cho SBD: 08003160
# Đã ghi dữ liệu thành công cho SBD: 08003161
# Đã ghi dữ liệu thành công cho SBD: 08003162
# Đã ghi dữ liệu thành công cho SBD: 08003163
# Đã ghi dữ liệu thành công cho SBD: 08003164
# Đã ghi dữ liệu thành công cho SBD: 08003165
# Đã ghi dữ liệu thành công cho SBD: 08003166
# Đã ghi dữ liệu thành công cho SBD: 08003167
# Đã ghi dữ liệu thành công cho SBD: 08003168
# Đã ghi dữ liệu thành công cho SBD: 08003169
# Đã ghi dữ liệu thành công cho SBD: 08003170
# Đã ghi dữ liệu thành công cho SBD: 08003171
# Đã ghi dữ liệu thành công cho SBD: 08003172
# Đã ghi dữ liệu thành công cho SBD: 08003173
# Đã ghi dữ liệu thành công cho SBD: 08003174
# Đã ghi dữ liệu thành công cho SBD: 08003175
# Đã ghi dữ liệu thành công cho SBD: 08003176
# Đã ghi dữ liệu thành công cho SBD: 08003177
# Đã ghi dữ liệu thành công cho SBD: 08003178
# Đã ghi dữ liệu thành công cho SBD: 08003179
# Đã ghi dữ liệu thành công cho SBD: 08003180
# Đã ghi dữ liệu thành công cho SBD: 08003181
# Đã ghi dữ liệu thành công cho SBD: 08003182
# Đã ghi dữ liệu thành công cho SBD: 08003183
# Đã ghi dữ liệu thành công cho SBD: 08003184
# Đã ghi dữ liệu thành công cho SBD: 08003185
# Đã ghi dữ liệu thành công cho SBD: 08003186
# Đã ghi dữ liệu thành công cho SBD: 08003187
# Đã ghi dữ liệu thành công cho SBD: 08003188
# Đã ghi dữ liệu thành công cho SBD: 08003189
# Đã ghi dữ liệu thành công cho SBD: 08003190
# Đã ghi dữ liệu thành công cho SBD: 08003191
# Đã ghi dữ liệu thành công cho SBD: 08003192
# Đã ghi dữ liệu thành công cho SBD: 08003193
# Đã ghi dữ liệu thành công cho SBD: 08003194
# Đã ghi dữ liệu thành công cho SBD: 08003195
# Đã ghi dữ liệu thành công cho SBD: 08003196
# Đã ghi dữ liệu thành công cho SBD: 08003197
# Đã ghi dữ liệu thành công cho SBD: 08003198
# Đã ghi dữ liệu thành công cho SBD: 08003199
# Đã ghi dữ liệu thành công cho SBD: 08003200
# Đã ghi dữ liệu thành công cho SBD: 08003201
# Đã ghi dữ liệu thành công cho SBD: 08003202
# Đã ghi dữ liệu thành công cho SBD: 08003203
# Đã ghi dữ liệu thành công cho SBD: 08003204
# Đã ghi dữ liệu thành công cho SBD: 08003205
# Đã ghi dữ liệu thành công cho SBD: 08003206
# Đã ghi dữ liệu thành công cho SBD: 08003207
# Đã ghi dữ liệu thành công cho SBD: 08003208
# Đã ghi dữ liệu thành công cho SBD: 08003209
# Đã ghi dữ liệu thành công cho SBD: 08003210
# Đã ghi dữ liệu thành công cho SBD: 08003211
# Đã ghi dữ liệu thành công cho SBD: 08003212
# Đã ghi dữ liệu thành công cho SBD: 08003213
# Đã ghi dữ liệu thành công cho SBD: 08003214
# Đã ghi dữ liệu thành công cho SBD: 08003215
# Đã ghi dữ liệu thành công cho SBD: 08003216
# Đã ghi dữ liệu thành công cho SBD: 08003217
# Đã ghi dữ liệu thành công cho SBD: 08003218
# Đã ghi dữ liệu thành công cho SBD: 08003219
# Đã ghi dữ liệu thành công cho SBD: 08003220
# Đã ghi dữ liệu thành công cho SBD: 08003221
# Đã ghi dữ liệu thành công cho SBD: 08003222
# Đã ghi dữ liệu thành công cho SBD: 08003223
# Đã ghi dữ liệu thành công cho SBD: 08003224
# Đã ghi dữ liệu thành công cho SBD: 08003225
# Đã ghi dữ liệu thành công cho SBD: 08003226
# Đã ghi dữ liệu thành công cho SBD: 08003227
# Đã ghi dữ liệu thành công cho SBD: 08003228
# Đã ghi dữ liệu thành công cho SBD: 08003229
# Đã ghi dữ liệu thành công cho SBD: 08003230
# Đã ghi dữ liệu thành công cho SBD: 08003231
# Đã ghi dữ liệu thành công cho SBD: 08003232
# Đã ghi dữ liệu thành công cho SBD: 08003233
# Đã ghi dữ liệu thành công cho SBD: 08003234
# Đã ghi dữ liệu thành công cho SBD: 08003235
# Đã ghi dữ liệu thành công cho SBD: 08003236
# Đã ghi dữ liệu thành công cho SBD: 08003237
# Đã ghi dữ liệu thành công cho SBD: 08003238
# Đã ghi dữ liệu thành công cho SBD: 08003239
# Đã ghi dữ liệu thành công cho SBD: 08003240
# Đã ghi dữ liệu thành công cho SBD: 08003241
# Đã ghi dữ liệu thành công cho SBD: 08003242
# Đã ghi dữ liệu thành công cho SBD: 08003243
# Đã ghi dữ liệu thành công cho SBD: 08003244
# Đã ghi dữ liệu thành công cho SBD: 08003245
# Đã ghi dữ liệu thành công cho SBD: 08003246
# Đã ghi dữ liệu thành công cho SBD: 08003247
# Đã ghi dữ liệu thành công cho SBD: 08003248
# Đã ghi dữ liệu thành công cho SBD: 08003249
# Đã ghi dữ liệu thành công cho SBD: 08003250
# Đã ghi dữ liệu thành công cho SBD: 08003251
# Đã ghi dữ liệu thành công cho SBD: 08003252
# Đã ghi dữ liệu thành công cho SBD: 08003253
# Đã ghi dữ liệu thành công cho SBD: 08003254
# Đã ghi dữ liệu thành công cho SBD: 08003255
# Đã ghi dữ liệu thành công cho SBD: 08003256
# Đã ghi dữ liệu thành công cho SBD: 08003257
# Đã ghi dữ liệu thành công cho SBD: 08003258
# Đã ghi dữ liệu thành công cho SBD: 08003259
# Đã ghi dữ liệu thành công cho SBD: 08003260
# Đã ghi dữ liệu thành công cho SBD: 08003261
# Đã ghi dữ liệu thành công cho SBD: 08003262
# Đã ghi dữ liệu thành công cho SBD: 08003263
# Đã ghi dữ liệu thành công cho SBD: 08003264
# Đã ghi dữ liệu thành công cho SBD: 08003265
# Đã ghi dữ liệu thành công cho SBD: 08003266
# Đã ghi dữ liệu thành công cho SBD: 08003267
# Đã ghi dữ liệu thành công cho SBD: 08003268
# Đã ghi dữ liệu thành công cho SBD: 08003269
# Đã ghi dữ liệu thành công cho SBD: 08003270
# Đã ghi dữ liệu thành công cho SBD: 08003271
# Đã ghi dữ liệu thành công cho SBD: 08003272
# Đã ghi dữ liệu thành công cho SBD: 08003273
# Đã ghi dữ liệu thành công cho SBD: 08003274
# Đã ghi dữ liệu thành công cho SBD: 08003275
# Đã ghi dữ liệu thành công cho SBD: 08003276
# Đã ghi dữ liệu thành công cho SBD: 08003277
# Đã ghi dữ liệu thành công cho SBD: 08003278
# Đã ghi dữ liệu thành công cho SBD: 08003279
# Đã ghi dữ liệu thành công cho SBD: 08003280
# Đã ghi dữ liệu thành công cho SBD: 08003281
# Đã ghi dữ liệu thành công cho SBD: 08003282
# Đã ghi dữ liệu thành công cho SBD: 08003283
# Đã ghi dữ liệu thành công cho SBD: 08003284
# Đã ghi dữ liệu thành công cho SBD: 08003285
# Đã ghi dữ liệu thành công cho SBD: 08003286
# Đã ghi dữ liệu thành công cho SBD: 08003287
# Đã ghi dữ liệu thành công cho SBD: 08003288
# Đã ghi dữ liệu thành công cho SBD: 08003289
# Đã ghi dữ liệu thành công cho SBD: 08003290
# Đã ghi dữ liệu thành công cho SBD: 08003291
# Đã ghi dữ liệu thành công cho SBD: 08003292
# Đã ghi dữ liệu thành công cho SBD: 08003293
# Đã ghi dữ liệu thành công cho SBD: 08003294
# Đã ghi dữ liệu thành công cho SBD: 08003295
# Đã ghi dữ liệu thành công cho SBD: 08003296
# Đã ghi dữ liệu thành công cho SBD: 08003297
# Đã ghi dữ liệu thành công cho SBD: 08003298
# Đã ghi dữ liệu thành công cho SBD: 08003299
# Đã ghi dữ liệu thành công cho SBD: 08003300
# Đã ghi dữ liệu thành công cho SBD: 08003301
# Đã ghi dữ liệu thành công cho SBD: 08003302
# Đã ghi dữ liệu thành công cho SBD: 08003303
# Đã ghi dữ liệu thành công cho SBD: 08003304
# Đã ghi dữ liệu thành công cho SBD: 08003305
# Đã ghi dữ liệu thành công cho SBD: 08003306
# Đã ghi dữ liệu thành công cho SBD: 08003307
# Đã ghi dữ liệu thành công cho SBD: 08003308
# Đã ghi dữ liệu thành công cho SBD: 08003309
# Đã ghi dữ liệu thành công cho SBD: 08003310
# Đã ghi dữ liệu thành công cho SBD: 08003311
# Đã ghi dữ liệu thành công cho SBD: 08003312
# Đã ghi dữ liệu thành công cho SBD: 08003313
# Đã ghi dữ liệu thành công cho SBD: 08003314
# Đã ghi dữ liệu thành công cho SBD: 08003315
# Đã ghi dữ liệu thành công cho SBD: 08003316
# Đã ghi dữ liệu thành công cho SBD: 08003317
# Đã ghi dữ liệu thành công cho SBD: 08003318
# Đã ghi dữ liệu thành công cho SBD: 08003319
# Đã ghi dữ liệu thành công cho SBD: 08003320
# Đã ghi dữ liệu thành công cho SBD: 08003321
# Đã ghi dữ liệu thành công cho SBD: 08003322
# Đã ghi dữ liệu thành công cho SBD: 08003323
# Đã ghi dữ liệu thành công cho SBD: 08003324
# Đã ghi dữ liệu thành công cho SBD: 08003325
# Đã ghi dữ liệu thành công cho SBD: 08003326
# Đã ghi dữ liệu thành công cho SBD: 08003327
# Đã ghi dữ liệu thành công cho SBD: 08003328
# Đã ghi dữ liệu thành công cho SBD: 08003329
# Đã ghi dữ liệu thành công cho SBD: 08003330
# Đã ghi dữ liệu thành công cho SBD: 08003331
# Đã ghi dữ liệu thành công cho SBD: 08003332
# Đã ghi dữ liệu thành công cho SBD: 08003333
# Đã ghi dữ liệu thành công cho SBD: 08003334
# Đã ghi dữ liệu thành công cho SBD: 08003335
# Đã ghi dữ liệu thành công cho SBD: 08003336
# Đã ghi dữ liệu thành công cho SBD: 08003337
# Đã ghi dữ liệu thành công cho SBD: 08003338
# Đã ghi dữ liệu thành công cho SBD: 08003339
# Đã ghi dữ liệu thành công cho SBD: 08003340
# Đã ghi dữ liệu thành công cho SBD: 08003341
# Đã ghi dữ liệu thành công cho SBD: 08003342
# Đã ghi dữ liệu thành công cho SBD: 08003343
# Đã ghi dữ liệu thành công cho SBD: 08003344
# Đã ghi dữ liệu thành công cho SBD: 08003345
# Đã ghi dữ liệu thành công cho SBD: 08003346
# Đã ghi dữ liệu thành công cho SBD: 08003347
# Đã ghi dữ liệu thành công cho SBD: 08003348
# Đã ghi dữ liệu thành công cho SBD: 08003349
# Đã ghi dữ liệu thành công cho SBD: 08003350
# Đã ghi dữ liệu thành công cho SBD: 08003351
# Đã ghi dữ liệu thành công cho SBD: 08003352
# Đã ghi dữ liệu thành công cho SBD: 08003353
# Đã ghi dữ liệu thành công cho SBD: 08003354
# Đã ghi dữ liệu thành công cho SBD: 08003355
# Đã ghi dữ liệu thành công cho SBD: 08003356
# Đã ghi dữ liệu thành công cho SBD: 08003357
# Đã ghi dữ liệu thành công cho SBD: 08003358
# Đã ghi dữ liệu thành công cho SBD: 08003359
# Đã ghi dữ liệu thành công cho SBD: 08003360
# Đã ghi dữ liệu thành công cho SBD: 08003361
# Đã ghi dữ liệu thành công cho SBD: 08003362
# Đã ghi dữ liệu thành công cho SBD: 08003363
# Đã ghi dữ liệu thành công cho SBD: 08003364
# Đã ghi dữ liệu thành công cho SBD: 08003365
# Đã ghi dữ liệu thành công cho SBD: 08003366
# Đã ghi dữ liệu thành công cho SBD: None
# Đã ghi dữ liệu thành công cho SBD: 08003368
# Đã ghi dữ liệu thành công cho SBD: 08003369
# Đã ghi dữ liệu thành công cho SBD: 08003370
# Đã ghi dữ liệu thành công cho SBD: 08003371
# Đã ghi dữ liệu thành công cho SBD: 08003372
# Đã ghi dữ liệu thành công cho SBD: 08003373
# Đã ghi dữ liệu thành công cho SBD: 08003374
# Đã ghi dữ liệu thành công cho SBD: 08003375
# Đã ghi dữ liệu thành công cho SBD: 08003376
# Đã ghi dữ liệu thành công cho SBD: 08003377
# Đã ghi dữ liệu thành công cho SBD: 08003378
# Đã ghi dữ liệu thành công cho SBD: 08003379
# Đã ghi dữ liệu thành công cho SBD: 08003380
# Đã ghi dữ liệu thành công cho SBD: 08003381
# Đã ghi dữ liệu thành công cho SBD: 08003382
# Đã ghi dữ liệu thành công cho SBD: 08003383
# Đã ghi dữ liệu thành công cho SBD: 08003384
# Đã ghi dữ liệu thành công cho SBD: 08003385
# Đã ghi dữ liệu thành công cho SBD: 08003386
# Đã ghi dữ liệu thành công cho SBD: 08003387
# Đã ghi dữ liệu thành công cho SBD: 08003388
# Đã ghi dữ liệu thành công cho SBD: 08003389
# Đã ghi dữ liệu thành công cho SBD: 08003390
# Đã ghi dữ liệu thành công cho SBD: 08003391
# Đã ghi dữ liệu thành công cho SBD: 08003392
# Đã ghi dữ liệu thành công cho SBD: 08003393
# Đã ghi dữ liệu thành công cho SBD: 08003394
# Đã ghi dữ liệu thành công cho SBD: 08003395
# Đã ghi dữ liệu thành công cho SBD: 08003396
# Đã ghi dữ liệu thành công cho SBD: 08003397
# Đã ghi dữ liệu thành công cho SBD: 08003398
# Đã ghi dữ liệu thành công cho SBD: 08003399
# Đã ghi dữ liệu thành công cho SBD: 08003400
# Đã ghi dữ liệu thành công cho SBD: 08003401
# Đã ghi dữ liệu thành công cho SBD: 08003402
# Đã ghi dữ liệu thành công cho SBD: 08003403
# Đã ghi dữ liệu thành công cho SBD: 08003404
# Đã ghi dữ liệu thành công cho SBD: 08003405
# Đã ghi dữ liệu thành công cho SBD: 08003406
# Đã ghi dữ liệu thành công cho SBD: 08003407
# Đã ghi dữ liệu thành công cho SBD: 08003408
# Đã ghi dữ liệu thành công cho SBD: 08003409
# Đã ghi dữ liệu thành công cho SBD: 08003410
# Đã ghi dữ liệu thành công cho SBD: 08003411
# Đã ghi dữ liệu thành công cho SBD: 08003412
# Đã ghi dữ liệu thành công cho SBD: 08003413
# Đã ghi dữ liệu thành công cho SBD: 08003414
# Đã ghi dữ liệu thành công cho SBD: 08003415
# Đã ghi dữ liệu thành công cho SBD: 08003416
# Đã ghi dữ liệu thành công cho SBD: 08003417
# Đã ghi dữ liệu thành công cho SBD: 08003418
# Đã ghi dữ liệu thành công cho SBD: 08003419
# Đã ghi dữ liệu thành công cho SBD: 08003420
# Đã ghi dữ liệu thành công cho SBD: 08003421
# Đã ghi dữ liệu thành công cho SBD: 08003422
# Đã ghi dữ liệu thành công cho SBD: 08003423
# Đã ghi dữ liệu thành công cho SBD: 08003424
# Đã ghi dữ liệu thành công cho SBD: 08003425
# Đã ghi dữ liệu thành công cho SBD: 08003426
# Đã ghi dữ liệu thành công cho SBD: 08003427
# Đã ghi dữ liệu thành công cho SBD: 08003428
# Đã ghi dữ liệu thành công cho SBD: 08003429
# Đã ghi dữ liệu thành công cho SBD: 08003430
# Đã ghi dữ liệu thành công cho SBD: 08003431
# Đã ghi dữ liệu thành công cho SBD: 08003432
# Đã ghi dữ liệu thành công cho SBD: 08003433
# Đã ghi dữ liệu thành công cho SBD: 08003434
# Đã ghi dữ liệu thành công cho SBD: 08003435
# Đã ghi dữ liệu thành công cho SBD: 08003436
# Đã ghi dữ liệu thành công cho SBD: 08003437
# Đã ghi dữ liệu thành công cho SBD: 08003438
# Đã ghi dữ liệu thành công cho SBD: 08003439
# Đã ghi dữ liệu thành công cho SBD: 08003440
# Đã ghi dữ liệu thành công cho SBD: 08003441
# Đã ghi dữ liệu thành công cho SBD: 08003442
# Đã ghi dữ liệu thành công cho SBD: 08003443
# Đã ghi dữ liệu thành công cho SBD: 08003444
# Đã ghi dữ liệu thành công cho SBD: 08003445
# Đã ghi dữ liệu thành công cho SBD: 08003446
# Đã ghi dữ liệu thành công cho SBD: 08003447
# Đã ghi dữ liệu thành công cho SBD: 08003448
# Đã ghi dữ liệu thành công cho SBD: 08003449
# Đã ghi dữ liệu thành công cho SBD: 08003450
# Đã ghi dữ liệu thành công cho SBD: 08003451
# Đã ghi dữ liệu thành công cho SBD: 08003452
# Đã ghi dữ liệu thành công cho SBD: 08003453
# Đã ghi dữ liệu thành công cho SBD: 08003454
# Đã ghi dữ liệu thành công cho SBD: 08003455
# Đã ghi dữ liệu thành công cho SBD: 08003456
# Đã ghi dữ liệu thành công cho SBD: 08003457
# Đã ghi dữ liệu thành công cho SBD: 08003458
# Đã ghi dữ liệu thành công cho SBD: 08003459
# Đã ghi dữ liệu thành công cho SBD: 08003460
# Đã ghi dữ liệu thành công cho SBD: 08003461
# Đã ghi dữ liệu thành công cho SBD: 08003462
# Đã ghi dữ liệu thành công cho SBD: 08003463
# Đã ghi dữ liệu thành công cho SBD: 08003464
# Đã ghi dữ liệu thành công cho SBD: 08003465
# Đã ghi dữ liệu thành công cho SBD: 08003466
# Đã ghi dữ liệu thành công cho SBD: 08003467
# Đã ghi dữ liệu thành công cho SBD: 08003468

# %%
import requests
import time
import csv

# Đường dẫn đến file CSV
file_path = r"E:\\DA\\Crawl\\09_TuyenQuang.csv"

# Mở file CSV để ghi dữ liệu
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Ghi tiêu đề cột
    writer.writerow([
        'SBD', 'Toan', 'Van', 'NgoaiNgu', 'VatLy', 'HoaHoc', 'SinhHoc',
        'TBKHTN', 'LichSu', 'DiaLy', 'GDCD', 'TBKHXH'
    ])
    
    # Vòng lặp lấy dữ liệu
    for x in range(9000001, 10000001):
        scraping_url = f"https://dantri.com.vn/thpt/1/0/99/{x}/2024/0.2/search-gradle.htm"
        
        try:
            # Gửi yêu cầu
            response = requests.get(scraping_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            
            # Phân tích phản hồi JSON
            data = response.json()
            
            # Kiểm tra nếu có khóa 'student' trong phản hồi
            if 'student' in data:
                info = data['student']
                
                # Ghi dữ liệu vào file CSV
                writer.writerow([
                    info.get('sbd', 'None'),
                    info.get('toan', 'None'),
                    info.get('van', 'None'),
                    info.get('ngoaiNgu', 'None'),
                    info.get('vatLy', 'None'),
                    info.get('hoaHoc', 'None'),
                    info.get('sinhHoc', 'None'),
                    info.get('diemTBTuNhien', 'None'),
                    info.get('lichSu', 'None'),
                    info.get('diaLy', 'None'),
                    info.get('gdcd', 'None'),
                    info.get('diemTBXaHoi', 'None')
                ])
                
                # Hiển thị thông báo đã ghi dữ liệu thành công
                print(f"Đã ghi dữ liệu thành công cho SBD: {info.get('sbd', 'Unknown')}")

                # Đảm bảo dữ liệu được ghi vào tệp ngay lập tức
                file.flush()
            else:
                print(f"Không có khóa 'student' trong phản hồi cho URL: {scraping_url}")
            
        except requests.RequestException as e:
            print(f"Yêu cầu không thành công cho URL {scraping_url}: {e}")
        except ValueError as e:
            print(f"Lỗi khi phân tích cú pháp JSON cho URL {scraping_url}: {e}")
        except csv.Error as e:
            print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
        
        # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
        time.sleep(0.4)

# %%
import requests
import time
import csv

# Đường dẫn đến file CSV
file_path = r"E:\\DA\\Crawl\\10_LangSon.csv"

# Mở file CSV để ghi dữ liệu
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Ghi tiêu đề cột
    writer.writerow([
        'SBD', 'Toan', 'Van', 'NgoaiNgu', 'VatLy', 'HoaHoc', 'SinhHoc',
        'TBKHTN', 'LichSu', 'DiaLy', 'GDCD', 'TBKHXH'
    ])
    
    # Vòng lặp lấy dữ liệu
    for x in range(9000001, 10000001):
        scraping_url = f"https://dantri.com.vn/thpt/1/0/99/{x}/2024/0.2/search-gradle.htm"
        
        try:
            # Gửi yêu cầu
            response = requests.get(scraping_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            
            # Phân tích phản hồi JSON
            data = response.json()
            
            # Kiểm tra nếu có khóa 'student' trong phản hồi
            if 'student' in data:
                info = data['student']
                
                # Ghi dữ liệu vào file CSV
                writer.writerow([
                    info.get('sbd', 'None'),
                    info.get('toan', 'None'),
                    info.get('van', 'None'),
                    info.get('ngoaiNgu', 'None'),
                    info.get('vatLy', 'None'),
                    info.get('hoaHoc', 'None'),
                    info.get('sinhHoc', 'None'),
                    info.get('diemTBTuNhien', 'None'),
                    info.get('lichSu', 'None'),
                    info.get('diaLy', 'None'),
                    info.get('gdcd', 'None'),
                    info.get('diemTBXaHoi', 'None')
                ])
                
                # Hiển thị thông báo đã ghi dữ liệu thành công
                print(f"Đã ghi dữ liệu thành công cho SBD: {info.get('sbd', 'Unknown')}")

                # Đảm bảo dữ liệu được ghi vào tệp ngay lập tức
                file.flush()
            else:
                print(f"Không có khóa 'student' trong phản hồi cho URL: {scraping_url}")
            
        except requests.RequestException as e:
            print(f"Yêu cầu không thành công cho URL {scraping_url}: {e}")
        except ValueError as e:
            print(f"Lỗi khi phân tích cú pháp JSON cho URL {scraping_url}: {e}")
        except csv.Error as e:
            print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
        
        # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
        time.sleep(0.4)

# %%
import requests
import time
import csv

# Đường dẫn đến file CSV
file_path = r"E:\\DA\\Crawl\\12_ThaiNguyen.csv"

# Mở file CSV để ghi dữ liệu
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Ghi tiêu đề cột
    writer.writerow([
        'SBD', 'Toan', 'Van', 'NgoaiNgu', 'VatLy', 'HoaHoc', 'SinhHoc',
        'TBKHTN', 'LichSu', 'DiaLy', 'GDCD', 'TBKHXH'
    ])
    
    # Vòng lặp lấy dữ liệu
    for x in range(12000001, 13000001):
        scraping_url = f"https://dantri.com.vn/thpt/1/0/99/{x}/2024/0.2/search-gradle.htm"
        
        try:
            # Gửi yêu cầu
            response = requests.get(scraping_url)
            response.raise_for_status()  # Raise an HTTPError for bad responses
            
            # Phân tích phản hồi JSON
            data = response.json()
            
            # Kiểm tra nếu có khóa 'student' trong phản hồi
            if 'student' in data:
                info = data['student']
                
                # Ghi dữ liệu vào file CSV
                writer.writerow([
                    info.get('sbd', 'None'),
                    info.get('toan', 'None'),
                    info.get('van', 'None'),
                    info.get('ngoaiNgu', 'None'),
                    info.get('vatLy', 'None'),
                    info.get('hoaHoc', 'None'),
                    info.get('sinhHoc', 'None'),
                    info.get('diemTBTuNhien', 'None'),
                    info.get('lichSu', 'None'),
                    info.get('diaLy', 'None'),
                    info.get('gdcd', 'None'),
                    info.get('diemTBXaHoi', 'None')
                ])
                
                # Hiển thị thông báo đã ghi dữ liệu thành công
                print(f"Đã ghi dữ liệu thành công cho SBD: {info.get('sbd', 'Unknown')}")

                # Đảm bảo dữ liệu được ghi vào tệp ngay lập tức
                file.flush()
            else:
                print(f"Không có khóa 'student' trong phản hồi cho URL: {scraping_url}")
            
        except requests.RequestException as e:
            print(f"Yêu cầu không thành công cho URL {scraping_url}: {e}")
        except ValueError as e:
            print(f"Lỗi khi phân tích cú pháp JSON cho URL {scraping_url}: {e}")
        except csv.Error as e:
            print(f"Lỗi khi ghi vào CSV cho URL {scraping_url}: {e}")
        
        # Thêm thời gian chờ 0.5 giây giữa các yêu cầu
        time.sleep(0.4)
